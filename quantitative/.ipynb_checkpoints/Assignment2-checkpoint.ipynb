# %%
import pandas as pd
import seaborn as sns
import spacy # Dutch language package required (python -m spacy download nl_core_news_lg)
import nltk 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
df = pd.read_excel('dataset.xlsx')

# %%
df = df.dropna(axis=1, how='all')
df.head()
TBT = df[(df['INTERFACEUSED'] == 'TBT') & (df['TURNTYPE'] == 'TBT')]
WYS = df[df['INTERFACEUSED'] == 'WYSIWYG']
test = WYS[(WYS['dyadid'] == 4) & (WYS['GameNo'] == 0)]
WYS
# Out:
#        turntid  dyadid experimenttype INTERFACEUSED TURNTYPE        Sender  \
# 0         2088       4     WYSIWYGTBT       WYSIWYG  WYSIWYG  Participant1
# 1         2089       4     WYSIWYGTBT       WYSIWYG  WYSIWYG  Participant2
# 2         2090       4     WYSIWYGTBT       WYSIWYG  WYSIWYG  Participant1
# 3         2091       4     WYSIWYGTBT       WYSIWYG  WYSIWYG  Participant2
# 4         2092       4     WYSIWYGTBT       WYSIWYG  WYSIWYG  Participant1
# ...        ...     ...            ...           ...      ...           ...
# 36227    86458      48     WYSIWYGTBT       WYSIWYG  WYSIWYG  Participant1
# 36228    86468      48     WYSIWYGTBT       WYSIWYG  WYSIWYG  Participant2
# 36229    86469      48     WYSIWYGTBT       WYSIWYG  WYSIWYG  Participant1
# 36230    86484      48     WYSIWYGTBT       WYSIWYG     data  Participant1
# 36231    86485      48     WYSIWYGTBT       WYSIWYG     data  Participant2
#
#                                                Text  Deletes1  Deletes2  \
# 0                                             hello       NaN       NaN
# 1                                   helloHIk begin?       NaN       NaN
# 2                                              JA a       NaN       NaN
# 3                                                Ok       NaN       NaN
# 4                                               ben       NaN       NaN
# ...                                             ...       ...       ...
# 36227                                   5X2y3ofx7y2       NaN       NaN
# 36228                             Dat kan nietx2y3?       NaN       NaN
# 36229  sta op roodx2y3is daar een gijze in debururt       NaN       NaN
# 36230                                       CORRECT       NaN       NaN
# 36231                                       CORRECT       NaN       NaN
#
#        TimestampReceived  Duration  GameNo  MazeID
# 0          1590415670089      1180       0       3
# 1          1590415839078    167246       0       3
# 2          1590415843050      1353       0       3
# 3          1590415843491       189       0       3
# 4          1590415843951       159       0       3
# ...                  ...       ...     ...     ...
# 36227      1591782098813      9301       9       1
# 36228      1591782107599      7161       9       1
# 36229      1591782127222      9852       9       1
# 36230      1591782148944         0       9       1
# 36231      1591782148945         0       9       1
#
# [13719 rows x 13 columns]

# %%
temp_string1, temp_string2 = '', ''
WYS_turn_list, participant1, participant2 = [], [], []
timestamps = set()
gameid = WYS.iloc[0].GameNo
for index, row in WYS.iterrows():
    if gameid != row.GameNo:
        WYS_turn_list.append(([turn for turn in participant1 if turn != '' and turn != 'CORRECT' and turn != ' '], [turn for turn in participant2 if turn != '' and turn != 'CORRECT' and turn != ' '], (max(timestamps) - min(timestamps))/1000))
        participant1, participant2, timestamps = [],[],set()  
        gameid = row.GameNo
    timestamps.add(row.TimestampReceived)
    item = str(row.Text)
    if row.Sender == 'Participant1':
        if len(item) == 1:
            temp_string1 += item
        elif len(temp_string1) != 0 and len(item) != 0:
            participant1.append(temp_string1)
            participant1.append(item)
            temp_string1 = ''
        else:
            participant1.append(item)
    else:
        if len(item) == 1:
            temp_string2 += item
        elif len(temp_string2) != 0 and len(item) != 0:
            participant2.append(temp_string2)
            participant2.append(item)
            temp_string2 = ''
        else:
            participant2.append(item)
WYS_turn_list.append(([turn for turn in participant1 if turn != '' and turn != 'CORRECT'], [turn for turn in participant2 if turn != '' and turn != 'CORRECT'], (max(timestamps) - min(timestamps))/1000))
# Out:
# 1590416038132 1590415670089
# 1590416166266 1590416033956
# 1590416288357 1590416164772
# 1590416330401 1590416287863
# 1590416425462 1590416330389
# 1590416621600 1590416423789
# 1590416709688 1590416616927
# 1590416816815 1590416707875
# 1590416892914 1590416836697
# 1590416969981 1590416905723
# 1590654589880 1590652206798
# 1590654833229 1590654584922
# 1590654948783 1590654840591
# 1590655027457 1590654955673
# 1590655116618 1590655036060
# 1590655197951 1590655125505
# 1590655335980 1590655200637
# 1590655456402 1590655346097
# 1590655692650 1590655461116
# 1590655856056 1590655699735
# 1590657436972 1590657164989
# 1590657499955 1590657438451
# 1590657753164 1590657518808
# 1590657893158 1590657768231
# 1590657987567 1590657895814
# 1590658145782 1590658001238
# 1590658269960 1590658142836
# 1590658417588 1590658271114
# 1590658466544 1590658417687
# 1590658522452 1590658481618
# 1590665443372 1590665403169
# 1590665592148 1590665442458
# 1590667967791 1590667704470
# 1590668276973 1590667974196
# 1590668492326 1590668278997
# 1590668752041 1590668493026
# 1590668800003 1590668752842
# 1590668896780 1590668822045
# 1590669029157 1590668896951
# 1590669127449 1590669051858
# 1590669204569 1590669152464
# 1590669512228 1590669224568
# 1590672757446 1590672607394
# 1590672890215 1590672759063
# 1590738408070 1590738116180
# 1590738500284 1590738403309
# 1590740068887 1590739776335
# 1590740302064 1590740075127
# 1590740612286 1590740309118
# 1590740736363 1590740600285
# 1590740937498 1590740743415
# 1590741101593 1590740939576
# 1590741411810 1590741118249
# 1590741716953 1590741409626
# 1590741844007 1590741705732
# 1590742099137 1590741851084
# 1590747500156 1590747223738
# 1590747643270 1590747515356
# 1590747953438 1590747670163
# 1590748061469 1590747903976
# 1590748210528 1590748055988
# 1590748334568 1590748223124
# 1590748392614 1590748330976
# 1590748540695 1590748404897
# 1590748674765 1590748552571
# 1590748773818 1590748668308
# 1590754267662 1590754054732
# 1590754462444 1590754290292
# 1590754539989 1590754480251
# 1590754642052 1590754540317
# 1590754682116 1590754654119
# 1590754761735 1590754684601
# 1590754827243 1590754775343
# 1590754922342 1590754825591
# 1590755003979 1590754947645
# 1590755050484 1590755005815
# 1590760959302 1590760718959
# 1590761296193 1590760953701
# 1590761984001 1590761795150
# 1590762170920 1590761984585
# 1590762281477 1590762192925
# 1590762396064 1590762306855
# 1590762498300 1590762391704
# 1590762549163 1590762515701
# 1590762603214 1590762552553
# 1590762695285 1590762602999
# 1590762844359 1590762710819
# 1590762915411 1590762839946
# 1590837370437 1590837078163
# 1590837631669 1590837377244
# 1590837900021 1590837632550
# 1590838102794 1590837902801
# 1590838222665 1590838120107
# 1590838457104 1590838222731
# 1590838764280 1590838458925
# 1590839069499 1590838764152
# 1590839340559 1590839081859
# 1590839479370 1590839344679
# 1590843861409 1590843547734
# 1590843985510 1590843863432
# 1590845282593 1590845017407
# 1590845587883 1590845521677
# 1590845893118 1590845571735
# 1590846198333 1590845906475
# 1590846503534 1590846194374
# 1590846808716 1590846516535
# 1590846999554 1590846810736
# 1590847239970 1590847004850
# 1590847459143 1590847251629
# 1590847705483 1590847474527
# 1591004020728 1591003911973
# 1591004157407 1591004023018
# 1591009921463 1591009647893
# 1591010051124 1591009926151
# 1591010136696 1591010052207
# 1591010299857 1591010167582
# 1591010401991 1591010300550
# 1591010494075 1591010404753
# 1591010620360 1591010524288
# 1591010719323 1591010621089
# 1591010881720 1591010722965
# 1591010967592 1591010883000
# 1591015074602 1591014864242
# 1591015178708 1591015081652
# 1591020680380 1591020378850
# 1591020917770 1591020683983
# 1591021046451 1591020925867
# 1591021183740 1591021056666
# 1591021327361 1591021194243
# 1591021442969 1591021327756
# 1591021677330 1591021447614
# 1591021747633 1591021679387
# 1591021864270 1591021753584
# 1591021994054 1591021866026
# 1591022264795 1591022264795
# 1591091144744 1591090955702
# 1591091303870 1591091151789
# 1591093235736 1591092979464
# 1591093430869 1591093238076
# 1591093522911 1591093437926
# 1591093647004 1591093547343
# 1591093861087 1591093663161
# 1591093921130 1591093885883
# 1591094027201 1591093923483
# 1591094223272 1591094022486
# 1591094533444 1591094220198
# 1591094838626 1591094532238
# 1591100219719 1591099943902
# 1591100463507 1591100239332
# 1591176842307 1591176603178
# 1591176962379 1591176841920
# 1591179871889 1591179618627
# 1591180177104 1591179873919
# 1591180451295 1591180176394
# 1591180665498 1591180472376
# 1591180792223 1591180670309
# 1591181099822 1591180793289
# 1591181263953 1591181103064
# 1591181473723 1591181260862
# 1591181737116 1591181477323
# 1591181860870 1591181737303
# 1591184681280 1591184442896
# 1591184740345 1591184678165
# 1591186477347 1591186332881
# 1591186643453 1591186472838
# 1591186787575 1591186665945
# 1591186968699 1591186782443
# 1591187139844 1591186982642
# 1591187240927 1591187139090
# 1591187399016 1591187235239
# 1591187463073 1591187398063
# 1591187620129 1591187462192
# 1591187759226 1591187619358
# 1591191277087 1591191134711
# 1591191418901 1591191279062
# 1591620142022 1591620011404
# 1591620227104 1591620155080
# 1591780990833 1591780572562
# 1591781183003 1591780997883
# 1591781493282 1591781205442
# 1591781672252 1591781506299
# 1591781717515 1591781684194
# 1591781785584 1591781721782
# 1591781857706 1591781790058
# 1591781934780 1591781870543
# 1591782056018 1591781945062

# %%
WYS_turn_list
# Out:
# [(['hello',
#    'JA a',
#    'ben',
#    'Ik kan niet helemaal nlinks onder komen',
#    'JA',
#    'OkeIk heb van de linkerrij de onderste nodig',
#    'Ja',
#    'Ik ben onderweg',
#    'Is ',
#    'het deze',
#    '?',
#    'Kun je mijne nog eens open zetten?',
#    'Ogf moet je dan langs een poortje?',
#    'De rechtre',
#    'Je hebt ede derde rij van rechtes en dan het onderste blokjeDe is ook ',
#    'g',
#    'rij',
#    's b',
#    'ij mijIk ben er'],
#   ['helloHIk begin?',
#    'Ok',
#    'hHelemaal links onder kun je een vierkant maken met 4 vblokjes?',
#    'nee maar zie je helemaal links onder 4 blokes?',
#    'Ik heb het rechter bovenste blokje nodig',
#    'Gaat je poortje open?',
#    'Mijne niet',
#    'okiiwaa',
#    'r j',
#    'jaaa',
#    'ga naar je kruisje',
#    'okii',
#    'huh wat raarik moet waarschijnlijk een andere grijse van jouanders kan i',
#    'k ',
#    'niet ',
#    'lang',
#    's ',
#    'd ',
#    'e poort',
#    'ga',
#    'at',
#    'he',
#    't?'],
#   368.043),
#  (['Ik heb een grijs blokje helemaal rehchst',
#    'Ik heb ook een grijze in de vierde rij van boven en dan de tweede',
#    'wekewelk',
#    'e ',
#    'mo',
#    'et',
#    'Ja hij is open',
#    'oh dan moet ik weet door een poort',
#    'Deze?',
#    'kun je er komen'],
#   ['oki',
#    'ik heb daar een ppoortdus kannie',
#    'gaat het open?',
#    'vi',
#    'er',
#    'd',
#    'e rij van boven en dan de tweede zei je?>',
#    'okik heb bovik heb de tweede rij van bocven en dan links',
#    'ok ik heb tderde ru=rij van onder de rechter',
#    'top!',
#    'ja'],
#   132.31),
#  (['tweede rij van boven tweede rechtsen vri',
#    'ie',
#    'vierde rij van boven tweede van rehchts?',
#    'h',
#    'oe',
#    'waar zijn die?',
#    'Kan ik niet komen',
#    'zijn ze open?',
#    'nee',
#    'ja'],
#   ['waar heb je?',
#    'he',
#    'b',
#    ' poortje daar',
#    'poortjeik kan alleen naa rbenedenof je',
#    ' m',
#    'oe',
#    't poortje openen',
#    'helemaal beneden middelste',
#    'oki dan tweede rij boven helemaal links',
#    'kan jioj door je poortjes?',
#    'nu?',
#    'top'],
#   123.585),
#  (['ben jij bij de ', 'ik bij linksonder', 'zijn ze open?'],
#   ['ik heb bij de aller rechste blok een grijze',
#    'ik kan niet naar onder',
#    'nu?'],
#   42.538),
#  (['Ja',
#    'kan ik niet komen',
#    'ik',
#    ' h',
#    'eb',
#    ' er dr',
#    'ie',
#    'bovens',
#    'te',
#    ' rij',
#    'd',
#    ' de linker',
#    'JaIs dit die van jouw?',
#    'be',
#    'n ',
#    'j',
#    'e ',
#    'er a',
#    'lkun je naar de tweede rij de derde?'],
#   ['ik heb veierder*vierde rij onder helemaal links',
#    'dat is mijn enige',
#    ' waar ',
#    'is',
#    ' jo',
#    'uwne?',
#    'ok',
#    'i u',
#    'mnu?',
#    'ja',
#    'b',
#    'en',
#    ' b',
#    'ij',
#    ' m',
#    'ij',
#    'n doel',
#    'ja??'],
#   95.073),
#  (['ik bern er',
#    'ik ook',
#    'maa',
#    'r ',
#    'ik kan e',
#    'daa',
#    'r',
#    ' niet komen',
#    'i',
#    'k heb de rechternaast het midden',
#    'waar',
#    ' z',
#    'i',
#    'deze?',
#    'rec',
#    'h',
#    'ts',
#    'va',
#    'n',
#    ' het midden',
#    'nee',
#    'vierde rij vijfde van links',
#    'ja',
#    'jij had dtoch ook een twee onder het midden?',
#    'zijn ze open?'],
#   ['hahaoki ik heb tweede onder middelste',
#    'oh ',
#    'ik',
#    ' k',
#    'an',
#    ' er nie',
#    't he',
#    'en',
#    ' hahah ik ookn',
#    'ie',
#    'ik kan alleen de linker vlak doen. Dus jij moet eerst mijn poortjes openenik',
#    ' h',
#    'eb',
#    'tw',
#    'ee',
#    'de van boven helemaal rechts',
#    'waar was jouwne ook al weer?',
#    'd',
#    'ie',
#    ' ban',
#    'is het goed?',
#    'rechts van het midden?',
#    'nu?',
#    'mijn ppoortje gaat nu dicht je moet dan naar de tweede rij voen enboven* en dan helemaal rechts',
#    'jaa'],
#   197.811),
#  (['ik heb de meest rechteren de alleronderste',
#    'welke he',
#    'b ',
#    'jij?',
#    'kan niet',
#    'gaan ze open?',
#    'janu zijn ze weer cdicht'],
#   ['Mee, ik heb tweede rij van onder, en dan in het middenja',
#    'ok ik kan daar nie theen',
#    'i',
#    ' h',
#    'e',
#    'b ',
#    'bov',
#    'enste en dan erechts',
#    'vierde rij van onder en dan tweede van rechts',
#    'gaan jouwnes open?',
#    'oki, was te snelga naar je doel'],
#   92.761),
#  (['ben er',
#    'mooiik heb linksonderli',
#    'nk',
#    'er',
#    'rij',
#    'rechts twweede van bovenkan die?',
#    'Ja',
#    'he',
#    'b',
#    ' je',
#    ' no',
#    'g eentje links?',
#    'deze?'],
#   ['ik heb rechts helemaak onderwaar heb jij?hij is open hoor',
#    'ik ',
#    'mo',
#    'et',
#    'ergens rechts zijn',
#    'dze?',
#    'oh shit nus mijne dichtik he',
#    'b p',
#    'oo',
#    'rtj',
#    'e ',
#    'nee ik heb rechts onderohh wacht jawel linkslinkste rij en dan tweede van boven'],
#   108.94),
#  (['kan ik niet komen',
#    'ik',
#    ' h',
#    'eb',
#    ' v',
#    'ie',
#    'r',
#    'de',
#    'rij van boven en de meest rechterik h',
#    'eb ook ',
#    'de ',
#    'o',
#    'nderste rij de rechter',
#    'ben bij jouwne'],
#   ['hjaik ben erik heb 1die is derde rij van onder en dan tweede van rechts',
#    'ok',
#    'waa',
#    ' r',
#    'he',
#    'b',
#    ' j',
#    'ij?ka',
#    'n ',
#    'ik ',
#    'nie',
#    ' r',
#    'bi',
#    'j',
#    'ja'],
#   56.217),
#  (['ik ook',
#    'pja',
#    'j',
#    'ou',
#    'nwne ook',
#    '?',
#    'kun je naar',
#    ' onderste rij links?',
#    'jaik',
#    ' b',
#    'en',
#    ' er'],
#   ['ja ik kan nuik heb helemaal rechts onder',
#    'gaan jouwne o[en',
#    'ga',
#    ' d',
#    'ja',
#    'a',
#    'ja',
#    'jagoed?',
#    'g',
#    'a na',
#    'ar ',
#    'je'],
#   64.258),
#  (['HIOK. HwWaWowik heb een ideeals we nou',
#    'as',
#    ' w',
#    'e',
#    'als we een raster maken en ekklk vakje',
#    ' e',
#    'en',
#    ' getal hebb',
#    'en',
#    '7x7',
#    'er zijn 49 vakjes totlaa, maar wre zien er maar een ',
#    'pa',
#    'ar',
#    'ja',
#    ' dat',
#    'bedel',
#    ' i',
#    'kA1',
#    'A2etc',
#    'bo',
#    'oketoo',
#    'alleen niet elke combu i bestaat',
#    'isgu',
#    'it',
#    'tekene',
#    'n',
#    ' of',
#    ' maf',
#    ' d',
#    'at n',
#    'ie',
#    't?',
#    'oki',
#    'ma',
#    'armj',
#    'jamaar onze vormen zijn anders',
#    'ja',
#    'to',
#    'ch>drm',
#    ' i',
#    'k ',
#    'h',
#    'eb',
#    ' o',
#    'nd',
#    'erin 3 vakjes begint bij A2rij',
#    ' B heft',
#    ' er 344ooh okedan wel ',
#    'he',
#    'tz',
#    'el',
#    'fde d',
#    'en',
#    'k',
#    'ja b',
#    'u',
#    'j mij ook bed',
#    'o',
#    'elde',
#    ' i',
#    'k ook',
#    'ik heb 2,5,5,6,3,4,3',
#    'volorde va bivenoke we moeten wat d',
#    'o',
#    'en',
#    'g',
#    'a j',
#    'i',
#    'j hleema',
#    'al',
#    ' naa',
#    'r on',
#    'derien',
#    'middels',
#    'te ',
#    'van ',
#    'onder',
#    'ga onderin de middelsteondersteerijmiddel ste vakdat is',
#    ' bi',
#    'j ',
#    'mij g',
#    'rijsja3 sec',
#    'kutok',
#    'ja',
#    ' v',
#    'er',
#    'zi',
#    'n ',
#    'er',
#    ' 1',
#    'en=i',
#    'k ',
#    'k',
#    'an ',
#    'niet op d',
#    'e ',
#    '2e',
#    ' rij komen',
#    'oke ik weerga naar rij B het vakje helemaal rechts',
#    'doe de helee maal rechts dieje wel kanmsis miss is die van jou verder maar ',
#    'is ',
#    'i',
#    'de',
#    ' a',
#    'l goedgo',
#    'TIMEOUT'],
#   [' fhello',
#    'o',
#    'ke',
#    'eee',
#    'hoe',
#    ' w',
#    'il',
#    ' je',
#    ' een ra',
#    'st',
#    'e',
#    'r ',
#    ',akemakenwals je nou zegt waar je bent',
#    'ik snap je idee niet ',
#    'al',
#    's ',
#    'we nou elke rij een nummer gevendus we ',
#    'he',
#    'beginnen',
#    'ond',
#    'e',
#    'raan',
#    'oo',
#    'ooh',
#    'ja ',
#    'go',
#    'ed ide',
#    'du',
#    'ja maar als we nu de onderste rij als A zien en dan diegene daarboven als B en die daarboven a',
#    'l',
#    's ',
#    'C en da',
#    'n e',
#    'lk',
#    ' v',
#    'akje i',
#    's e',
#    'en',
#    'cijf',
#    'erik kan dat niet zien ja dus heeft geen zin',
#    'dus d',
#    'e ',
#    'on',
#    'derste rij is ',
#    'A3',
#    ' A2 en A1 maar dan andersomsorry ging mis',
#    'oooh fack echt',
#    'goo',
#    'oog',
#    'een',
#    ' f',
#    'la',
#    'u',
#    'w ',
#    'id',
#    'ee',
#    'ja',
#    ' b',
#    'ij m',
#    'ij',
#    ' ook',
#    'ooi ',
#    'ne',
#    'e wac',
#    'ht',
#    ' die rij daarboven heeft bij mij 4 vakjes',
#    'p',
#    'op',
#    'oo',
#    'ooh',
#    'en daarboven 4 vakjes maar dan wel met 1 lege',
#    'wat bedoel je daarmee',
#    'oo',
#    'ooohik heb',
#    ' 2 5 5 ',
#    '6 4 ',
#    '4 3',
#    'oke sorry kon niet lezen wat je zei',
#    'he',
#    'l',
#    'em',
#    'a',
#    'al',
#    ' on',
#    'der',
#    'in',
#    'ik kan daar niet komen',
#    'misschien moet je mi eeerst doenmijn ',
#    'grijz',
#    'e va',
#    'k',
#    'jes zij',
#    'n d',
#    'e t',
#    'weede roij, dan het een na laatste vakje',
#    'tw',
#    'eede rij van ',
#    'bove',
#    'mn',
#    'jezus wat is dit',
#    'neee dniet helemaal rechtsdegene ndaaroverdaarvoorhai ',
#    'okee',
#    ' w',
#    'e ',
#    'fucked u',
#    'p ',
#    'TIMEOUT'],
#   2383.082),
#  (['Zelfde idee?',
#    'wo',
#    'w ',
#    'oke',
#    ' a',
#    'n',
#    'de',
#    're',
#    ' vorm',
#    'hhahahah',
#    'mijn stip',
#    'je',
#    ' is he',
#    'le',
#    'maal ',
#    're',
#    'chts',
#    'ok',
#    'ja',
#    'd',
#    'us t',
#    'm G',
#    'van links naar ecrerech',
#    'tsjaa',
#    'll',
#    'een de citzichtbare of totaal?',
#    'ok',
#    'preciesik ga',
#    ' nu mijn',
#    ' s',
#    'tuopje t',
#    'el',
#    'l',
#    'en',
#    'ja',
#    'I',
#    'k ',
#    'hb',
#    'eg',
#    'in p',
#    'opEÊ6ben iken ik moet naar',
#    'F2',
#    'F2',
#    'C7 probeer dieAnder',
#    's A3',
#    'C7',
#    'ja!!!',
#    'IK be er!!BY hNU jij',
#    'geenf me coordinaat',
#    'ciirdu',
#    'ba',
#    'atcoo',
#    'rdinaatWelke FG?',
#    'ijokdat z',
#    'va',
#    'n ',
#    'm',
#    'ij is gesloten weermaaar kan nog naar mn odoelben je er?',
#    'ik ook!'],
#   ['hahahahah',
#    'o',
#    'ke',
#    'e ',
#    'mij',
#    'ne',
#    ' i',
#    's ',
#    'nu 1 vakje op de ondersteen dan 34 vak neeeee niet 34 hai waarom hebben we geen backspace',
#    'oke',
#    'e',
#    ' e',
#    've',
#    'n e',
#    'en',
#    'du',
#    'id',
#    'el',
#    'ijk ',
#    'id',
#    'ee ma',
#    'ken n',
#    'u',
#    'oke luister nuniet missen wat ik zeg',
#    'de bovenste rij is Adxe rij daaronder is Bde rij daaronder C snappie',
#    'en dan',
#    ' g',
#    'ee',
#    'f j',
#    'e de blokjes cijfers',
#    'va',
#    'n links naar ',
#    'r',
#    'echts cijfe',
#    'rs',
#    'allemaal ',
#    'a',
#    'nders kan je niet tellen',
#    'dus kolomm',
#    'en',
#    'zij',
#    'n ',
#    'cij',
#    'fers',
#    'rienrijen zijn letters',
#    'kolommen is van bovenaf toch? moet ik ',
#    'he',
#    't ',
#    'w',
#    'el ',
#    'go',
#    'ed ze',
#    'ggen',
#    'E6 ja',
#    ' h',
#    'eb hetnaar?',
#    'en waar zit jpuw switchdaar gaat het om',
#    'da',
#    'ar',
#    ' ka',
#    'n ik komen wacht',
#    'ik ben nu',
#    ' op ',
#    '7y essss',
#    'okeee mijn switch is helemaal links onderhet eerste vakje',
#    'Gsorry wat zei je',
#    'pa',
#    'p ',
#    'kawam bin',
#    'nen',
#    'G1',
#    'ja',
#    'aaaa',
#    'ik ben op mijn doel!',
#    'yesss gehaald'],
#   248.307),
#  (['hahhahaah yesOke zelfe idee',
#    'ga naarE6E6',
#    'Da',
#    'n ',
#    'mo',
#    'et',
#    ' jij',
#    'zeg maar',
#    'G3 danben erik heb maar ',
#    '1 g',
#    'rijs vlakoke topga jij nu naar ',
#    'E6',
#    'E6',
#    'yes!terug naar doel'],
#   ['jaaadit werktbegin jij',
#    'kan oik niet komen jij moe',
#    't eerst',
#    'd ',
#    'e',
#    'nk ikooooh wachtohneegrapje jij moet eerst',
#    'D6of G3',
#    'ye',
#    'ss',
#    'ss',
#    'oke',
#    'e be',
#    'n nu op mn doelohja sorrywaar heen?',
#    'ben er',
#    'yesss we rck ro'],
#   108.192),
#  (['da',
#    'aamn we Ik heb 2x grijs',
#    'B4B4',
#    'yes nuy  jij',
#    'ben er',
#    'okik kan nu niet meer dnaar mn doelkan jij nu naarE4?',
#    'yes terug nar doel nu'],
#   ['ck',
#    'ik ookjij eerst?',
#    'ben er',
#    'D2of F& F7',
#    'yes',
#    'ben er',
#    'd',
#    'it',
#    'is',
#    'le',
#    'uk'],
#   71.784),
#  (['Niceee',
#    'eA3',
#    'D5',
#    'ja',
#    'oke nu jij',
#    'yesk heb jo',
#    'u ',
#    'nodig om etr hier uit te komen',
#    'kan je op je doel?ik bzit nu vastA3?',
#    'nu naar doel'],
#   ['kan ik niet komenmijn ',
#    'gri',
#    'jze voooh wacht je hebt nog 1 D5?',
#    'ben er?',
#    'B7',
#    'to',
#    'p',
#    'wait',
#    'ik kan op mn doelja ben er',
#    'tooop'],
#   80.558),
#  (['yesB3',
#    'ok',
#    'ye',
#    's',
#    'yes',
#    'hahahha ikillen',
#    'ben ',
#    'a43oke top',
#    'kan je A3?',
#    'A3',
#    'B2',
#    'B3 s',
#    'or',
#    'ry',
#    'B#B',
#    '3',
#    'yes'],
#   ['even kijken hoornee jij moet eerst',
#    'A3nee ',
#    'so',
#    'rry A4',
#    'oh je zat wel op de goede',
#    'yes ',
#    'di',
#    't is ',
#    'goed',
#    'okee ben op mn doel jij?',
#    'a3 of a4?na ',
#    'a3 kot',
#    'm',
#    ' k',
#    'omt d',
#    'i',
#    'e ',
#    'po',
#    'ort',
#    'oo',
#    'oh ja dat wil'],
#   72.446),
#  (['C1?',
#    'ji moet sws eerst ik kan niks',
#    'C1',
#    'F7',
#    'joejoe',
#    'nu jij iet szeffe',
#    'ze',
#    'ggen',
#    'ik2',
#    'ki',
#    'e',
#    's er 1',
#    'ja',
#    'be',
#    'n ',
#    'b7',
#    'sorrynu kan niik niet meer bij mn doel dus jij moet nu weer ff',
#    'C1',
#    ' of',
#    'j',
#    'a topyes ben er'],
#   ['yess',
#    'wacht ff',
#    'wat zei je?',
#    'ja daar kom ik niet',
#    'daar wel denk ik momento',
#    'be er',
#    'hahahah zeffe ',
#    'oke ',
#    'focuseuuh ff tellen ik heb er 4',
#    'B&?',
#    'b7?of C1',
#    'of F5',
#    'oh ',
#    'ja ',
#    'top wait ff lp lopen poh nee ja goedzo',
#    ' G1 ',
#    'toe',
#    'vallig?',
#    ' oh ja dat kan ook C',
#    '1',
#    'topppp'],
#   135.343),
#  (['lekkeerrweziuwij zijn ecgt goedoke',
#    'F3?',
#    'B5',
#    'yes',
#    'yes oke',
#    'wat?',
#    'ja d5',
#    'ok',
#    'e n',
#    'u jij naar B5',
#    'F3',
#    'yes terug'],
#   ['hope weee ho spastisch oke ',
#    'jij',
#    ' be',
#    'gintnee lukt niet',
#    'b5 wel denk ik moment',
#    'ja ben er',
#    'euhhh ff tellenD5?if F4',
#    'D5 of F4',
#    'top ben er j',
#    'ij?',
#    'nog een andere? dan ko ik niet terugd enk ik',
#    'yesben er'],
#   110.305),
#  (['yessjij moet erst zeggen',
#    'D6',
#    'G7of',
#    'C3',
#    'UDan m',
#    'ie',
#    't',
#    'C3 of G8G7ander smoet jeerngesn anders heenander gedeelte zodat je er wel kan komen',
#    'ik hiu m nu oepoopendaarna maak jij voor mij open en dan ik weer voo',
#    'r jou',
#    'oke nu jij een zeggenik kan ibij m',
#    'inj',
#    'do',
#    'el',
#    'nog een ker?',
#    'oke dan moetik er uitOke aegrns anders heenehmkan jij naar G 7G& G7 en doel?of C3',
#    ' e',
#    'n doel',
#    'o',
#    'ke',
#    'zeg al jouwe',
#    'Mijn doel is A1 dus dat i',
#    's',
#    ' v',
#    'he',
#    'el',
#    ' ve',
#    'el',
#    ' u',
#    'it',
#    ' el',
#    'kaar',
#    'en je pporten?',
#    'G',
#    'jaohhh oke G3 wist ik niet',
#    'n',
#    'u ',
#    'ga',
#    'an',
#    'kan je nu naar je doe?ik we',
#    'l'],
#   ['werew so good',
#    'D6 pf G3 en G7',
#    'ja jij',
#    'nog een ',
#    'ander',
#    'e ja topoh wacht niet zo top',
#    'U ',
#    'hebben we niet hahahah',
#    'ja maar dan gaat mijn poort weer dicht',
#    'oke b',
#    'en nu C3',
#    'D',
#    '6 of',
#    ' G',
#    '3 of G7',
#    'D6 G3 G7',
#    'nee',
#    'allebei poort voor nodig ok were not so good any',
#    'm',
#    'or',
#    'e',
#    'D^G hgo ho D6 G3 G7',
#    'oooo',
#    'h',
#    ' s',
#    'orry dhe',
#    't ',
#    'doel',
#    ' mij n doel is C6',
#    'D',
#    '6 G3 G7 ja idd',
#    'ooh pro',
#    'be',
#    'er',
#    ' e',
#    'ens?ja en nu?',
#    'j'],
#   231.534),
#  (['Hahah goed ztellendan gaat het goedoke jij eerst zeg',
#    'gen',
#    'yes',
#    'oh',
#    'oke jij',
#    'D2',
#    'F5',
#    'k',
#    'ut',
#    'ik heb D2of F5',
#    'hahah ku',
#    'tt',
#    't',
#    'ma',
#    'ar',
#    ' h',
#    'oe',
#    'dan',
#    'ga jij nu weg adaarnaar E2',
#    'fjadoe ff deodie',
#    'ok',
#    'e ',
#    'n',
#    'u ',
#    'k',
#    'an ',
#    'j',
#    'e ',
#    'er uit',
#    'gaaeja geef ',
#    'mij ',
#    'nu e',
#    'en ',
#    'an',
#    'dere',
#    'nu kan ik bij een andere van hjjou wss',
#    'ja F5kan je ny tergug',
#    'ik kan',
#    'naar ',
#    'do',
#    'el',
#    'tip'],
#   ['aaoooh top ging ff moeilijk wff terugvall',
#    'D',
#    ' ho foutje E1 of F4 n',
#    'ee',
#    ' F5 tup t',
#    ' oja dit is goed',
#    'be',
#    'n',
#    ' op doelnog een andere?',
#    'zit ook een pport voor',
#    'dan moet jij eerst denk ik?',
#    'oh ja nee dat lukt dfus niet',
#    ' h',
#    'uuuh',
#    ' g',
#    'a ',
#    'j',
#    'ij weer eens?',
#    'E2?',
#    'nu',
#    ' zi',
#    't ',
#    'ik',
#    ' opges',
#    'lo',
#    'ten',
#    'ik',
#    ' zit opge',
#    'sloten i',
#    'n mn hokje',
#    'OOh nopu F5 dus of E1F5 E1',
#    'jaa',
#    'ik ben',
#    ' d',
#    'oel '],
#   156.321),
#  (['HalloHell',
#    'o',
#    ':)0)',
#    'o',
#    'nd',
#    'ers',
#    'te vakjemeest onderste is bij mij grijs',
#    'meestbo',
#    've',
#    'nin',
#    ' r',
#    'e',
#    'cht',
#    's ',
#    'heb ik ook een grijs vakjemmaamaar ik sta er nu inis je gate open?',
#    'je moet o',
#    'je m',
#    'o',
#    'et ',
#    'op een grijs akdvgfakje van mi jstaannik heb er een boven in rechtsen hel',
#    'em',
#    'a',
#    'al ',
#    'o',
#    'nd',
#    'era',
#    'an',
#    'ja mijn gates zijn nog dicht',
#    'onderaan lqaagste rijen ',
#    'twe',
#    'ed',
#    'e r',
#    'u',
#    'hj',
#    ' v',
#    'an bov',
#    'en rechtswaar is je tweede grijze',
#    'ja',
#    'sta ik nu op',
#    'en nu',
#    'kan je naar die onderste'],
#   ['h',
#    'ello',
#    'bij',
#    ' mij',
#    'n ',
#    'daar kan ik niet komen dan ,',
#    'oe',
#    't ',
#    'ji',
#    'j eerst naar het bovenste vakjedan drechts',
#    'bov',
#    'en',
#    'aan ',
#    'rech',
#    'ts',
#    'neneneeik sta oop een grijs vakje',
#    'ik sta nu op een grijs v',
#    'ak',
#    'je',
#    'da',
#    'ar',
#    ' s',
#    'ta',
#    'ik nubovenste rijrechts',
#    'oke ander vakje danwaar jiwaar he b jij nog meer grijs',
#    'da',
#    'ar',
#    ' k',
#    'an',
#    'ik ni',
#    'e',
#    't ',
#    'ko',
#    'men',
#    'oke vanaf onderde 4e rijdaar zijn 4 vakjes naast elkaar toch',
#    'dan de 3e',
#    'gebeurt weer niks',
#    'jaa topoke nu moet ik naar een grijs vakje',
#    'jaachill'],
#   271.983),
#  (['nice',
#    'bij mij derde van boven meest linkse rij',
#    'yeswacht hij ging te snel dicht',
#    'jagelukt'],
#   ['oke bovenaanis bij mijj grijsbovensta vakje', 'deze?', 'moe t ik terug'],
#   61.504),
#  (['ds',
#    'a',
#    'ad',
#    'aar',
#    'kan ik niet heen',
#    'daar wel',
#    'sta ik nu opik heb 55ho4de van boven',
#    't',
#    'weede vakje',
#    'gebeurt nog niks',
#    '45vierde rij van boventweede vakj',
#    'e',
#    'yesswacht even',
#    'oke',
#    'ben ',
#    'er',
#    'gi',
#    'k ',
#    'heb',
#    'ook een gfrijze bij tweede rij van onder',
#    'me',
#    'e',
#    'st',
#    'rechtse',
#    'nee',
#    'gkan jij naar tweede rij van onder meest rechtse',
#    'oke tyop wachtben nu op de kruis',
#    'huh maar dan ',
#    'waar heb je je twede grijze',
#    'j',
#    'neeiddwaar is je tweede tgrijze',
#    'ja',
#    'yesals het goed is kan je nu terug naar kruios',
#    'top'],
#   ['toppieokederde rij van onderzi',
#    'jn',
#    '2boj',
#    'of tweede rij van boven?',
#    'dan linkse blokje',
#    'wat',
#    '?',
#    'deze?',
#    'kan je nog een keer uitleggen',
#    'd',
#    'eze?',
#    'janu is die van mijnn weer dichtmoet anders',
#    'kan jij nu naar de biboven',
#    'd',
#    'an',
#    ' tweede an ',
#    'bo',
#    've',
#    'n',
#    'deze ga',
#    'at ',
#    'g',
#    'oe',
#    'd',
#    'kan jij nu naar de goal?',
#    'dus ik moet terug naa r een grijze?',
#    'jajsta ik in',
#    'kan je nu naar vtweede van bovenen dan links',
#    'ik zit nu weer vast namelijk',
#    'jaa zo is goedsta nu op kriuismaar nu kan ',
#    'jij zeker weer niet',
#    'oke ik ga terug naar dia tweede rij van onderkan jij dan naar derde rij van onder',
#    'linksrevhttrechts sorry',
#    'jaa sta ik u'],
#   234.356),
#  (['st',
#    'a ',
#    'i',
#    'k nik kan maar nar twee vakjeszit gelijk geblokt rechjtsboven in',
#    'tweede rij van onder rechts',
#    'oke, meeste linkse derde rij van oinder',
#    'ja nu kan ik er door',
#    'nu?zo?',
#    'oke je moet denk ik naar mijn tweexe grijze',
#    'kan je naar tweede van onder en dann de rechhtse',
#    'jaa wachtben op kruis'],
#   ['topik heb een grijs blokje op tweede van onder rev',
#    'c',
#    'ht',
#    's',
#    'oke waar is grijs',
#    'kan ik niet heen',
#    'nu?',
#    'oke dan 4e rij van ondertweede van links',
#    'jaik sta op kruis',
#    'waar',
#    'zo?',
#    'top'],
#   124.927),
#  (['hihi',
#    'i',
#    's ge',
#    'bl',
#    'o',
#    'kt ',
#    'mij ',
#    'd',
#    'erde rij derde blokje van links',
#    'derde rij vna onder',
#    'd',
#    'eeh okebovenstre rij derde blokje',
#    'jaaals het goed is het bij jou ook open nu',
#    'oke kan je nu naar derde rij vasn onder derde van lkinks',
#    'jaaben bij kr',
#    'uis'],
#   ['oke onderste rehcrehr',
#    'ecjts',
#    'waar heb jij grij',
#    's',
#    'zo?',
#    'kan i',
#    'k niet heenandere?',
#    'zo?',
#    'ja',
#    'zo?',
#    'kr',
#    'ui'],
#   91.753),
#  (['is bij mij ook grijsen adfgelosslotenben ju bij kruis lkol',
#    'waar heb je nog ',
#    'me',
#    'er',
#    ' g',
#    'ri',
#    'js',
#    'oke wacht kan je voor mij gates open doen',
#    'meest onderste rijde lmeeste linkse en rechtse zijn bij mij grijs',
#    'zpwe; zowel links als rechts onder iniet?',
#    'oke ze zij  nu openwaar moest ik heen?',
#    'zo?',
#    'nee',
#    'ja'],
#   ['sonderste rij rechts',
#    'de',
#    'derde ',
#    'rij van boven3e van links',
#    'welke?',
#    'kan ikniet heen',
#    'ik sta nu rects',
#    'van boven 3e rijen dan derde links',
#    'kan jij kruis',
#    'nu wel?',
#    'sta je kruis?'],
#   144.544),
#  (['ja',
#    'kan ik niet heen',
#    'twee van boven tweede van rechts',
#    'vierde van boventweede van rechts',
#    'oke w',
#    'a',
#    'r ',
#    'i',
#    's jouw ',
#    'nzoi?zo?',
#    'of tweede van rechts tweede',
#    'o',
#    'f ',
#    'jaa zij nu open',
#    'ik sta nu op onderste rijezsorry vtweede van onderzit ',
#    'e',
#    'en',
#    'tweede van ondr helemaal r',
#    'ec',
#    'hts ',
#    'sta ',
#    'i',
#    'k ',
#    'nu'],
#   ['onderste middelste',
#    'waargrijs?',
#    'kan ik niet heenandere',
#    'kan ook nietkan ',
#    'j',
#    'ij ',
#    't',
#    'weede va',
#    'n bovenlinks',
#    'ja topwaar moet ik heen nu',
#    'zo?',
#    'nu moet ik nog wergens langswaar sta jij nu',
#    'hel',
#    'em',
#    'aal rehts',
#    'ik s',
#    'ta',
#    ' nu ',
#    'kr',
#    'uis'],
#   127.124),
#  (['nice',
#    'is geblokt',
#    'bovenstre rij meest linkjse',
#    'jawaar moest ik heen',
#    'die is bij oomij ook grijs haha',
#    'nee',
#    'kj',
#    'r',
#    'kruis zit meest onderste bij mij',
#    'vierde van onder meest l',
#    'in',
#    'ksjasta nu op kruis',
#    'ja',
#    'ja bij mij is het gebloktkan je naar waar is je rkuis',
#    'ja kan je naar tweede van boven rechts ',
#    'twede van boven derde blokje*',
#    'jaik sta nu o'],
#   ['okevierde van onder links',
#    'ik kan alleen vovnste rijsbovenste rij',
#    'zo?',
#    'vierde van onderja top',
#    'kan je bij kruis nu?',
#    'wa',
#    'ar',
#    '?',
#    'waar grijs?',
#    'zo?',
#    'nnu kan ik niet bijkan je ook vierde van onder links komen',
#    'nu ben ik kruis',
#    'derde vanbovenlinks',
#    'ja',
#    'zo?'],
#   146.474),
#  (['ni',
#    'ce',
#    'o',
#    'bewelke rij',
#    'alleen 1x helemaal links onder',
#    'jastas op rkusilekker'],
#   ['joe', 'boevnst', 'e rechts?k', 'waar heb jij grijs?', 'zo?'],
#   48.857),
#  (['rrk',
#    'an',
#    ' i',
#    'k niet heen',
#    'ondersrte rechtsen vierde van boven rechtssta ',
#    'op',
#    'o ',
#    'kr',
#    'uis',
#    'ja',
#    'yes'],
#   ['sn',
#    'elderde rij van onder tweede van lirechstweede van re',
#    'ch',
#    'ts',
#    'waar heb ij grijs?',
#    'ik ts',
#    'a nukan jij nu derde rij van onder',
#    '5e blokje',
#    'ik sta nu kruis'],
#   40.834),
#  (['aha', '1', ',1', '1,1', 'jij', '?', '@7,5'],
#   ['kun je naaar r jou kruis?((NEWLINE))nice((NEWLINE))zie nchat nieta',
#    'dammndi',
#    'd',
#    'ff',
#    '7',
#    ',5',
#    '3,7',
#    'ok ga naar kruis'],
#   40.203),
#  (['@kruis',
#    'nope1,1',
#    '1,35,21,11,ok1,3',
#    '5,',
#    '2j',
#    'ij',
#    ' m',
#    'oet mij eerst vrijlaten',
#    '1,21,.....1,2...1,31,3',
#    '5,2',
#    'ja5,3?welke?',
#    '@5,2',
#    '@2,4',
#    'ka',
#    'n ',
#    'nie',
#    't ',
#    'na',
#    'a',
#    'r ',
#    'kr',
#    'ui',
#    's',
#    '1,3',
#    '5',
#    ',2',
#    '@kr',
#    'uis',
#    'priem'],
#   ['heb je bijgehouden hoeveel we nog moeten?',
#    'oke',
#    '5,',
#    '2',
#    '2,4welk',
#    'e ',
#    'had',
#    'okewelke had je',
#    'o',
#    'pe',
#    'n?',
#    '5,2\t\t\t\t\t\t\t\t',
#    '42,2,542,4 en 5,2zo',
#    'kom je',
#    ' b',
#    'ij',
#    ' jo',
#    'uw',
#    ' krui',
#    'saitwelke had je',
#    'en',
#    '?@kr',
#    'uis',
#    '?ait'],
#   149.69),
#  (['oke lets gokan jij op',
#    ' j',
#    'e ',
#    'wssiwiswitch gaan staan?',
#    'linksbovenkan je operopgaan staan?dan kjik ik of t werkt',
#    'o',
#    'oo',
#    'g',
#    'oohg',
#    'oed',
#    ' da',
#    't ',
#    'je',
#    't ',
#    'zegt',
#    'dan g',
#    'a ',
#    'ik',
#    ' e',
#    'er',
#    'st',
#    'werkt ie?',
#    'ik ',
#    'st',
#    'a op m',
#    'n ',
#    'grij',
#    'ze',
#    ' vak nu',
#    'do',
#    'e ',
#    'ik',
#    'doet je switch t nu',
#    'huhhahahaik sta aecht al lang op  t grijze vak',
#    'hij is links maar ik heb maar 1 grjis vak',
#    'jij ook?o',
#    ' j',
#    'a ',
#    'om',
#    'gh',
#    'ah',
#    'ahahah fuv',
#    'co',
#    'k',
#    'ik',
#    ' s',
#    'ta',
#    'nu bovenooh maar ik kan niet naar rechts ',
#    'ond',
#    'er',
#    'door',
#    ' d',
#    'e ',
#    'gat',
#    'e',
#    'kan jij naar boven',
#    'shitik heb geen rechts obovenalle',
#    'en',
#    ' ma',
#    'ar',
#    ' l',
#    'in',
#    'ks ',
#    'b',
#    'ove',
#    'n',
#    'ok',
#    'e m',
#    'is',
#    'sc',
#    'hien moet en we gewoon ff random uitproberenik ',
#    'st',
#    'a ',
#    'n',
#    'u ',
#    'vo',
#    'or m',
#    'ij',
#    'n ',
#    'g',
#    'at',
#    'e',
#    'dit ',
#    'is t ',
#    'mee',
#    'st',
#    ' rechts wat ',
#    'ik kan',
#    'nu ben ik helelmaal links boven',
#    'oke uhm mijn grijze vak zit 2 blokjes naar benedenvanaf ',
#    'li',
#    'nk',
#    's obovendus naar linksvojaaaa',
#    'aaa',
#    'omggggheb',
#    'be'],
#   ['my ',
#    'is goedwaar is jouw grijze stuk?',
#    'okemaar dat gaat niet want ik heb een gate v',
#    'oo',
#    'r d',
#    'vo',
#    'or',
#    'da',
#    't ik naa',
#    'r ',
#    're',
#    'ch',
#    'tsbove',
#    'n ga',
#    'kun jij an',
#    'ders op mi',
#    'j  ',
#    'grijz',
#    'e ',
#    'stuk ',
#    'staan',
#    'di',
#    'e ',
#    'is rechtsondermaar niet de meest rechts',
#    'nee',
#    'waarwant deze is rechtsonder maar niet de meest rechtse',
#    'je',
#    ' moet ',
#    'ni',
#    'et op je eigen grijze vak gaan staan m',
#    'aar ',
#    'op',
#    ' d',
#    'ie',
#    ' van m',
#    'ij',
#    'hahah',
#    'd',
#    'us rec',
#    'ht',
#    'son',
#    'der',
#    'h',
#    'ah',
#    'a',
#    'ha',
#    ' hoe gaa',
#    'n ',
#    'we dit ',
#    'dpe\\doen',
#    'ik zit nu rechtsoboven',
#    'jaa ik oo',
#    'k ',
#    'ni',
#    'e',
#    't echtmaar het meest rechtsboven wat kanhahah dat gaat onsnooit',
#    ' u',
#    'kke',
#    'nkun jij ',
#    'na',
#    'a',
#    'r ',
#    'r',
#    'ec',
#    'h',
#    'tsonder',
#    'odf he',
#    'helemaal naar linksboven?',
#    'okee ik sta op mn kruis',
#    'g',
#    'oed',
#    '?',
#    'is ',
#    'jo',
#    'uw gate nu open??',
#    'ha'],
#   263.321),
#  (['s',
#    'okee hmmm',
#    'oke hmm',
#    'we',
#    'rk',
#    't ',
#    'd',
#    'it',
#    '?kun j',
#    'e ',
#    'her',
#    'halen? sorry',
#    'jai',
#    'k d',
#    'en',
#    'k dat',
#    ' dbij mij daar een gate voor zit',
#    'er is toch een lange verticale streep in het midden?',
#    'ik ben 3e van boven',
#    'ooo okehmmm',
#    'die lange verticale3r 3e van boenboven',
#    'nee daaar zit een hek tus',
#    'sen',
#    'o nee ',
#    'wa',
#    'ch',
#    'tji',
#    'j moet ',
#    'hele',
#    'ma',
#    'al',
#    ' n',
#    'aar links',
#    'v',
#    'an die 4',
#    'ja het werkttop',
#    'wer',
#    'kt',
#    ' t',
#    'top! voor mij moet nog 1 x een hek opendan b',
#    'en',
#    ' i',
#    'k',
#    ' erwaar sta je?',
#    'oke als t kandan moet je1 naar links1 naar boveneen naar rdrechts',
#    'oke kan je dan1 naar rechts 2 omhoog?',
#    'shiiiiiiiiiiiiiit',
#    'uhhh',
#    'ik snap wniet lolverticale rij?',
#    'TIMEOUT'],
#   ['h',
#    'ahahanet geluktecht ',
#    'mijn grijze vak is nu in het kmidden',
#    'dus je hebt die hele lange ',
#    'rij ',
#    'van',
#    ' boven naar ',
#    'ondermaar dan met jedde rij er links ',
#    'v',
#    'an',
#    ' he',
#    'bb',
#    'en',
#    'je hebt de langste verticale rijde r',
#    'i',
#    'j daar links van moet je hebbenen dan van bedbendenhoobeneden naar boven moet je de tweede hebbensna',
#    'p ',
#    'je',
#    '?',
#    'ohwaar zit jouw grijze vak?',
#    'jaa',
#    'ik kan niet uit mijn ijrij ik zit vast in de horizaontale rij helemaal rechtsobovennbij die 4 vakjes',
#    'waae zit jij',
#    'kun jij 1 naar links en 1 naar onder',
#    'o',
#    'p een andere manier?want ik denk dat we bij jou moeten beginen',
#    'aa',
#    'n',
#    'ge',
#    'z',
#    'ien ik',
#    ' wva',
#    'st',
#    'zi',
#    't',
#    'oh oke',
#    'e',
#    'doe ik nu',
#    'top kun jij ',
#    'nu n',
#    'aar ',
#    'ik sta op mijn kruis',
#    'welke',
#    'uhhm inndin de tweede rij van links en dan de tweede van boven naar onder',
#    'dat kan niet',
#    'nee',
#    'ik',
#    'sta in de 3e rij van boven naar bendenbenedenen dan het meest links',
#    'hojaa',
#    'TIMEOUT'],
#   302.777),
#  (['kuuuuutjammer dit haha',
#    'hok ',
#    'ik st',
#    'a',
#    ' h',
#    'el',
#    'em',
#    'aa',
#    'l ',
#    'o top',
#    'ik ',
#    'sta',
#    'he',
#    'le',
#    'ma',
#    'a',
#    'l ',
#    'r',
#    'ec',
#    'hts boven indat allerhoogste vak rechts',
#    'eentje helemaal links onder',
#    'ja!',
#    'oh ',
#    'ok',
#    'ii',
#    'in',
#    'jawel2e rij ',
#    'van',
#    ' l',
#    'inksw',
#    'el',
#    'ke ho',
#    'og',
#    'te',
#    'eokezo?',
#    'oke shit nu ka',
#    'n i',
#    'k n',
#    'ie',
#    't m',
#    'ee',
#    'r ',
#    'na',
#    'ar',
#    ' m',
#    'n',
#    ' rk',
#    'ruis ',
#    'h',
#    'aha',
#    'h',
#    'jaaje hebt t allerlaagste vakjeen en daarboven t2',
#    'toch?dan is ',
#    't',
#    ' d',
#    'e ',
#    'rech',
#    'ternee',
#    'd',
#    'e allerlaagste en daar zitten er 2 bovenhet is de rechter van die 2',
#    'nee shitte',
#    'ie',
#    'ja ik snap niet',
#    'jaaaaaa',
#    'kan jij n',
#    'u ',
#    'ook teru',
#    'g naar je kruis?ik sta',
#    'ja'],
#   ['haha',
#    'haokeee ik ',
#    'k',
#    'an i',
#    'n 1keer ',
#    'bij mijn kruis',
#    'dus ze',
#    'g',
#    ' maar ',
#    'wat',
#    ' ik m',
#    'oe',
#    't',
#    ' do',
#    'en',
#    'waar is jowjouw grijze vak',
#    'sta ik erop?',
#    'okeee ik moet toch door een dgate zag het verkeerdk',
#    'kun j',
#    'ij ',
#    'in ein de tweede rij van links naar rechtsgaan',
#    ' s',
#    'taan ',
#    'en',
#    ' d',
#    'an ',
#    'de',
#    '1 na onder',
#    'ste',
#    'ja',
#    'i',
#    'k ',
#    'ka',
#    'n op mn hk',
#    'ru',
#    'i',
#    'sohheb je een ander grijs vak',
#    'oke',
#    'g',
#    'oe',
#    'd ',
#    'zo',
#    '?',
#    'okee',
#    'goed?',
#    'hahah',
#    'dan hebben we misschien een andere maze',
#    'wacht werkt het zo',
#    'okeee ro',
#    't',
#    'op',
#    'jaa'],
#   213.329),
#  (['a',
#    'aaaaa',
#    'oke i moet maar door 1 gate',
#    'een van mijn grijze vakken is dat allerlaastallerlaagste vak',
#    'e',
#    'hel',
#    'em',
#    'aa',
#    'l',
#    ' b',
#    'e',
#    'nedenokedan het allerrechtse vakjedie bo',
#    've',
#    'n',
#    'in',
#    'ja',
#    'ok',
#    'e ',
#    'da',
#    'n j',
#    'i j eerst',
#    'yesss',
#    'k',
#    'an',
#    ' i',
#    'k ',
#    'o',
#    'ok',
#    ' niet heenheb j',
#    'e ',
#    'een ande',
#    're',
#    '?',
#    'zo?',
#    'rechts naar links de 3e zei je?',
#    'en dan de 2e van boven',
#    'hmm daar sta ik vgm op? jkut',
#    'doet i het?',
#    'zo!o',
#    'f ',
#    'nog nietsiht hahah',
#    'zo',
#    ' d',
#    'an',
#    'zo?',
#    'zo dan',
#    'hahahah ooo nu snap ik ojoutop',
#    'kan je naar het aller ondersta',
#    ' vakoke plsdat is mijn gate',
#    'jaewacht',
#    ' hhshshkut te sne',
#    'l',
#    'ben op kruis!!'],
#   ['yea',
#    'hahaha',
#    'topwat kan ik doen',
#    'ka',
#    'n ik m',
#    'n',
#    'ie',
#    't b',
#    'ij',
#    'da',
#    'ar',
#    'boven?kan i',
#    'k ook niet bi',
#    'j ',
#    'oke',
#    'e m',
#    'ijn ',
#    'gr',
#    'ij',
#    'ze v',
#    'akje is ',
#    'linksboven d',
#    'at ui',
#    'st',
#    'oju',
#    'hhm ',
#    'kun je wel naar uhhm wachtvan reavan rechts naar links de derde trijen dan van boven naar beneden de tweede',
#    'er gebeurt noh niets',
#    'jaa',
#    'jaa',
#    'wacht ik ga het anders uitleggenvan boven naar beneden de 4e rijen van dda van rechts naar links de 3e rij',
#    'nee',
#    'ne',
#    'e',
#    '4e',
#    ' re',
#    'rij van boevn naar bendednen dan van links naar rechts de 5e rij',
#    'hahahah jezus nee',
#    'jaa',
#    'ik sta eropdat kruiswat kan ik doen?',
#    'ja',
#    'werkt het',
#    't',
#    'haha',
#    'hahaha',
#    'ik ook'],
#   259.015),
#  (['yessss',
#    'ja!',
#    'z',
#    'o?',
#    'ik heb maar 1 grijs vakde allerlaagstekan je daar heen',
#    'niceeik ben op mn rkuis'],
#   ['kun jij naar het meest rechter vakje', 'to', 'p', 'jaa', 'dsta erierop'],
#   47.161),
#  (['zo?',
#    'die ene die uitsteekt?',
#    'o ',
#    'ne',
#    'e',
#    ' hela',
#    'as',
#    'daar ise',
#    ' een gate',
#    'zo?',
#    'top',
#    'mijn gate is nog 1 hokje naar rechtsvan die plek',
#    'ja!bne op mn kruisy'],
#   ['ik ookkun je naar het vaakje rechtsonder',
#    'nee',
#    'needie hvan de onderste rijen d',
#    'a',
#    'n ',
#    're',
#    'chts',
#    'oj',
#    'kun je naar de meest linkeren dan 1 naar rechts',
#    'jaa',
#    'okee ',
#    'zo?',
#    'ye',
#    'ah'],
#   74.735),
#  (['esss',
#    'ooh inee daar kan ik niet komen',
#    'di',
#    'e ',
#    'b',
#    'zo?',
#    'ik heb er een helemaal rechts boven ine da',
#    'n ',
#    '1 n',
#    'aar ',
#    'onder',
#    'top',
#    'ben',
#    ' e',
#    'r!',
#    'ja hoor',
#    'ik',
#    ' k',
#    'an',
#    ' n',
#    'u l',
#    'inks',
#    'deze?',
#    'top!!'],
#   ['h',
#    'mijn grijze vak is nu rechooolinksboven en dan 1 naar onderkun je daarbij',
#    'ofmee',
#    'st ',
#    'rechter rijen dan helemaal onder',
#    'jaawacht ga eens terugof nee trouwens vertel nmaar waar jouw grijze vak is',
#    'o',
#    'h t',
#    'op',
#    'daar sta ik',
#    'ku',
#    'n ji',
#    'j nu',
#    ' nog een ankant op¿',
#    'wa',
#    'nt i',
#    'k ',
#    'm',
#    'oet er nog in',
#    'jaaik sta er'],
#   132.206),
#  (['zo?',
#    'grijze vakje is 2e rij van bovenen dan 2e van rechtskan je daarbij?',
#    'ja het werkt',
#    'k',
#    'an bij m',
#    'n k',
#    'ruis',
#    'ja!',
#    'hier?',
#    'top'],
#   ['hahahokee kun je naar de twedde rij van boven naar benedenen dan helemaal links?',
#    'jaaokee waar staat jouw ding',
#    'jaa nu wel',
#    'okee hahah',
#    ' fu',
#    'ck',
#    'ik moet nog iets doenkun jij naar onderen?',
#    'en dat uitstulpseltje rechts',
#    'jaa'],
#   75.591),
#  (['zo?',
#    'm',
#    'ij',
#    'ne is 2 naar onderen vanaf daar',
#    'ja!',
#    'zo?',
#    'per',
#    'ff',
#    'ffff',
#    'wiheoeee'],
#   ['ik sta op mn kruismijn grijze vak is nu de 3e rij va rechts naar linksen dan de 1 na bovenste',
#    'jaa',
#    'ok',
#    'ee',
#    'zo?',
#    'haha okee ik heb nog een grijs vak 2e rij van onderenen dan de middeslte',
#    'jaalukt',
#    'ik',
#    's ',
#    'iks staerop'],
#   52.105),
#  (['vgm kan ik daar niet bij',
#    'rij helemaal rechtsen dan middelste vd 3',
#    'uhhverticale rij rechtsmet ',
#    '3v',
#    'ak',
#    'jes',
#    'o h',
#    'oho',
#    'h',
#    'ohnee wacht iksnap wat jij beodled1 naar linkse n 1 naar boven vanaf daardus eig 2e rijsorry',
#    '2e ',
#    'ri',
#    'j e',
#    'n ',
#    'da',
#    'n ',
#    'm',
#    'id',
#    'denste',
#    '2e rij vaooooohheb je bovenin nog een ander grijs ',
#    'v',
#    'ak',
#    'je',
#    '?want ik kan niet naar ondern',
#    'nee er is een gtaet',
#    '2e rij van rechtsde middelste van die 3',
#    'shittie',
#    'oke ik ga nu even helaamaal bovenin staanen dan helemaal in dat links d',
#    'i',
#    'ng ok',
#    '?',
#    'ja',
#    'ja',
#    'ja',
#    'neee kut',
#    'ik',
#    ' k',
#    'an ',
#    'm',
#    'aar 1 naar onderen dan is er gaatezit jij daar ook dan?d',
#    'a',
#    'ar booke zelde ',
#    'do',
#    'ne',
#    'wil',
#    'ji',
#    'j daar ook gaan staan?',
#    'helemaal boven links',
#    'da',
#    'n l',
#    'e',
#    'g ',
#    'i',
#    'k t nuit kuuut hahahwaar ',
#    'ku',
#    'n',
#    ' je',
#    'we',
#    'l',
#    'nee hahaha',
#    'nee shit nu snap ik er niks meer van',
#    ' h',
#    'ah',
#    'ah',
#    'ja helaasssmiss uhmmmjij jij kan niet naar boebov',
#    'e',
#    'n heecht kutto',
#    't ',
#    'we',
#    'klwelke wel?',
#    'LAAAT',
#    ' MAAR KUT D',
#    'IN',
#    'G',
#    'TIMEOUT'],
#   ['hahahah ik kan echt niet zo snel typenkee mijn grijze vak is nu de 2e rij van rehtshelemaal onder',
#    'waar staat die van ojou',
#    'ik snap het niet',
#    'dat',
#    'is',
#    ' m',
#    'ijn mij een uisttulpsel aa',
#    'n',
#    'ee',
#    'e ',
#    'ik',
#    ' kan',
#    ' daar niet ',
#    'bij',
#    'ne',
#    'e h',
#    'ahah',
#    'kun jij niet van onderen de 3e rij',
#    'okee leg m nog eens uit',
#    'lukt echt niet',
#    'hahaha khoe kan dta nou',
#    'oke',
#    'ee',
#    'ku',
#    ' je van uit daar 1 naar rechts',
#    'dan 2 naar onder',
#    '1 naar links',
#    '2 naar onder',
#    'gdo',
#    've',
#    'rj',
#    'aa',
#    'ik ',
#    'zit ',
#    'nu ',
#    'wat?',
#    'kan ',
#    'ik',
#    ' n',
#    'ie',
#    't',
#    'I ',
#    'ka',
#    'n we',
#    'l als je dat gat oversltaat die daarondersnap je?',
#    'in de zeldfde verticlae rijen dan 1 naar onder',
#    'denk ',
#    'dat we t maar moeten laten gaan hahahaha',
#    'n',
#    'ee',
#    'h',
#    'aha',
#    'hah',
#    'ah',
#    'ik zitokee l',
#    'a',
#    'at',
#    ' m',
#    'aa',
#    'rha',
#    'TIMEOUT'],
#   287.66),
#  (['oke',
#    '5,4 en ',
#    'zo go',
#    'ed is mijn genheugen niet :(5,4 en 4,6 dnke ikheb je nog ',
#    'iets gezegd want ik staarde naar de puzzle',
#    '5,2 kan ik misschien',
#    'ja',
#    'uh',
#    '5,4',
#    '5,4 en 4,6',
#    'hajawaar h',
#    'e',
#    'en of kan je er al bij',
#    'waar dan',
#    'huh',
#    'o',
#    'ke',
#    'oh ',
#    'to'],
#   ['top ((NEWLINE))',
#    '2 vakjes',
#    'en',
#    '?3',
#    '3,65,2',
#    'letsgo',
#    'welke had jij ookalweer',
#    '5,6',
#    '?',
#    'kan je nu lopen',
#    'o',
#    'ke',
#    'nee:(',
#    'nu wel',
#    'je st',
#    'o',
#    'nd perongelu'],
#   150.052),
#  (['p',
#    'ik k',
#    'an ',
#    'ne',
#    'rgens heenzit op 7,1',
#    'ik zit daarzal ff kijken waar die switches zijn1,5en',
#    '6,6dat is 1,5 en 56,66,6*jawaar wil je me hebben staan',
#    'dan zit ik weer opgesloten zokan nu niet weg',
#    '1,5 en 56,66,6',
#    'oh sorry 5,6',
#    ':',
#    "'9",
#    ')(',
#    'waar moet ik heen ',
#    'oh top'],
#   ['k op',
#    ' nb switch',
#    '2,4',
#    'ait',
#    'tadaa',
#    '5,65,6',
#    'okewaar was hje punt',
#    '6,6 bestaat bueniet',
#    '>:(i',
#    'k kan n',
#    'er ',
#    'nu bij',
#    'ikkanvbij het kruis'],
#   131.152),
#  (['OkeOke ',
#    'w',
#    'aa',
#    'r ',
#    's',
#    'ta je',
#    'om',
#    'g ',
#    'wat i',
#    'srritant',
#    'ok',
#    'e ',
#    'w ',
#    'e pr',
#    'aten',
#    ' allee',
#    'n als het nodig isik sta ',
#    'h',
#    'elema',
#    'al',
#    'bovenrechts',
#    'wa',
#    'a',
#    'nit ',
#    'et',
#    ' ba',
#    'n',
#    'ie',
#    't ',
#    'ba',
#    'ck',
#    'spac',
#    'e',
#    'waar is jouw grijs',
#    'daar kan ik nog niet komen, eerst mi',
#    'jn',
#    ' g',
#    'rij',
#    's',
#    'mijn grijs is de 3e rij van onder helemaal linkskan je daar kmen',
#    'no g niet3e ',
#    'ri',
#    'j v',
#    'an onder linksjawaar is jouwik ',
#    'ja',
#    'open?',
#    'nu?',
#    'oke wacht, ',
#    'ik',
#    'be',
#    ' n',
#    'ikje moet nog  1 keer grijs doen voor mjij',
#    'ka',
#    'n',
#    ' dat?nog 1 keer grijs doen voor mijwat je zonet ook deed',
#    'waar sta je nu',
#    'maak ',
#    'te',
#    'ge',
#    'lijker',
#    'tijdik jouw hek is openmaak mijne nu openja',
#    'sne',
#    'l',
#    '!!',
#    '!!!snel!!!!!!gr',
#    'kr',
#    'ui',
#    's',
#    '!!',
#    '!!',
#    's',
#    'nel',
#    '!',
#    '!!',
#    'we m',
#    'oet',
#    'en tegelikjkertijd werkendoe nog 1 keer grijs opendis hek popen?je moet terug',
#    'ja wachtmijne open makenhet moet tegelijkeritjdnukruis',
#    'ik heb hem open gemaakt?',
#    'maamijne ooknukan je nog een x openmklukt het/',
#    'TIMEOUT'],
#   ['jnokee',
#    'je zi',
#    'et ',
#    'he',
#    't ',
#    'heel langza',
#    'am v',
#    'er',
#    'va',
#    'gen',
#    'zis',
#    'ho',
#    'e ',
#    'ir',
#    'ritantw',
#    'ik',
#    ' sta',
#    'oke ',
#    'i',
#    'k sta hekeahelmaal ',
#    'links ',
#    'i',
#    'n de derde ri',
#    'j van b',
#    'oven',
#    'vierde rij van boven tweede vakje van links',
#    'waa',
#    'r ',
#    'i',
#    's jouw grijs',
#    'open?',
#    'nu?',
#    'vierde rij van odertweede vakje',
#    'van links',
#    'nog niet',
#    'ja',
#    'kun',
#    ' j',
#    'e ',
#    'k',
#    'ruis',
#    'wa',
#    'ar',
#    'dan moet ik ookhet hekje weer open',
#    'derde rij onder ywee',
#    'tweede vakj',
#    'e',
#    ' v',
#    'an lins',
#    'open die van ',
#    'jouik kna ',
#    'ni',
#    'e',
#    ' tnaar kruisdan moe ht hekje we',
#    'er oe',
#    'ja',
#    'hekje is dicth bij mij',
#    'nee hij zit dcicht',
#    'TIMEOUT'],
#   291.89),
#  (['waar tasta jij',
#    'ik ts',
#    'ta ookik oksiik ben daar ookik moer langs 1 hek',
#    'wa',
#    'ar',
#    ' is',
#    ' j',
#    'ou',
#    'w ',
#    'grijs',
#    'mi',
#    'jn',
#    ' g',
#    'ri',
#    'js',
#    'ja ',
#    'k ',
#    'be',
#    'n daar',
#    'is ie open',
#    'o',
#    'ke',
#    ' topmij',
#    'n',
#    ' g',
#    'r',
#    'ij',
#    's',
#    'die zit helemaal onderinlinksond',
#    'er',
#    'i',
#    'n ',
#    'linksja ik ben kruiswaar moet jij nog heen'],
#   ['die vn jou is nu open otch',
#    'ik sta derde rij van onder in het derde vakje ',
#    'va',
#    'n lin',
#    'ks',
#    'yes ik0ok',
#    'waar zi ',
#    'de',
#    'r',
#    'de',
#    ' rij ',
#    'van boven derde vakje van links is grijsof onderste rij g',
#    'h',
#    'elemaa',
#    'l rechts',
#    'yes ik eben oenop',
#    'ennu jijop',
#    'en',
#    '?',
#    'ik ook'],
#   96.975),
#  (['wat?',
#    'Links bovenin',
#    'ja iheb ik nu gedaan',
#    'o wacht ik zit niet helemaal obve==oveninmaar op de tweede rij van oven snap jedus ik nkan niet naar beneden',
#    'jep',
#    'gedaan',
#    'ja kloptof nuou ja ik sta nu wel op de plek maar ik kom wel een hekje tegendie zit hieronder',
#    'nu niet maar ik sta wel op de legoede plek volgens mijgebeurd er bij jou niks?',
#    'oke dan mag je drie stappen naar liknks dus helemaal naar links',
#    'ik sta op het kruisje nu',
#    'TIMEOUT'],
#   ['ergerg',
#    'ah oke nu zie ik hetik zit helemaal boven in de rechter hoekjij?',
#    'wil jij2 stsapp2stappen naar rechts doen',
#    '1 naar onder',
#    'oh juist daar dus waar alleen de middelste mogelijkheid geeft om naar benede',
#    'n ',
#    'te gaanwil je op die middenste gaan staan en 1 naar bedneden',
#    'eentje naar recht maar dan heb jij zeker ook zon hekje',
#    'dus je kunt nu niet naar beneden',
#    'neeoke proberen we jou eerstik zit helemaal bovenin rechts',
#    'gedaan',
#    'ik kan ghhier verder niet vandaankom direct een hekje tegen',
#    'TIMEOUT'],
#   292.552),
#  (['oke eerst maar overleggen we waar we staan?',
#    'ik ben helemaal onderin links',
#    'okezou jij dan eentje naar rechts willen gaan dan eentje naar boven en dan twee naar links?',
#    'ik',
#    ' s',
#    'ta op m',
#    "'nn",
#    'kr',
#    'ui',
#    'sj',
#    'eik sta nu op de plek waar jij eerst sonstondwaar moet ik voor jou heen?',
#    'nee ik sta nu op mijn rkuskruisje2e rij van boven drie van rechts',
#    'ja gedaan',
#    'topkun je bij je kruisje komen?',
#    'oke hahaik sta weer op wtweede rij van boven drie van rechts',
#    'gedaan'],
#   ['is goed',
#    'ik 2e rij van boen3 van rehtcrechts',
#    'heb ik gedaan',
#    ' ik',
#    ' k',
#    'o',
#    'm nu ',
#    'ee',
#    'n ',
#    'e',
#    'hekj',
#    'e ',
#    'tege',
#    'helemaal onderin links sta je toch',
#    'wil je 2 naar links gaan',
#    'haha hek1e hekj is open',
#    'nee ehet was een beetje een nutteloze doorgang',
#    'zou je weer naar die 2 naar links kunnnen gaan',
#    'ik sta nu oip mijn kruisje'],
#   226.937),
#  (['ik nu ookgehaald :)',
#    'ik sta in de linkerrijtweede vakje van onder',
#    'oke',
#    'zou je helemaal naar links willen gaan?',
#    'oh daar heb ik dan niks aandan moeten we eerst die van jou oplossen denk ik',
#    'volgens mij niet',
#    'sta ik op',
#    'ik k',
#    'an',
#    'maar ',
#    'i',
#    'eentje naar rechts',
#    'gaat goed zo',
#    'ok',
#    'e haha',
#    'mijn grijze vakje zit in dedie linkerrij en daar ga jij dus niet komen',
#    'maar hij oemoet op te lossen zijn',
#    'wij zin hier niet slim gegnoeg voor den iik',
#    'ha',
#    'ha',
#    'aha',
#    'we wachten gewoon op de volgende :P',
#    'TIMEOUT'],
#   ['lekker',
#    'ik helemaal recht rechts bovenin',
#    'zeg t maar',
#    'ik ben 3 stappen naar links gegaan tot ik een hejke tegenkom',
#    'die swithebben wij trouwens dezelfde hekjes',
#    'oke in die linkerrijwil jij naar de 3 3e van onderen gaan',
#    'en nu helemaal naar eerechtsbehalve 1tje',
#    ' vo',
#    'or',
#    ' d',
#    'e ',
#    'rand',
#    'hahah',
#    'okeik ga gewoon hier 1 voor 1 rondwandelenen als er eenhekje opengaatzeg t maar',
#    'klein ',
#    'oppervlakte',
#    'hahadie van mij hier in de rechter',
#    'yes',
#    'nee preciesafmeldenstudentenpas inleveren ',
#    'al',
#    'l',
#    'es',
#    'haha oh wat slecht',
#    'ja binnen 15 secodseconden wordt t m niet',
#    'TIMEOUT'],
#   303.168),
#  (['nee haha',
#    'kun ijij helemaal neaar erechts?',
#    'oke kun je wel helemaal naar boven?',
#    "wil je dan eentje naar links gaan?oke ik sta op m'n kruijse die is niet helemaal onderaan maar eentje daarbovenwaar kan ik voor jou heen?",
#    'gedaan',
#    'sta ik'],
#   ['ik zit helemaal onderinmaar dan 1 van onderen',
#    'niet helemaal voor de laatste zit een ghekje',
#    'ik zit nu pop die T splitsing',
#    'eentje naar rechts',
#    'een naar boven',
#    'kloar'],
#   136.078),
#  (['jeej2/',
#    '4',
#    'rechtsonderin?',
#    'geen idee waar dat is maar kun je ntoevallig helemaal naar links onderin',
#    'jammerik ga even nadenken hoe ik jou uitleggen moet waar ik benin het hmidden heb je diredrie blokjes opelkaar ik ben dan rechts van de bovensteis dat te begrijpen?',
#    'haha okezeg anders maar waar ik heen moet',
#    'ja',
#    'daar jga ik niet komen',
#    'ja',
#    'daar sta ik nu',
#    'top',
#    'k',
#    'un',
#    ' je',
#    ' he',
#    'lemaal naar links onderin?'],
#   ['10',
#    'ik zit helemaal rechts onderin',
#    'ja',
#    'haha nee',
#    'niet helemaal',
#    'je hebt links boven die 2 rijen naarnaast elkaar',
#    'de recht bovenste',
#    'okedie middenste lange rij',
#    'helemaal rechts',
#    'en ik nu op mijn kruisje',
#    'die',
#    ' staat ',
#    'h',
#    'elema',
#    'al li',
#    'n',
#    'ks',
#    'bei ik'],
#   194.083),
#  (['kruisjtejoepie',
#    'jadaar kan ik niet heen',
#    'oke',
#    'ik kan daar niet komen',
#    'je hebt die hele lange rij da',
#    'arvoven een rij van driekun jij naar het meeste rechtse blikblokje?',
#    'en naar het meest rechtse blokje van de onderste rij?kriusje',
#    'ik ben nu dus niet op de onderste rij maar de rij daarvboven en dan rechts',
#    'ja',
#    'ja'],
#   ['je hebt links onder zon rij van 3 blokjes',
#    'daarboven zit ik op die linker',
#    'op die rij daar weer bovendie allerlangstede 2e van rechts is mijn switch',
#    'oke dan moeten we jou eerst doen',
#    'ja',
#    'nee daar zitr een hekje',
#    'perfect',
#    'kun je eentje naar boven',
#    '3 naar rechts',
#    'kruisje'],
#   162.017),
#  (['toppiekun jij toevallig naar helemaal linksonderin?',
#    'naar niet helemaal link ik bedoel rechs boevenin?',
#    'oke haha zeg jij maar waar ik heen moet doendan',
#    'ikm ben rechtsonderin',
#    'nee eentje ndaar voen dus ik heb rechts en onder meij een blokje',
#    'ja',
#    'ja',
#    'ja',
#    'top',
#    'kun jij eentje naar onder',
#    'kruijse',
#    'ja haha',
#    'waar ziat die ook alwer precies?',
#    'sta ik nu',
#    'wil jij eentje naar onder',
#    'TIMEOUT'],
#   ['nee',
#    'nee ik ben echt heel beperkt',
#    'waar ben je nu',
#    'op die aller laagste?',
#    'oke1 tje naar boven?',
#    '1 naar rechts?',
#    '1 naar onder?',
#    'kruisje',
#    'helemaal rechts boven in ben ik nu',
#    'daar sra uik nu',
#    'oh dus we moeten allebei tegelijk op o',
#    'ns k',
#    'ru',
#    'i',
#    'sje staanokezou jij weer naar die ene helemaal rechts onder kunnen?',
#    'die ene rechts onder op de 2e rij van onderen',
#    'ik nu op kruisje',
#    'oke die moeten we rap doen dusmaar shit ik nzit nu opgesloten op mij nkruisje',
#    'TIMEOUT'],
#   293.561),
#  (['nu dannee net niet',
#    'kun jij helemaal naar linksonder?kruisje',
#    'helemaal onderin',
#    'ja',
#    'ja',
#    'ja',
#    'mooi ',
#    'maa',
#    'r ik zi',
#    't o',
#    'pgesloten',
#    'misschien oet en we een ander krgrijs valkje proberenjij moet eerst maar weer even naar helemaal nlnksvrijheb je nog een ander grijs valkvlak',
#    'je hebt die aller onderste en dan drie naar boven en dan eentje naar rechts',
#    'ja',
#    'ja',
#    'ja',
#    'ja',
#    'ja',
#    'ja',
#    'js',
#    'okekun jij nog helemaal naar linksnoderin',
#    'kruijse',
#    'ah neeik sanap dit niet',
#    'o',
#    ' j',
#    'a',
#    'die ',
#    'zit',
#    ' op dezelfde plekwe wachten nu wel gewoon ha',
#    'ha',
#    'TIMEOUT'],
#   ['jammer',
#    'waar zit die?',
#    '2 naar boven?',
#    '1 naar rechts',
#    '1 naar onder',
#    'kruisjekun jij n',
#    'u wee r ',
#    'haha oh wat kut',
#    'ja eentjewaar ben jij nu?',
#    'je bedoelt dus de 3e van onder en dan 1 naar rcech',
#    't',
#    'soke1 naar linsks',
#    'een naar boven',
#    '1 links',
#    '1 onder',
#    '1 links',
#    '1 boven',
#    'ik zit nu weer op mijn kruisjedat was een swithc van mij',
#    'ben ik nu',
#    'maar nu moest ik dus weg en ben ik weer opgesloten',
# ...
#    'ou',
#    'yes',
#    'here?',
#    'n',
#    'o!',
#    "I'm on ythe X",
#    'ye',
#    'ss we',
#    ' a'],
#   ['O',
#    'kay ',
#    'I a',
#    'm in the second row second room',
#    'can',
#    'no, I am in the second row second  roomfrom top 2nd row and from left the second room',
#    'oksay i am there now',
#    'second row ooooooh the most right room?',
#    "i can't reach ",
#    'i',
#    't, ',
#    'it',
#    '#s ',
#    'bl',
#    'o',
#    'cke',
#    'd',
#    'can you go theforth row and the third wrooom',
#    'tah',
#    't',
#    's it!o',
#    'k',
#    'ay',
#    'I ',
#    'am',
#    'blocked off, can you reach the top row?',
#    'can you stand in the room on the right?',
#    'ywaaasare you blocked n',
#    'ow',
#    '?',
#    'okay ',
#    'me',
#    ' t',
#    'oo',
#    ' l'],
#   259.793),
#  (['re',
#    ' getting mbetter',
#    'I',
#    "'m on the second row",
#    'Ok ',
#    'my siwtitch is on the bottom row third room',
#    'yeswhere',
#    ' i',
#    's ',
#    'yo',
#    'urs',
#    'how hoo can you stand on my switch again',
#    'that one?',
#    'IY',
#    'WHe'],
#   ['ol',
#    'yeah ha',
#    'ha',
#    'pkoky I am in the second row from the bottoml',
#    'ef',
#    't ro',
#    'om',
#    'that oone?',
#    'Okay, ',
#    'I just have one wsitch in the fifth row fifth room',
#    'sure',
#    'yes',
#    'y',
#    'eah'],
#   123.567),
#  (['ja((NEWLINE))ik sta((NEWLINE))linkshuhhahaha',
#    'wat 1',
#    'stuk',
#    'c1',
#    'f1',
#    'df1f1f1f1?',
#    'f5',
#    'rechts en dan 2e van boven',
#    '7',
#    'b7c1?',
#    'waarmoetikheen',
#    'neew8n',
#    'ee',
#    'wollah',
#    'ja',
#    'l',
#    'amollinksrij',
#    '2e bavan boven',
#    'v7b7B&jb7',
#    'f5',
#    'jaennu',
#    'gogogogoogogog',
#    'gogogoonee',
#    'k',
#    'ut'],
#   ['l',
#    'kun je een systematisch iets geven?',
#    'genietenoke',
#    'kan je C1',
#    'f1 lukt niet',
#    'f1nef1luktniet ',
#    'okokook niet',
#    'f7?of anee',
#    'c1',
#    'ik zit zo goed als vast',
#    'c1 of',
#    'f7',
#    'waar moest iknou ',
#    'geeheen',
#    '?',
#    'nee liever rechts kan dat?',
#    'kun je echtwacht neeoke mag ik cijfers?',
#    'ok',
#    'lukt het?',
#    'kun jij  weer naar een van mij?c1 of f',
#    'f7',
#    'ik sta nu go',
#    'e'],
#   238.384),
#  (['pffffff',
#    'li',
#    'nkso',
#    'nder',
#    'mo4rfh',
#    'aha',
#    'ha',
#    'hahah',
#    'LIN',
#    'KSONDER',
#    'ji',
#    'jd',
#    'an',
#    'jaleukspelletjeergl',
#    'e',
#    'uk',
#    'linksonder'],
#   ['d',
#    'meid ho',
#    'u ',
#    'die m',
#    'oet',
#    'moed r',
#    'er',
#    'in',
#    'okea',
#    '3',
#    'links kan ik niet bij ko',
#    'men',
#    'c7',
#    'ok',
#    'e',
#    ' en nu?',
#    'ja luktsta je?'],
#   62.18),
#  (['4e rij van bovenhelemaal rechts',
#    '3e',
#    'va',
#    'n ',
#    're',
#    'cht ',
#    'du',
#    's',
#    'waae ',
#    'r moet ',
#    'i',
#    'k he',
#    'en',
#    'nee ik kiik kan maar tot 4e rijvan',
#    'bo',
#    've',
#    'n',
#    'onderste rijhelemaal rechtsjanh hekje open5e rijen ',
#    'nu?',
#    'ja',
#    'ik kan nu naar het kruid ',
#    'ji'],
#   ['njWiMijn graWat is jou grijze vakje?',
#    'PO',
#    'ke',
#    ' d',
#    'an ',
#    'loo',
#    'p ',
#    'ik daar eheen Oh ik dkan dara niet heen Zit een hekje voorJk/',
#    'K',
#    'an',
#    ' ji',
#    'j naar de 5 rij van boven Tweerde vakje van rechts',
#    'Heb j',
#    'e ',
#    'no',
#    'g een anders grijs vakje',
#    'KA',
#    'n',
#    ' jij ',
#    'nuu naar de 5e rij Tweede vakje va rechts',
#    'Gelkukt ',
#    'Ik o',
#    'ok'],
#   144.466),
#  (['j ook?',
#    'helemaal rechts 2e van boven',
#    'he',
#    'lemaal links 2e van oboven en helemaal links onderste',
#    'ik kan niet naar lninks',
#    'daar ga ik nu heen',
#    'ik kan naar kruids',
#    'waar moet ik heen',
#    'ja',
#    ' wa',
#    'ar',
#    ' zit',
#    'die b',
#    'i',
#    'j ',
#    'jou',
#    'ben er',
#    'kan'],
#   ['Ik kan Waar is jou grijze vakje?',
#    'Daar aakan ik niet heen Heb je nog een andere',
#    '?',
#    'Daar kan ik ook niet een Mijne zijn helemaal links tweede van boven ',
#    'En helemaal rechts odndersta',
#    'Nu gaat er een nhekje voor jou opentoch?',
#    'Ik niet ',
#    'Naar een grijs vakje Re',
#    'cht s on',
#    'derHelemaal rechts onder Of helemaal links tweede van boven',
#    'Ik s'],
#   170.615),
#  (['doe maar',
#    'hahawaar zitten jouw ',
#    'grijze v',
#    'a',
#    'kj',
#    'es',
#    'kan ik n',
#    'iet geen',
#    'ga ik nu heen',
#    'ik nietm',
#    'ij',
#    'n',
#    ' grijze zit',
#    '3e',
#    ' van ',
#    'links helemaal onderinof helemaal rechts onderin'],
#   ['ta nu oop hetkruisIk kan nu in een keer naar een grijs vakje',
#    'Onee foutje',
#    'Mijn',
#    'e helemaal rechts onder E',
#    ' n',
#    'En de derde rij derde vakje an links',
#    'Ik sta nu op een grijs vakjeIk kan nu in een keer door naar het jkruis',
#    'Oke',
#    ' m',
#    'a',
#    'Waar moet ik h',
#    'ee',
#    'n?',
#    'Kan je nu naar ehet kruis?'],
#   121.63),
#  (['ja ik ben op kruis',
#    'ben er',
#    'de meest rechter die uitsteekt 2e rij avan onder',
#    'meest rechter 2e rij van onderof 4e rij bavan boven 2e cvan linksik b',
#    'n',
#    'en',
#    ' o',
#    'p kr',
#    'ui',
#    's',
#    'welke linker',
#    'heb',
#    ' je no',
#    'g een',
#    ' and',
#    'ere',
#    'di',
#    'e',
#    ' i',
#    's niet handig want dan moet jij o',
#    'p',
#    ' het grijze blijven staan',
#    'ben er'],
#   ['Mijn grijze vakjes zitten middelste rijtweede van boven ',
#    'Nee JaWaa r ziyt jou grijze vakje',
#    'Nog een keer?',
#    'I',
#    'k kan',
#    ' nu nie',
#    't mabKan jij naar het grijze vakje tweede van helemaal boven En dan de linker',
#    'T',
#    'we',
#    'ed',
#    'e ',
#    'rij van boevn linker v',
#    'ak',
#    'je ',
#    'of',
#    '3e rij van overonderrechter vakje'],
#   186.256),
#  (['4e van rechts en 2e van boven',
#    'nee',
#    'ja',
#    'ben er',
#    '3e rij van rechts en onderste',
#    'hij is niet open3e van rechts onderste',
#    'ja',
#    'ik sta op het kruisui',
#    'opni',
#    'e',
#    'uw',
#    '?',
#    'ben ',
#    'er'],
#   ['Ij sra sta op het kruisWat zijn jou grijze vakken?',
#    'Kan jij naar de derde rij van linksondersta vakje?',
#    'Kan je naar de dr3e rij van rechts bovenste',
#    '2e van boven bedoel ik',
#    'Waar moet ik nu heen?',
#    'Ben er',
#    'Nu?',
#    'Kan jij nu naar ',
#    '3e rij van rechte 2 vakje van boven of naar 4e rij455e r',
#    '3e',
#    'ri',
#    'j van links onderste vakje',
#    'o'],
#   157.202),
#  (['mijn ',
#    'grijze zijn de helemaal ondersteof de meest rechter',
#    'de aller ondersteof de meest rechter',
#    'ok',
#    'e wa',
#    'ar',
#    'nee',
#    'ben er',
#    'ik be',
#    'n'],
#   ['fIk sta op het kruis',
#    'W',
#    'Nog een keer?',
#    'Ik kan naar ebeide niet M',
#    'ijn',
#    'e ',
#    'i',
#    's de 3 van rilinks de bovensteof ',
#    '4e rij van onder tweede van rechts',
#    'Ik kan unu naar het kruis',
#    'mo',
#    'e'],
#   101.837),
#  ([' er ook',
#    'mij',
#    'n ',
#    'wa',
#    'ar moet ik heen',
#    'neea',
#    'nde',
#    'r',
#    'e?',
#    'mijne is 3e rij van rechts bovenste ',
#    '3e rij van links bovenste',
#    '3e rij van links 3e avan oboven',
#    'of4e rij van links bovenste',
#    'ik niet',
#    'kan',
#    'jij ',
#    'no',
#    'g n',
#    'aar',
#    ' 1',
#    ' van mij',
#    '3e rij van linkis obovensteof3e rij van links 1naonderste'],
#   ['Ik ',
#    'ka',
#    'n',
#    ' n',
#    'iet heel ver lopen Waa',
#    'a',
#    ' r',
#    'is jou vakje?Mijne is derde rij van linkstweede van onder',
#    'Waa',
#    'Ik heb eegeen anereI ',
#    'Wat?',
#    'Kan ik niet heen ',
#    'Die heb ik ook ',
#    'Kan je ersoorheen?Ik sta p kruis',
#    'W',
#    'aa',
#    'r ',
#    'mo',
#    'e',
#    't ',
#    'i',
#    'k he',
#    'en',
#    '?',
#    'Kan je erdoor heen?'],
#   163.777),
#  (['ik ben op kruis',
#    'b',
#    'en',
#    ' e',
#    'rgelu',
#    'k',
#    't?',
#    'mijn',
#    'e',
#    ' is linker rij 3e van bovendat is de enige'],
#   ['Mijn grijze vakjes ijn links bovensteTweede van rechts onde',
#    'rsteJo',
#    'uwe?',
#    'Ja',
#    'Gelukt?'],
#   65.01),
#  (['ja ik ben bij het kruis',
#    'k',
#    'en',
#    ' i',
#    'k ',
#    'ni',
#    'e',
#    't ',
#    'heen',
#    'ik kan maar naar 1 plek',
#    'g',
#    'a ',
#    'da',
#    'ar',
#    'wel',
#    'he',
#    'en',
#    'nu',
#    '3e ',
#    'van re',
#    'chts onderinof meest linker rij onderste',
#    'meest linker rij ondersteik kan naar het kruis',
#    ' d',
#    'us ',
#    'w',
#    'aar moet ik ',
#    'hee',
#    'njaoh nu ',
#    'kan ik niet meer naar kruis',
#    'linkerrij onderin',
#    ' of 3e van rechts onderin'],
#   ['Mijne zijn tweede rij van rechts 4e van bovenOf Nee wacht fout 3e rij ban links 4 e avan bovenof ',
#    'de',
#    'rd',
#    'e ',
#    'va',
#    'n ',
#    'erechts onderste',
#    'Oke ',
#    'we',
#    'ke',
#    ' z',
#    'ij',
#    'n',
#    ' n',
#    'jou',
#    '?W',
#    'e',
#    'lk',
#    'e ',
#    'zijn ',
#    'Welke is de tweede?',
#    'Ik ',
#    'neit',
#    ' Ka',
#    'n jij naar de 2e rij van links 4e van boven of naar 3e rij ',
#    'v',
#    'an rechts onderdeB',
#    'e',
#    'n ',
#    'b',
#    'ij ',
#    'kr',
#    'uis',
#    'Wacht',
#    'W',
#    '|Nu?'],
#   157.937),
#  (['jaben er',
#    '2e rij van rechts de bovenste',
#    'o',
#    'f 3e',
#    ' r',
#    'ij van rechts onderste',
#    'd',
#    'at',
#    ' i',
#    's',
#    ' a',
#    'l',
#    'ees',
#    'di',
#    'e ',
#    'v',
#    'an',
#    ' jou',
#    'nee',
#    'nee',
#    'ben er',
#    '2e rij van rechts bovensteof 3e van rehchts onderste'],
#   ['Wat zijn jou vakjes?',
#    'Daar kan ik niet ',
#    'eh',
#    'ee',
#    'n',
#    'Kan ik ook ni',
#    'e',
#    't ',
#    'he',
#    'en',
#    ' Mijn',
#    'e ',
#    'is Ik heb er 3onderste rij middelste@e ',
#    '2e rj van onder rechts',
#    'Of linktweede rij van oboven meest linkse',
#    'Welke zijn jjou',
#    'Kan je nu?'],
#   139.868),
#  (['jo((NEWLINE))gaa((NEWLINE))',
#    'haklll',
#    'prima',
#    '5,',
#    '23',
#    '1,11,1 en 5.21,1 5,5se5,2 bedoel ik',
#    'ja ',
#    'ik ',
#    'kan',
#    'w',
#    'el',
#    'k',
#    'e ',
#    'ha',
#    'd ',
#    'je',
#    'waar',
#    'ik kan er gwqn ',
#    'h',
#    'ee',
#    'n'],
#   ['wad',
#    'wat',
#    'mooi dit1,',
#    '5 ',
#    'em7,2151,5en7,2wat zijn die van jou?',
#    'knan',
#    'kan ',
#    'houd die van mij open',
#    'w',
#    'an',
#    't',
#    ' i',
#    'k h',
#    'eb een hgekje ervoor',
#    '7,2en1,5',
#    'ik',
#    ' s',
#    'ta op xdit is vervelend'],
#   142.376),
#  (['ja echt',
#    '4,2',
#    '4,2',
#    ' en',
#    '4,2 en 5, ',
#    '45,4',
#    'zijn ze open',
#    'ga ',
#    '4,2en 5,45,4 en 4.2',
#    'ben er',
#    'superdepuper'],
#   ['3m',
#    '3,131,121wdadwadwad3,13,2is het3,2en',
#    '4,',
#    '6ik zit vast',
#    'ik ',
#    'zit vas',
#    't ',
#    'in kcolumn 1',
#    'nope3,2en5,6',
#    'welke had jij>?',
#    'nu open?',
#    'jepic',
#    'hiervboor heb ik een gamerchair'],
#   139.839),
#  (['L¿', 'L?1-5, 1-5, 6-71,-`1', 'Open?', 'Nee1-56-7'],
#   ['Ben je?((NEWLINE))',
#    'dofhfsd',
#    'Ik kan niet 1-5 of 6-7Mijn gagrijd mijn grijs is 4-5kan jij 4-5?',
#    'KQN JIKan ijji rood?',
#    'IOpen?'],
#   130.618),
#  (['Rood3-3',
#    '7-4',
#    'JaRoo',
#    'Kan ',
#    'NeeIk sta op 1-6',
#    'Nope3-3 7',
#    '47-4',
#    'Ro'],
#   ['3-3 kan ik niet komen',
#    'Open?',
#    '1-6?',
#    'Kan jij van 1-6 naar rood zonder gate?',
#    'Kan jij rood nu zonder gate?',
#    'Open',
#    '?s',
#    'ta ',
#    '3-3',
#    'Rood?'],
#   72.024),
#  (['test',
#    'moi',
#    'ik ook',
#    'o',
#    'nder',
#    ' d',
#    'at rooddr',
#    'ode',
#    'k',
#    'ru',
#    'is',
#    'e',
#    'onder rode kruis zit 1tjeWil je daar opstaanOh damnWil je dan weer eer',
#    'st ',
#    'zo s',
#    'ta',
#    'an',
#    'al',
#    's',
#    ' eerstik was er doorheen',
#    'b',
#    'en',
#    ' erd',
#    'o',
#    'or',
#    'Waar zit het ',
#    'g',
#    'ru',
#    'i',
#    'waar zit je rode kruis',
#    'hier?',
#    'Waar',
#    ' zit',
#    ' j',
#    'e ',
#    'ro',
#    'de kruis',
#    'oh daardie van mij rechts boven',
#    'okay links onder zit een opgr',
#    'is',
#    ' vakje',
#    'Helemallal links onder is gruijskan je daar komenonderste rij links',
#    'nu welof niet',
#    'okay ik ben er door'],
#   ['hoi',
#    'ik sta nu op een grijs vakje',
#    'rechtsonder is het grijze vakjerechtonsrecht',
#    'so',
#    'nd',
#    'er',
#    'D',
#    'at',
#    ' zi',
#    'e ik niet',
#    'I',
#    'k ',
#    'ben',
#    ' er',
#    'd',
#    'oo',
#    'r',
#    'he',
#    'en',
#    'Sta ik nuNu zi',
#    'jnm',
#    'ij',
#    'nporortjesdicht',
#    'r',
#    'ec',
#    'h',
#    'tsonder',
#    '3vakjesnaarvanafrodekruisnaaronderendanhelemaalrechts',
#    'vaneevanafrodekruis2stappenomlaagendan',
#    '2na',
#    'arrech',
#    'ts',
#    'linksbovenhelemaal',
#    'dus op jouw rode kruis dan',
#    'ik',
#    'benernog niet doorheen',
#    'Daar kan ik nog niet in',
#    'ja sta er nu'],
#   418.271),
#  (['lek',
#    'kerok',
#    'ay ',
#    'Ik links onder',
#    'helemaal onderinand ',
#    'me',
#    'es',
#    't ',
#    'rechter zitgrijs vlakje',
#    'ok',
#    'e 3,',
#    '2 zsta ik3,1 is een gruijs kruis',
#    'ik ben op de rode',
#    'w',
#    'waar staan jou grijze vlkajes',
#    'ah ik doe vanaf onder',
#    'ben je er door',
#    'ik',
#    ' s',
#    'ta ',
#    'op',
#    ' k',
#    'ru',
#    'is'],
#   ['Yeaahahhhboyy',
#    'y',
#    'Ik ',
#    'he',
#    'b',
#    'indielangereeksdetweedevanrechts',
#    'ik sta er',
#    'linkson',
#    'd',
#    'er',
#    'in',
#    'latenweinrijenpratenhelemaal boen boven is rij 1 en zo verderik sta nu o',
#    'n',
#    'der1',
#    ' e',
#    'n ',
#    'Daar sta ik nu',
#    'ik ',
#    'ben er nietdoorheen',
#    '66,5x6y5vanaf boven',
#    'okee priamx6y3',
#    'jjak',
#    'u',
#    't ',
#    'no',
#    'g e',
#    'en',
#    'kee'],
#   185.12),
#  (['x',
#    'van mij x2y1 of y7grijze vlakje',
#    'is',
#    ' vanaf ',
#    'on',
#    'de',
#    'r',
#    'neex',
#    '5',
#    'y1',
#    'mijne staat op X2y7',
#    'y',
#    'ja',
#    'en',
#    'x5y1is grijze vlak',
#    'ja',
#    'o',
#    'nd',
#    'ereste vlkaje is gr',
#    'ijze',
#    'nee',
#    'die',
#    ' rechtsboven ook',
#    'x7x7y6en waawaar staan jou grijze vlkajes',
#    'ik moet er eerst doorheen',
#    'je',
#    ' moe',
#    't op',
#    ' de onderste staande alle onderste xx',
#    '5',
#    'x5alle onderste',
#    'x7',
#    ' die kan ik nietmoetje naar x7',
#    'welke hbe je nog meer',
#    'TIMEOUT'],
#   ['erikbendoordeverkeerdejastaeropoke vafyisbvanafbovenx3',
#    'y1l',
#    'Kanje',
#    'erdoorh',
#    'een',
#    'x',
#    '2y',
#    '1watisjouwx',
#    'vanafon',
#    'der?',
#    'sdd',
#    'a',
#    'arstaiknu',
#    'vanafonder?',
#    'okem',
#    'ij',
#    'n',
#    'ja',
#    'benjeerdoorheen',
#    'ikstaerop',
#    'mi',
#    'jn',
#    'mmm',
#    'x3y1boven',
#    'JaIkstaopx2y121x2y2',
#    'x2',
#    'y1',
#    'al',
#    'leronderstex?',
#    'Daar kan ik niet komenjij moet eerst ',
#    'x',
#    '3y1',
#    'Kan ik niet',
#    'TIMEOUT'],
#   287.84),
#  (['hahah',
#    'ik',
#    'x7',
#    'y',
#    '7x',
#    'y6',
#    'x5',
#    'y4x5y4oke wekle ',
#    'grijs',
#    'ze hbe je',
#    'voor ',
#    'mij',
#    'oke twee mogeli',
#    'jk',
#    ' he',
#    'de',
#    'nx5y4',
#    'x6y6x',
#    '5y',
#    '4',
#    'jaik sta op x'],
#   ['x5y4Ahhh jij hebjouwporortjeszitenaergensandersnatuurlijk',
#    'okevanafondery3',
#    'uhhhwachty1x3x5y2',
#    'en',
#    'xyx7xx7y7?Dat ',
#    'ka',
#    'n nietahh jakaniknietheen',
#    'ietslinksnder',
#    'ook',
#    'niet',
#    'ikz',
#    'itx3y1x5y2enx3y6x3y6ben erodoor',
#    'sta ik',
#    ' er nu?gis',
#    'ie',
#    'op',
#    'en',
#    'nu?',
#    'Lkeke'],
#   165.953),
#  (['n',
#    '1ik heb',
#    ' green ',
#    'grijz',
#    'e',
#    'ja',
#    'x1',
#    'y',
#    '1x1y1',
#    'be rben er'],
#   ['rx7y5', 'x7y5', 'en', 'nu?'],
#   33.321),
#  (['z7',
#    'y6',
#    'x7y6',
#    'j',
#    'e s',
#    'otnd',
#    'go',
#    'je stond hiervoor geo',
#    'edp',
#    'ja',
#    'oke '],
#   ['nice',
#    'x',
#    'y72',
#    'ik st',
#    'a ',
#    'op',
#    ' k',
#    'ruis',
#    'nu',
#    'x1y5',
#    'sta op rood'],
#   63.802),
#  (['gj', 'x2y4x5y4x2y4x5y4', 'ja', 'sta ', 'op'],
#   ['x3y2x5y6', 'Nu?', 'en dan x', '3y'],
#   67.648),
#  (['x1y5',
#    'jij moet als laatste erop',
#    'ik kan nu nietwelkeik sta helemaal links',
#    'ja mjij moet op x1y5'],
#   ['2ofx5y6jastanicex6y1', 'kanikniethelemaalrechts', 'oke', 'x1y7', 'Nu?'],
#   64.237),
#  (['ben erik ',
#    'sta x7y7',
#    'jij moet eerst x4y1x1y4x1y4',
#    'x1y3',
#    'Die is niet goedwelke no',
#    'g ',
#    'me',
#    'er',
#    'Nu sta ik ahchter poorje',
#    'x5y',
#    '2',
#    ' zit achter poortje',
#    'ha x5y2 ook voor jou ppoortje?',
#    'samemooi'],
#   ['x',
#    'ikstax2y5jijmoetx5y2',
#    'kanikniet',
#    'jax5y2',
#    'bener',
#    'doorheen',
#    'waar dan',
#    'w',
#    'aar',
#    'nu?',
#    'neekkannaarrood'],
#   110.956),
#  (['jij moet ',
#    'x$',
#    '5X2y3ofx7y2',
#    'sta op roodx2y3is daar een gijze in debururt'],
#   ['lekkerjaikstax3y2jij moet x4y6of', 'x4', 'y3', 'Dat kan nietx2y3?'],
#   66.448)]

# %%
TBT_turn_list, participant1, participant2 = [], [], []
timestamps = set()
gameid = TBT.iloc[0].GameNo
for index, row in TBT.iterrows():
    if gameid != row.GameNo:
        TBT_turn_list.append(([turn for turn in participant1 if turn != '' and turn != 'CORRECT'], [turn for turn in participant2 if turn != '' and turn != 'CORRECT'], (max(timestamps) - min(timestamps))/1000))
        participant1, participant2, timestamps = [],[], set()
        gameid = row.GameNo
    item = str(row.Text).strip()
    timestamps.add(row.TimestampReceived)
    if row.Sender == 'Participant1':
        participant1.append(item)
    else:
        participant2.append(item)
TBT_turn_list.append(([turn for turn in participant1 if turn != '' and turn != 'CORRECT'], [turn for turn in participant2 if turn != '' and turn != 'CORRECT'], (max(timestamps) - min(timestamps))/1000))

# %%
TBT_turn_list
# Out:
# [(['Ik heb de derde van de linkerrij',
#    'daar ben ik',
#    'Nu niet meer',
#    'Ja',
#    'Ik ben bij het doel'],
#   ['oki',
#    'uhh',
#    'ik heb helemaal links boven',
#    'open?',
#    'nu?',
#    'ga naar doel'],
#   49.558),
#  (['Ok',
#    'kan ik niet heen',
#    'ik heb bovenste rij, derde van links',
#    'ik ben bij jouwne',
#    'derde van onder derde van links',
#    'ja',
#    'ben er'],
#   ['gnd = ga naar doel',
#    'ik heb helemaal rechts onder',
#    'ik heb ook derde van onder tweed evan links',
#    'ja?',
#    'waar moet ik nu heen?',
#    'ik kan alleen onderste 3 rijen',
#    'ja?',
#    'gnd'],
#   86.048),
#  (['Ik zie niks',
#    'Enter drukken',
#    'Aiiiiit',
#    'Ik zie het experiment',
#    'OK',
#    'Kan jij A1?',
#    'otop',
#    'ik ben op doel',
#    'ja',
#    'Ik vergeet steeds enter te drukken lol'],
#   ['okeee oh dit is makkelijker denk ik',
#    'nan',
#    'ooooh',
#    'haha',
#    'got it',
#    'hahahahah',
#    'jij eerst?',
#    'ja',
#    'ben er',
#    'C1?',
#    'top',
#    'ben doel',
#    'haha ff wennen'],
#   67.862),
#  (['Ja echt hoor',
#    'Ok',
#    'D3?',
#    'Hhahahahah ik sta gwn klaar',
#    'Top ben op del',
#    'Hahaha ik ging voor de poort staan',
#    'Hahahah oke zeg maar',
#    'ja',
#    'had gewoon keuse top',
#    'Ben er',
#    'kutjes',
#    'KILLL',
#    'Ga lopen nu'],
#   ['wow lekker rood',
#    'huh',
#    'je hebt mn poorten al open lol!!!',
#    'ik ben d3',
#    'we worden helderziend',
#    'ja nu zit ik ophesloten lol',
#    'A4 of B3 of D3',
#    'top',
#    'ho nee te vroeg',
#    'ben weer opgesloten',
#    'HHAHA',
#    'thanks',
#    'neeee',
#    'ben weer weg',
#    'ja ben doel',
#    'jajajajaja'],
#   109.3),
#  (['kan ik niet heen',
#    'zo?',
#    'top bij mij ook open nu',
#    'sta opp kruis',
#    'lol',
#    'ja',
#    'zo?'],
#   ['tweede rij van onder',
#    'middelste',
#    'waar heb jij grijs?',
#    'eena bovenste rij',
#    'rechts',
#    'ja',
#    'waar heb jij grijs?',
#    'nu kan ik niet naar kruis',
#    'kan je eena onderste rij',
#    'middelste?',
#    'ik sta kuris'],
#   75.107),
#  (['sta ik',
#    'tweede van onder vierde blokje',
#    'ja',
#    'kan jen aar kruis?',
#    'sta ik',
#    'oh wacht',
#    'zo',
#    'skipt ie t nou lol'],
#   ['tweede rijvan onder',
#    'rechts',
#    'kan dat?',
#    'waar moet ik heen?',
#    'zo?',
#    'nee',
#    'derde rij van boven',
#    'links',
#    'derde rij vanboven',
#    '1e blokje',
#    'ik sta kruis',
#    'ik zi eook nisk'],
#   116.027),
#  (['Ik heb 2 gates voordat ik bij een switch kan',
#    'Dus jij zal een switch moeten proberen',
#    'Klopt, maar ik weet wel waar de mijne zijn.',
#    'Probeer gewoon een switch',
#    'Ik kan namelijk niet naar een switch toe, dus jij moet er eentje doen',
#    'Oooh zo, dat was nog niet duidelijk',
#    'Ik heb 2de van links midden een switch',
#    'Of helemaal rechts onder',
#    'Ja',
#    "Ik sta nu op m'n kruis",
#    'Waar moet ik voor jou heen?',
#    'Ik sta op eentje'],
#   ['je weet niet waar mijn switches zijn he',
#    'waar sta je?',
#    'jij ziet waar jouw switches zijn, ik zie waar de mijne zijn',
#    'om jouw te begeleiden en vice versa, moet ik weten waar je staat',
#    'ik sta in de onderste horizontale rij van doolhof helemaal links',
#    'tell me where to go',
#    'ait',
#    'ik sta er nu',
#    'zijn ze open?',
#    'mijn switches staan: 2de rij van boven helemaal links, 3de rij van onder rechts',
#    'ja done',
#    'ik sta op mn kruis',
#    'gg wp'],
#   200.045),
#  (['Mijn switches: 4, 7 en 3,3',
#    'coordinaten',
#    'vanaf linksonder gekeken',
#    'Nope',
#    'Nope',
#    'x,y',
#    '3,3 is 3de rij van onder, 3de van links',
#    '1,1',
#    'Ik sta trouwens op de jouwe',
#    'Van mij nog niet',
#    'yes',
#    'nu niet meer',
#    'ja'],
#   ['oke mijn switches zijn, 2de rij van boven 2e vakje links',
#    '3e rij van onder 2e vakje links',
#    'die van jou?',
#    'ait ik sta op 1',
#    'open?',
#    'oh linksonder',
#    'nu?',
#    'geef even duidelijkere directie dan',
#    'is helemaal links onder 0,0?',
#    'if 1,1',
#    'of*',
#    'daar kom ik niet bij',
#    'nu open?',
#    'die van jou?',
#    'die van mij wel',
#    'nu?',
#    'ik sta op de kruis',
#    'ah shit',
#    'nu?',
#    'hmm'],
#   206.614),
#  (['Oh wacht ik had x en y omgedraaid net volgens mij haha',
#    'sta ik op 3,5?',
#    'Nu bedoel ik',
#    'chill',
#    'mijne 3,1 en 7,1',
#    'em 6,4',
#    'ja',
#    'en weer dicht..',
#    'dat was te snel',
#    'ja',
#    'sta op kriuis',
#    'jsa',
#    'uiteraard...'],
#   ['gaan ze na een tijdje dicht?',
#    'oke 3,5 7,1',
#    'de jouwe?',
#    'bru',
#    'nee',
#    'ja',
#    'waar moet ik heen',
#    'ik sta op kruis',
#    'nu?',
#    'oh als ik eraf ga gaan ze dicht'],
#   109.838),
#  (['5,4 en 6,6',
#    'jij?',
#    'nu?',
#    'ja',
#    'op kruis',
#    'nu?',
#    'ik kan nu er ook niet meer bij',
#    'yes',
#    'kun je mij eerst vrijlaten?',
#    'chil',
#    'ja'],
#   ['3,1 5,2 3,6',
#    'yes',
#    'nu?',
#    'oke ik kan niet meer bij mn kruis',
#    'sta erop',
#    'jij',
#    'jouw switches zijn buiten mijn area met het kruis',
#    'dus jij moet een switch van mij zoeken, die binnen de area met jouw kruis zit',
#    'ik sta kruis',
#    'ez game ez life'],
#   142.842),
#  (['ik had jouw verkeerde switch te pakken',
#    '3,4',
#    'kom ik niet',
#    '3,5',
#    '4,7',
#    '3,6 ipv 3,5',
#    'ja, ik nu op 3,4',
#    'nope',
#    'ja',
#    'chill'],
#   ['oke 3,4',
#    'hahahahah',
#    'ik kom er ook niet',
#    'die wel',
#    'kun je bij je kruis?',
#    'nu?',
#    'ik zit in mn kruis area'],
#   59.593),
#  (['4,2', '5,4', '?', 'Ik sta op 5,6', 'nope', 'ja', 'sta er op', 'nu wel'],
#   ['3,2',
#    '5,6',
#    'kun je bij jouw kruis?',
#    'nu?',
#    'ik kom niet meer bij mijn kruis nu',
#    'yes',
#    'jij?',
#    'nice'],
#   89.598),
#  (['1,5', 'nee', 'chill', 'sta er o[p'],
#   ['1,7 6,1',
#    'sta je op jouw kruis?',
#    'ga er naartoe',
#    'ik kan naar die van mij'],
#   45.117),
#  (['1,1',
#    '1,5',
#    '5,2 7,6',
#    'ik op 7,2',
#    'ben @ kruis',
#    'ja',
#    'sta er op',
#    '1,5',
#    'wacht',
#    'nee haha',
#    'nu wel'],
#   ['7,2 1,5',
#    'ik kom niet bij jouw switches',
#    'nu wel',
#    'oke is een switch van mij in jouw gate area?',
#    'ik kan er nog niet bij',
#    'u sure?',
#    'net wel',
#    'ze gingen even open',
#    'ik sta op kruis',
#    'thnx'],
#   100.537),
#  (['5,1 7,6', 'op 5,4', 'ben @5,4?', 'jo', 'ben @kruis'],
#   ['3,7 5,4', 'oke ga naar je kruis', 'sorry ik was ff in de war'],
#   69.776),
#  (['3,1 6,4', '6,3 kom ik niet', 'nu wel'],
#   ['6,3', 'kun je naar jou kruis?', 'nice'],
#   30.789),
#  (['ik zit bovenin',
#    'en kan niet naar onderen',
#    'oke daar kan ik bij',
#    'welke?',
#    'zo?',
#    'oke',
#    'die van mij zit in de middelste rij met 5 vakjes',
#    'en dan de 2e van links',
#    'top!',
#    'ik ben bij kruis',
#    'zo?',
#    'tooop'],
#   ['mijn grijze vak is nu in de tweede rij van boven',
#    'kun je daarbij?',
#    'en dn de linker',
#    'jaa',
#    'wat kan ik doen',
#    'jaa',
#    'jaa',
#    'ik sta erop',
#    'kun jij nu naar de 3e rij van onderen',
#    'en dan het rechter vakje',
#    'jaa',
#    'ik sta op mn kruis'],
#   93.105),
#  (['kan ik niet bij komen',
#    'heb j e meer grijze vakken?',
#    'deze?',
#    'oke',
#    'die van mij zit helemaa l links onderin of rechts onderin',
#    'kan je bij 1 van die 2?',
#    'jaa tiop',
#    'ben bij mn kruis'],
#   ['grijs is bij mij rechtsonder',
#    'en die andere is bij mij de 3e rij van links',
#    'en dan de bovenste',
#    'jaa',
#    'okee ik sta op mn kruis',
#    'jaa',
#    'zo?',
#    'okeee ik ga u',
#    'ik vind dit dus kutter ommuniceren',
#    'want je ziet hier niet gelijk wat er wordt getypt',
#    'dus je moet steeds wachten'],
#   119.815),
#  (['ik heb een grijs vakje in de buurt, zal ik kijken wat dat doet?',
#    'ik ben er',
#    'zal ff tellen',
#    'wacht hoe werkt je coordinaat?',
#    'eerst x en dan y of andersom',
#    'dan is mijne op 3,7 denk ik',
#    'nee maar als ik mijne wil doorgeven',
#    'ik kan bij 3,3, niet bij 7,7',
#    'ik heb er ook een op 7,7 denk ik, als dat helemaal in de hoek is?',
#    'ben nu op 3,3',
#    'er gaat bij mij wat open en dicht',
#    'nee dit werkt wel',
#    'ik ben nu ook 7,7',
#    'dus blijkbaar gaan alle hekjes altijd open?',
#    'ik nog niet, tenzij je op een grijze gaat staan',
#    'nu wel',
#    'jij ook nog?'],
#   ['yes',
#    'mijn grijze vakje is op 7,7',
#    'kan je daar naar toe?',
#    'de ander is op 3,3',
#    'eerste is x de ander is y',
#    'maakt op zich ook niet uit als het 7,7 is maar he',
#    'ik kan nog niet op 3,7 komen',
#    'heb je een 2de?',
#    'kun je naar 3,3?',
#    'ik sta nu op 7,7',
#    'moet ik naar 3,7?',
#    'ik kan nu naar de kruis',
#    'nu dan',
#    'same',
#    'lets go'],
#   222.811),
#  (['1,1 is dan top left toch?',
#    'ik heb een grijze twee daar onder en verder niet',
#    'ik sta nu op 1,1',
#    'ik kan nu naar 6,7 denk ik',
#    'werkt dit?',
#    'ik kan naar het kruis maar alleen als de poort open blijft',
#    'ik ben er, maar kan je er nu in of niet?'],
#   ['1,1 en 6,7',
#    'jup',
#    'ik sta nu op 1,3',
#    'ik kan nu bij de kruis',
#    'oke ga maar',
#    'ik sta naast het kruis',
#    'yeah boi'],
#   105.24),
#  (['ik heb weer 1 grijs',
#    'helemaal linksonder',
#    'ben nu 7,3 denk ik',
#    'kun je nu ergens komen?',
#    'dan kan ik niet tellen hold on',
#    'oke nu?',
#    'dan ga ik zo naar 3,1',
#    'ik ook'],
#   ['3,1 en 7,3',
#    'oke daar kan ik niet komen',
#    'er gaat niks open',
#    'hahaha',
#    'yes',
#    'ik sta nu 0op jouw punt',
#    'en kan bij het kruis komen',
#    'nois'],
#   73.328),
#  (['heb er 2',
#    '3,7 en 6,4',
#    '6,5 kan i kniet bij',
#    'prima',
#    'vanaf nu kan ik bij kruis, geen hekje meer',
#    'dus ga jij maar eerst',
#    'top'],
#   ['ik 1',
#    '6,5',
#    'ik kan bij beiden van jou',
#    'ik begin bij 3,7',
#    'same',
#    'nois'],
#   75.779),
#  (['heb er 4',
#    '1,3; 7,2; 1,7; 5,6',
#    '7,6 kan ik bij denk ik',
#    'daar ben ik nu',
#    'ik kan al bij het kruis trouwens',
#    'zonder hekjes',
#    'of ben je er?',
#    'wacht',
#    'ik keek scheef',
#    'zit wel hekje tussen',
#    'excuus',
#    'please send help',
#    'ja vgm ben ik daar',
#    'ik kan zo wel naar 1,3 als ik door het hekje ben',
#    'en vanaf daar zonder hekje naar kruis',
#    'ja'],
#   ['2 vakjes',
#    'oh damn',
#    '1,3 & 7,6',
#    'oh top',
#    'ik ook',
#    'jup',
#    'ik ben er',
#    'wauw',
#    'ait',
#    'kan je terug naar 7,6\\',
#    'jup',
#    'wacht ff',
#    'kan je nu',
#    'lets go',
#    'ik ben op het kruis'],
#   162.295),
#  (['4,1 en 3,5',
#    'kan ieg bij 2,5',
#    'yes',
#    'dan ff kijken',
#    '3,2 kan ik nu heen',
#    'idem'],
#   ['3 vakjes',
#    '2,5 3,2 en 6,7',
#    'nu is ie open vgm',
#    'ik kan vanaf nu bij het kruis'],
#   83.761),
#  (['2 vakjes',
#    '6,2',
#    'en 5,4',
#    'ik ga naar 3,2',
#    'moet ik nog iets opendoen?',
#    'is open?',
#    'ik kan er bij'],
#   ['3 vakjes:',
#    '3,2 & 3,7  & 5,6',
#    'ik kan nu naar 62',
#    'jup',
#    'graag',
#    'ik dan?',
#    'same',
#    'thnx'],
#   77.901),
#  (['7,2 en 5,7', 'open?', 'ik ben er', 'top'],
#   ['2 vakjes', '1,3 & 5,4', 'ik kan nu bij het kruis'],
#   49.71),
#  (['3,2 4,1 3,5',
#    'alleen 3,4?',
#    'daar kan ik bij maar kan dan niet meer bij kruis',
#    'zit nog wat tussen',
#    'ben er',
#    'yes',
#    'dik duimpje'],
#   ['3,4',
#    'jup',
#    'nee komt goed',
#    'doe mr',
#    'nu kan je naar het kruis toch',
#    'ik nmlk wel'],
#   63.616),
#  (['2,4 en 7,6', 'zo?', 'is die niet open?', 'huh', 'ja is open', 'ja'],
#   ['4,2 & 4,5',
#    'ja maar ik heb nog wel een deur nu',
#    'wacht zat naar mn eigen coordinaten te kijken',
#    'oke nu is ie open',
#    'kan je bij eht kruis',
#    'top'],
#   79.793),
#  (['Oke hoe en wat is het handigst, ik sta links',
#    'in een hoek',
#    'Jij?',
#    'Ik sta nu op een grijs vlak, gaat een hekje open?',
#    'Ik ga wel op een paar vakjes staan, laat het me weten als een hekje open gaat',
#    'Open?',
#    'Mijn hekje is open!',
#    'Super!',
#    'Ik sta nu op een grijs vlak',
#    'Ik moet nog 1 hekje open',
#    'Kan je die open maken door op veel vakken te lopen?',
#    'Ik sta nu gevangen in 1 2 vakjes binnen 2 hekjes',
#    'Dan moet de vorige weer open',
#    'Kan je wat rondlopen daar?',
#    'Dan kan ik weer terug',
#    'Yes top',
#    'ik ben een stapje terug',
#    'waar ben je',
#    'ik sta nu weer grijs',
#    'IK heb nog 1 hek',
#    'kan je lopen?',
#    'Ik moet nog 1 open',
#    'nog 1 min en 50 sec!!',
#    'mijn vlakkn zijn anders he',
#    'ik heb andere grijze vlakken',
#    'ja dat heb ik ok!',
#    'nan',
#    'we zijn gevangen!',
#    'oke we moeten eruit',
#    'Kan je wat rondlopen?',
#    'Ik ben rood',
#    'kruis',
#    'nu jij nog',
#    'waar ben je',
#    'Mijn hek gaat zo dicht',
#    'Open?',
#    'ik heb veel gelopen',
#    'Oei ik zit nu ook achter een hek',
#    'Wel rood kruis nu',
#    'maa hier is geen grijs vlak'],
#   ['Wat is jouw startpunt',
#    'ik sta helemaal rechts bovenin in een hoek',
#    'het allerbovenste hoekje',
#    'nee zie niks',
#    'yes',
#    'ik moet vier vakjes naar links tot ik bij een hek ben',
#    'ne dicht',
#    'open',
#    'ik kan nu naar kruisje',
#    'jij ook al?',
#    'oke als jij mijn hekjes even opdoet',
#    'open doet',
#    'dan kan ik op grijs komen',
#    'wat stressvol',
#    'ik sta nu grjs',
#    'grijs',
#    'het ging in eens opne',
#    'ben jij ook al open?',
#    'kruisje',
#    'kun jij op kruis komen',
#    'huh dit is onmogelijk',
#    'ik sta voor een hek op grijs vlak',
#    'dus als ik die open wil hebben kan ik er niet meer uit',
#    'hoe komen we er dan uit haha',
#    'ik ben gevangen',
#    'in een hek',
#    'als het hek open is dan ben ik ook rood',
#    'maar jij zit dan weer opgesloten',
#    'nee dicht nog',
#    'ik ben gevangen',
#    'helaas'],
#   291.556),
#  (['HahahaHaha nieuwe kansen!',
#    'Waar sta jij?',
#    'Ik onderin',
#    'helemaal links onderin',
#    'Okee',
#    'ik zie dus 1 hek',
#    '2 vakjes onder het rode kruis',
#    'zie je die?',
#    'Ik jeb 1 hek die open moet',
#    'Top',
#    'die moet open',
#    'moet jij ook lang een hek?',
#    'lang',
#    's',
#    'Oke',
#    'nog niet!',
#    'Ik heb een grijs vakje rechts bove in kruis',
#    'zegmaar de bovenste rij',
#    'en dan 3e van links',
#    'die is grijs bij mij',
#    'kan je daarheen?',
#    'kan je daar wel wat rondlopen?',
#    'want mijne zijn anders dan jouwe',
#    'hahahahahaha',
#    'nooo!',
#    'kan je wel wat rondlopen?',
#    'moet je uberhaupt langs een hekje',
#    '?',
#    'ja jij moet op mijn vlak',
#    'die ik zie',
#    'daar moet ik jou heen krigen',
#    'ja ahahahhaaha',
#    'haahahahhhahhaa',
#    'hahahaha',
#    'ehhh',
#    'ik zie eentje 3e rij van onder',
#    '3e van links',
#    '1 min!!!!!',
#    'haahhaa',
#    'daar zit bij mij een hek',
#    'Ja boven in! Maar jij was onder toch',
#    'neee we zitten weer gevangen ahaha',
#    'neeeee',
#    'jaa',
#    'hahahaa volgende',
#    'hahaah'],
#   ['gelukkig',
#    'ik sta tweede rij van onder in het middelste vlakje',
#    'oke dan zijn we dicht bij elkaar denk',
#    'huh ik ben verplaatst',
#    'ik sta tweede rij van boven nu in het derde vakje van rechts',
#    'ja die zie ik',
#    'oke ik ga nu naar grijs',
#    'open?',
#    'oke ik loop even',
#    'ik heb geen grijs daar',
#    'wacht',
#    'ik zit nu vast',
#    'dichterbij het kruis kan ik niet komen',
#    'hahahha',
#    'zit op de vierde rijvan onder',
#    'maar ik snap niet waarom de hekken niet opengaan',
#    'of gaanz e alleen open als ik op de grijze vlakken van jou kom',
#    'oooooh',
#    'hahahhahahha hoe dom',
#    'oke welke rij?',
#    'daar kan ik niet komen want tussen rij drie envier zit een hek',
#    'misschien kun jij die openmaken',
#    'helemaal onderste rij',
#    'rechterhokje',
#    'is grijs',
#    'dan kan ik het voor jou openen',
#    'heb je nog meer grijze vlakken',
#    'ergens bovenin',
#    'nee ik zit boven hahaha ik was verplaatst',
#    'oke volgende'],
#   289.233),
#  (['Het kruis zit bij mij onderin',
#    'Ik heb 1 hek',
#    'Ben je boven?',
#    'Ik ben ook boven',
#    'Oke mijn grijze vak die zit helemaal onderin',
#    'links',
#    'daar heb je 3 vakjes he',
#    'onderin',
#    'de derde is het',
#    'nog niet open',
#    'jaaaa!!!!',
#    'thanks',
#    'waar s jouw grijs?',
#    'Deze gaat lukken',
#    'open?',
#    'nu naar kruis!',
#    'ben je er',
#    'hahaha',
#    'waar ben je ahahaha',
#    'kan je naar kruis?',
#    'oke waar is grijs',
#    'wat kan ik openmaken',
#    'ben er',
#    'open?',
#    'jaaa',
#    'was gelukt'],
#   ['oke waar zit het kruis',
#    'grijs vlak bedoel ik',
#    'oke wat heb jij nodig',
#    'ik kan namelijk niet naar het kruis toe',
#    'waar heb je grijs',
#    'nee onderin',
#    'tweede rij van onder linker vak',
#    'open?',
#    'ja',
#    'nu?',
#    'top',
#    'oke ik heb een vlak derde rij van onder tweede vakje van rechts',
#    'nee',
#    'nog niet',
#    'nu wel',
#    'ik ben in verkeerde gang',
#    'wat is deze',
#    'hahahha',
#    'nu zit ik gevangen',
#    'in de rij onder het kuis',
#    'kruis',
#    'en dan het middelste vakje',
#    'kun jij nog naar dat grijze vlak',
#    'grijs is derde',
#    'yes top[',
#    'ik sta er',
#    'jij dan'],
#   155.204),
#  (['yesss',
#    'okee',
#    'helemaal bovenin zie je 1 vakje he',
#    'daaronder 2',
#    'daaronder 3',
#    'ik sta links',
#    'van die 3',
#    'en ik moet langs 2 hekjes',
#    'zie ik',
#    'en jij',
#    'oke daar is mijn rode kruis ook',
#    'ik heb grijs 4e rij van onder',
#    '2e van links',
#    'kan je daar komen',
#    'ja supe!!',
#    'super!!',
#    'waar heb jij grijs',
#    'welke',
#    'ja',
#    'rechts',
#    'pen?',
#    'super!!'],
#   ['eindelijk yes',
#    'yes',
#    'ke',
#    'ik sta tweede rij van onder helemaal links die met die vijf vlakjes',
#    'waar zit grijs voor jou',
#    'open?',
#    'ik sta daar nu',
#    'top',
#    'derde rij van onder',
#    'die twee blokjes',
#    'dan rechts',
#    'dan kan ik naar het kruis toe',
#    'yes ik sya er'],
#   90.214),
#  (['teamworkkkk',
#    'bovenin heb je 2 blokjes he',
#    'daaronder 5',
#    'ik sta helemaal rechts',
#    'vandie 5',
#    'oke top',
#    'Ik heb grijs de 4e rij van onder',
#    'en dan 5e vak',
#    'maar die is lastig te bereiken',
#    'zie ik',
#    'eerst jouwe doen dan',
#    'waar is jouw grijs',
#    'top',
#    'heb hem open',
#    'open?',
#    'top',
#    'oke nu ben je dan boven',
#    'waar ben je nu',
#    '3e rij van boven?',
#    'omg daR Ben je',
#    'ga 1 naar boven',
#    '2e rij',
#    '4e vak',
#    'daar is grijs!!',
#    'nog niet',
#    'JA!!!!',
#    'kruis snel!',
#    'ben je kruis?',
#    'hahahahaha a',
#    'jammer',
#    'hahahaha',
#    'ja!',
#    'war is grijs',
#    'ja open?',
#    'ik ben er nu',
#    'kruis!!',
#    'yes!',
#    'hahhaha'],
#   ['oke waar sta jij',
#    'ik sta derde rij van onder met die drie aan elkaar dan in het midde',
#    'oke ja',
#    'waar is grijs',
#    'dan kan ik jou openen',
#    'die kan ik ook niet halen',
#    'ik heb grijs tweede rij van boven helemaal links',
#    'daar kun jij komen vgm',
#    'yes',
#    'waar was jouw grijs',
#    'dan kan ik openen',
#    'nu derde rij vierde vak vaanf links',
#    'vamaf',
#    'vanaf',
#    'moeilijk',
#    'hahahha',
#    'ja',
#    'open?',
#    'nu?',
#    'topppp',
#    'ja ik heb nog hekken',
#    'kun jij naar beneden',
#    'tweede rij van onder helemala rechts vlak',
#    'dat is grijs',
#    'eys',
#    'yes',
#    'hoppaa'],
#   189.888),
#  (['ze worden steeds lastiger he',
#    'je hebt onderin 1 rij',
#    'met 3 vakjes he',
#    'en dan de tweede rij',
#    '5e vak sta ik',
#    'wat is het middelste blok',
#    'ja vanaf L',
#    'daar sta jij?',
#    'oh ja',
#    'oke',
#    'waar is grijs',
#    'voor jou',
#    'ja',
#    'heb open?',
#    'ik be rechts',
#    'super',
#    'kan je al naar kruis?',
#    'ik moet nog 1 hek',
#    'waar sta je nu',
#    'dan leg ik uit waar grijs is',
#    'nu eerst mijn grijs zodat ik jouw grijs dan kan doen',
#    'anders sta je gevangen',
#    'zometeen',
#    'top',
#    'ik heb grijs',
#    'helemaal rechts bove in',
#    '2e vakje',
#    'niet de bovenste maar daarondr',
#    'top!',
#    'ja',
#    'waar is jouw grijs',
#    'ik ben nu aan linkerkant',
#    'van de maze',
#    'yes!!',
#    'die is bij mj ook grijs',
#    'heel toevallignu',
#    'jaaaaaa',
#    'haahhaa'],
#   ['ik sta in het middelste blok op de onderste',
#    'vanaf links?',
#    'die enkeltjes op de onderste rij',
#    'dan de middelste dus tweede vanaf links',
#    'yes',
#    'tweede rij vanaf onder en dna helemaal rechts',
#    'dat is grijs',
#    'daar kun je komen geloof ik',
#    'dan kan ik heel ver open',
#    'yes',
#    'ja',
#    'jij?',
#    'oh ik heb een hek voor het kruid',
#    'ik sta die vierde rijzesde blok',
#    'waar is jouw gijs?',
#    'open?',
#    'helemaal links en dan het tweede blokje van bovenm',
#    'zie je die',
#    'open!!!',
#    'hahah toeval'],
#   188.154),
#  (['super!',
#    'ik sta nu onderin',
#    'links',
#    '2e vakje van onder',
#    'ik moet langs 2 hekken zie ik',
#    'jij?',
#    'oke top, waar is jouw grijs',
#    'nee daar kan ik nog niet komen',
#    'eerst mijn grijs dan',
#    'daar ben ik',
#    'open?',
#    'Super!',
#    'Omg',
#    'mijne is open',
#    'ik zit kruis',
#    'jij?',
#    'jaaaa',
#    'Omg!!!',
#    'wat smooth'],
#   ['oke waar sta jij',
#    'ik sta vijfde rij van boven helemaal rechts',
#    'ik ook twee hekken',
#    'onderste rij tweede vakje vanaf rechts',
#    'maar die is onhaalbaar geloof ik',
#    'en ik heb nog heklemaal die linker kolom de allerbovenste',
#    'in de linkerbovenhoek',
#    'yes',
#    'waar is jouw grijs',
#    'want adners ben ik zo gevangen',
#    'wow sick',
#    'ik ook',
#    'wow dit was sick'],
#   105.611),
#  (['hahahahahh',
#    'okeee',
#    'ik zit eh',
#    '4e rij van boven',
#    'en dan 3e vakje van links',
#    'dicht bij mij dus',
#    'ik moet langs 1 hekje',
#    'waar is grijs?',
#    'bij jou',
#    'bij mij zit die helemaal onderin links',
#    'ja ik be daar nu',
#    'open?',
#    'omg yes',
#    'waar ben je nu',
#    'nee ik zit nog gevangen',
#    'mijn grijs zit helemaal links onderin',
#    'vanaf bove/',
#    '?',
#    'waar sta jij',
#    'grijs vlak is onderin links',
#    'helemaal in het uiteinde',
#    'ja je kan er komen',
#    'ik sta op jouw grijze vlak nu',
#    'ja',
#    'sne',
#    'ja!',
#    'jij?',
#    'ben je kruis'],
#   ['hahahhahhaha',
#    'ik sta vijfde rij van boven, rechtervakje',
#    'ja idd',
#    'waar zit jouw grijs',
#    'ik heb helemaal rechterkolom',
#    'het meest rechtse vakje',
#    'die kun je halen geloof ik',
#    'ja',
#    'jij?',
#    'nu sta ik derde rij tweede vakje van links',
#    'kun je dan nog een keer op dat grijs komne?',
#    'bedoel je links onderin of bovenin?d',
#    'het grijze vlak',
#    'ik sta derde rij van boven en dan helemaal links',
#    'oke als jij  naar het grijs kan',
#    'dan kan ik door het hek en jou bevrijden',
#    'open?',
#    'yes'],
#   150.903),
#  (['top',
#    'je hebt bovenin',
#    'linker vak',
#    'daar be ik',
#    'heleemaal bovenin',
#    'hahahhaha',
#    'oke ik moet langd 1 hek',
#    'jij?',
#    'waxht',
#    'mijn grijs is dichtbij',
#    'ga 1 naar boven',
#    'en 2 naar links',
#    'je staat toch in een alleen vakje?',
#    'mijn grijs is 4e rij van onder en dan 3e van rechts',
#    'kan je daa komen?',
#    'oke',
#    'waar is jouw grijs',
#    'we doen eerst jouwe',
#    'dat is effectiever',
#    'ja!',
#    'ben er',
#    'open?',
#    'super',
#    'ja',
#    'omg wacht',
#    'doe eens wat je net deed',
#    'het hekje was even open',
#    'zonet',
#    'nee',
#    'waar sta je?',
#    'nu',
#    'top',
#    'mijn grijs',
#    'zit daar',
#    '2e rij van onder',
#    'en dan 3e vakje van links',
#    'ja!',
#    'super!',
#    'kruis?',
#    'ben je kruis',
#    'oooo',
#    'snellll',
#    'waar is grijs',
#    'ja!',
#    'ben ik',
#    'ja',
#    'open?',
#    'nu kruis',
#    'j'],
#   ['wat stressvol dit',
#    'ik sta derde rij helemaal rechts in dat lonely vakkie',
#    'wat heb jij nodig',
#    'ik ook eentje',
#    'maar ik kan heel stuk bewegen',
#    'ik kan niet naar boven',
#    'hahahhaha',
#    'ik ben dat bovenste vakje helemaal links',
#    'nee dan moet ik hek openen',
#    'even kijken',
#    'mijn grijs is tweede rij van boven en dan meest rechtse vakje',
#    'kun je daar komen?',
#    'toppp',
#    'nu jouw grijs',
#    'open al?',
#    'dit?',
#    'ik sta nu derde rij van onder en derde vak links',
#    'open?',
#    'toppp',
#    'nee ik moet nog een hek',
#    'maar ik heb grijs onderin tweede rij van onder',
#    'en dan middelste vak',
#    'kun je daar komen',
#    'yesss',
#    'ik sat kruis'],
#   205.471),
#  (['oke',
#    'ik sta 3e blok van onder',
#    'meest links',
#    'jij?',
#    'oke ik moet angs 1 hekje',
#    'langs',
#    'maar heb veel ruimte',
#    'eerst jouwe doen',
#    'denk k',
#    'waar is houw grijs',
#    'jou',
#    'w',
#    'daar be ik',
#    'ben',
#    'nu',
#    'waar ben je nu',
#    'mijn grijs',
#    'is helemaal onderin',
#    'dat lonely vakje',
#    'heeelemaal onderin',
#    'ja!',
#    'kruis?',
#    'kan je kruis',
#    'hahahaha wooow',
#    'snel'],
#   ['ik sta tweede rij van boven tweede vak van links',
#    'waar zit grijs?',
#    'mijn grijs is vierde rij van onder derde vakje van links',
#    'daar kun je komen denk',
#    'oke nice',
#    'jij nu?',
#    'wat is jouw grijs',
#    'tweede rij onder meest links',
#    'open?',
#    'topppp'],
#   101.678),
#  (['oke',
#    'dit is raar',
#    'kun jij naar rechts ondeirn?',
#    'krisje',
#    'hoezo?',
#    'huh',
#    'ik sta het meest rechtsbovenin zeg maar',
#    'oke haaha',
#    'nee ik kan niet veel kanten op',
#    'ik kan alleen nog eentje naar links',
#    'dan naar onder',
#    'en dan eentje naar rechts',
#    'en dan heb ik hekje',
#    'nu ben ik los',
#    'ik ben naar helemaal rechtosnderin',
#    'oh nee ik ben linksonderin',
#    'o jemig zeg',
#    'ja',
#    'ja',
#    'ja',
#    'ja',
#    'oke',
#    'niet in de buurt',
#    'kun je naar de meet links onderin?'],
#   ['rwerg',
#    'ah nice',
#    'daar ben ik nu',
#    'oke vreemd',
#    'van jouw kruisje',
#    'is een switch voor mij en de hekkengaan niet open',
#    'oh jah sorry ik ben vaag',
#    'oke ehm',
#    'kun jij nu helemaal naar recths onderin?',
#    'oke',
#    'wat vaag dit want mij hekjes blijven dicht',
#    'oke kun jij',
#    '2 naar boven',
#    '1 links',
#    '2 boven',
#    '1 rechts',
#    'ik sta nu op mijn kruisje helemaal links bovenin',
#    'heb jij daar ergens een 2e switch'],
#   260.483),
#  (['ja',
#    'kun jij naar helemaal links boven in komen? Dat is de tweede rij',
#    'zeg maar',
#    'oke',
#    'ik ben daar',
#    'ja ben ik nu',
#    'ja',
#    'snap ik niet',
#    'niet aan elkaar?',
#    'oke weetje wat laat maar',
#    'in de middelste rij (waar dus drie rijen boven zitten en drie rijen onder) kun je dan in het tweede blokje van rechts komen?',
#    'kruisje'],
#   ['oke jammer',
#    'nee hekje',
#    'waar ben jij?',
#    'kun jij helemaal naar uiterste links boven?',
#    '1 naar onder',
#    'ik zit nu op mijn kruisje. Dat is die rechts in het midden onderste uitsteeksel',
#    'je hebt in het midden',
#    'die langste rij',
#    '6 blokjes',
#    'helemaal rechts heb je dan zon eenzaam blokje',
#    'nee die zijn niet allemaal verbonden',
#    'puik'],
#   213.515),
#  (['test',
#    'switch op 4,6',
#    'kan niet verder dan 4e rij',
#    'kan je bij 7,3?',
#    'oh 4,6 sorry',
#    'ben op 5,6',
#    'kan bij X'],
#   ['test',
#    'ok heb een switch op 5e 6e',
#    'ben bij 5 6',
#    'benn u bij 7 3',
#    'same'],
#   81.267),
#  (['switches op 1,4 en 5,3',
#    'sta op 5,2',
#    'ik nog niet, kan je bij 1,4?',
#    'of 5,3?',
#    'ja'],
#   ['switch op 3 2, 5 2 en 7 6', 'ben bij 1,4', 'kan bij x', 'nu?', 'wacht nu'],
#   42.5),
#  (['lets startt',
#    'to the white one right',
#    'ups hahahah',
#    'oh nooo',
#    'i didnt know we cant move where we want',
#    'i cant go to the left',
#    'i have a barrer',
#    'i just can move on the right part',
#    'do you can move any to the right',
#    'you can go like to the middle of the screen',
#    'like i think we should be both parts of barrers for open it, right',
#    'like in vertical',
#    'being in the middel',
#    'and you move all as you can close to the right',
#    'and me all close as i can to the left',
#    'like in the 3 square',
#    'the maximum you can go to the middle',
#    'to the center'],
#   ["Okay so let's start?",
#    'okay move yourself to the top square of the right',
#    'you know which one I mean?',
#    'Probably you see it white but for me is gray hahaha',
#    'So yes the one that is on the top at the right',
#    'wait wait',
#    'i cant hahaha i have the barrer',
#    'okay so move to the square that is most on the right',
#    'can you?',
#    'fuck so tell me where i have to move myself',
#    'Yess',
#    'Tell me',
#    '??',
#    'hahah which middle',
#    'hmmm okay',
#    'Im in the top middle one (the longest line) in the square most on the right7',
#    'is that?',
#    'something happens?'],
#   295.769),
#  (['okay, lets meet where',
#    'oh what happend',
#    'we open it',
#    'olee',
#    'not now any more',
#    'okay you should move to the botton part',
#    'any of the corners',
#    'and we get it',
#    'enough',
#    'go go go',
#    'opennn',
#    'close so fast',
#    'open again',
#    'what did you dooo',
#    'im in one grey of mine',
#    'now that i dont have barrers',
#    'guide me for you not having barreres',
#    'you have to tell me where to go i think',
#    'yes',
#    'i go',
#    'now',
#    'oh shit'],
#   ['okay lets try this',
#    'okay lets go to the one that is on the bottom in the rigth',
#    'can u?',
#    'something happen?',
#    "hahaha so you have any barreer open now'?",
#    'i can only go to the one in the right',
#    'can you go to any grey point?',
#    'okay i should stay hahaha',
#    'in the same square',
#    'Nothing is opening :(',
#    'Okay to open mine',
#    'You see the three top squares',
#    'its making an L',
#    'with 3 squares of tall and three of long',
#    'go to the end of the bottom',
#    'nope',
#    'in which are u hahaha',
#    'ohhh'],
#   290.409),
#  (['you',
#    'where do you want to go',
#    'okay',
#    'lets go',
#    'im gonna try',
#    'oh shit',
#    'i have it blocked',
#    'i cant go to the top part',
#    'can you go to the buttom',
#    'i have one therre',
#    'or in the top left',
#    'i also have one grey there in the corner',
#    'okay',
#    'im gonna try go',
#    'now',
#    'goooooood',
#    'now for me not this time hahha',
#    'lets go for other',
#    'on the top, the right corner',
#    'i have one thee',
#    'the second one if you start from the top',
#    'in vertical',
#    'the one to the most right',
#    'try',
#    'yes',
#    'im just go there',
#    'are you in your cross',
#    'or not still',
#    'where i have to go so',
#    'dont scream to me in caps',
#    'hahahha',
#    'now',
#    'i did',
#    'ayyy',
#    'runnn'],
#   ['we almost have it hhahaha',
#    'Okay who start',
#    'i have one grey in the top right one',
#    'fuck',
#    'so my other one is in the fourth level (starting from the bottom) the second one (starting from the right)',
#    'Im gonna try it',
#    'wooow',
#    'finally something open',
#    'so tell me yours now',
#    'hmm',
#    'okay',
#    'im in',
#    'okay now can you go to the cross?',
#    'nO, YOU HAVE TO OPEN TO ME',
#    'Ups sorry',
#    'So the one of the top line of the right',
#    'or the other that i told you',
#    'can you',
#    'wow i go',
#    'im in the cross',
#    'wooooow'],
#   276.705),
#  (['ole olee',
#    'i love this game',
#    'now that we pass one',
#    'start',
#    'i cant go there',
#    'i have barrers',
#    'oh shit i have barrers to all my squares',
#    'i just can move from the top part',
#    'the tree first levels in vertical',
#    'anything else',
#    'okay',
#    '4 line in vertical',
#    'the second one to the right',
#    'left',
#    'sorry',
#    'yes',
#    'olee',
#    'borders open',
#    'yes',
#    'now',
#    'amazing',
#    'tomaaaa'],
#   ['cracks',
#    'Okay next one',
#    'okay the third line from the bottom',
#    'you have two squares, the right one',
#    'can you go?',
#    'okay and the other is in the second line from the top, the left one',
#    'can you?',
#    'and tell me where you have yours',
#    'Okay hahaha',
#    'the second from the left',
#    'no?',
#    'can you go to any of mine now?',
#    'so open me and go to your cross',
#    'cool',
#    'im in the cross',
#    'wooow'],
#   170.495),
#  (['this is more bigger shit',
#    'its open now',
#    'perfectt',
#    'i need you to open mines now',
#    'so if you go to the right part',
#    'the second',
#    'in vertical',
#    'in the right part of the screen',
#    'the last column',
#    'the second one if you go vertical',
#    'from the top',
#    'olee',
#    'im in my cross',
#    'oh no',
#    'going where',
#    'yes',
#    'now',
#    'perfect'],
#   ['okay',
#    'Mines are in the second line starting from the bottom (the square of the rigth) and in the third line from the top (the rigth one)',
#    'Can you go? and tell me where you have yours',
#    'yesss',
#    'open hehehe',
#    'tell me yours',
#    'which line',
#    'okay hahaha',
#    'here?',
#    'but wow i need you to open me again',
#    'can yo go to any of my points and return to your cross?',
#    'yess'],
#   198.289),
#  (['I DONT KNOW',
#    'but now we know how to play on time',
#    'hahaha',
#    'we are improving',
#    'we have time to talk',
#    'lets go',
#    'i have one grey square in the third of the first colum of the left if you start form the top',
#    'from',
#    'now',
#    'go to mine',
#    'is just two down yours',
#    'not yet',
#    'the third one',
#    'perfect',
#    'lets goo',
#    'go again',
#    'its block',
#    'hahahaha',
#    'yes',
#    'wait',
#    'i need going to mine',
#    'dont move from there',
#    'now',
#    'OLEEE'],
#   ['how many levels are there hahaha',
#    'okay mines are in the top square of the left collumn and the other is in the bottom line, the second one startting from the right',
#    'yeeeah we are masters',
#    'yess',
#    'wait',
#    'im going to yours',
#    'is open yours?',
#    'fuck i was in the 4 hahaha',
#    'now?',
#    'where haahahaha',
#    'im in my cross',
#    'now?',
#    'okay hahaha'],
#   149.702),
#  (['me i have 3',
#    'i cant go to that one',
#    'i have in the second line starting from the top',
#    'in the thrid square',
#    'okay',
#    'lets try to go to others of mine',
#    'in the first line',
#    'the first one',
#    'of the left',
#    'to that one you can',
#    'yess',
#    'im gonna go to yours',
#    'one second',
#    'now you can',
#    'good',
#    'now i cant move from two squaes',
#    'im locked here',
#    'now',
#    'do that again',
#    'you open them for a second',
#    'now',
#    'wait',
#    'now',
#    'im my cross',
#    'go to yours',
#    'but im gonna be locked again',
#    'HAHAHAH',
#    'maybe we have to try open others of mine',
#    'where you have yours in the fourth from the botton',
#    'in the left i have a square',
#    'okay',
#    'now',
#    'now',
#    'sorry',
#    'i was confused',
#    'can i move now'],
#   ['okay',
#    'now i have only one square',
#    'in the fourth line (starting from the bottom), the left one',
#    'tell me where are yours',
#    "okay let's try if i open for you",
#    "i can't pass, i can only move in the top line:(",
#    'do you have any there?',
#    'okay',
#    'oh cool',
#    'this?',
#    'now you can go to mine?',
#    'no',
#    'oh wait yesss',
#    'okay now i can go to the cross',
#    'you?',
#    'hahaha where do you have more',
#    'okay but now you have to open me',
#    'hahahaha',
#    'im locked',
#    'hahaha so tell me where you have other squares',
#    'oh wait you already told me',
#    'okay but first open me hhahaha',
#    'runnnn',
#    'no',
#    'cool fuck we have the same',
#    'but then i cant retunr',
#    'tell me the other you have',
#    'fuck'],
#   293.552),
#  (['i have two this time',
#    'i cant go to that one',
#    'so try come to mines',
#    'one is 4 line',
#    'in the right',
#    'from the top',
#    'sorry',
#    'the one in the corner',
#    'okay',
#    'the other i have on the botton part',
#    'in the left one',
#    'can you go there',
#    'right',
#    'sorry',
#    'i have problems with left and right',
#    'hahahah',
#    'yesss',
#    'im in my cross',
#    'i go now',
#    'now',
#    'amazing',
#    'wow'],
#   ['okay i only have one again',
#    'you?',
#    'Mine is in the third line from the bottom, the second one in the right',
#    'Tell me yours',
#    'yess',
#    'xd',
#    'which line',
#    'wich one from the right',
#    'Ii cant go there hahaha',
#    'tell me other',
#    'here?',
#    'hahaha',
#    'now?',
#    'xdd',
#    'can you go to mine?',
#    'cool',
#    'nan',
#    'yes',
#    'im in my cross',
#    'wooow'],
#   173.637),
#  (['i have also two this time',
#    'perfet',
#    'okay, from the bottom part',
#    'the second line',
#    'the one of the right',
#    'okay the other is in the line fourth from the top',
#    'oh shit',
#    'tell me yours so',
#    'i cant go to the second line of the botton',
#    'in the middle where',
#    'nothing sorry',
#    'now',
#    'okay',
#    'yes',
#    'perfect',
#    'yess',
#    'perfect',
#    'im in the cross',
#    'yes',
#    'can you',
#    'okay',
#    'now',
#    'sorry',
#    'now',
#    'ahh',
#    'perfect'],
#   ['now i have two',
#    'tell me yours',
#    'i cant go',
#    'i only can move in the left collum :(',
#    'Mines are in the second line from the  bottom, the one of the middle',
#    'And the other in the second line from the top, the right one',
#    'and the other?',
#    '???',
#    'there are three, so the middle one',
#    'hahaha',
#    'yesss',
#    'okay and now i have to open to you',
#    'ok im going',
#    'here?',
#    'now can you go to your cross?',
#    'okay but i need you to open me again hahaha',
#    'can you go to mines again?',
#    'and dont get blocked?',
#    'yesss',
#    'eeee',
#    'no',
#    'what happen',
#    'open again',
#    'no',
#    'oh yess',
#    'im in the cross',
#    'you?',
#    'wow',
#    'cracks'],
#   216.851),
#  (['i have two too',
#    'i have both on the botton parts',
#    'lines 2 and 3',
#    'can you go to that lines',
#    'okay',
#    'but i just can move to one square',
#    'because im blocked',
#    'i cant',
#    'i just can do one movement if you dont open my borders',
#    'like im in the colum of the right',
#    'in the frist square',
#    'and then i just can go one dwon',
#    'and the i have a barer',
#    'so we cant do anything',
#    'something we should can do',
#    'but what',
#    'i dont know',
#    'hahahha',
#    'maybe we were not masters of this game',
#    '>*',
#    'the system hack us',
#    'you are sure you cant go to mines',
#    'im really blocked',
#    'like just can go to one square',
#    'you too',
#    'the third or second line',
#    'from the bottom',
#    'OPEN',
#    'WHERE DO YOU HAVE YOURS',
#    'WAIT',
#    'i have no time',
#    'no worries'],
#   ['okay i have 2 again',
#    'i cant go so go to mine first',
#    'mines are in the fourth line, the second one in the left',
#    'ot in the second line from the bottom, the one of the right',
#    'I cant go outside hahah',
#    'Im trapped in the second collumn in the left',
#    'wow so we cant do anything or what',
#    'hahahah',
#    'yes it looks like that',
#    'hack the system',
#    'wow dont start now jajajaj',
#    'same',
#    'im gonna check again but idk',
#    'Fucking hell i can go to one',
#    'But now is late hahaha',
#    'can you go to mines now?',
#    'i told u',
#    ':(',
#    'sorry'],
#   285.599),
#  (['ik heb 1,3',
#    'ja top',
#    'wacht kun je naar het kruis zo?',
#    'ik sta op het kruis'],
#   ['oehh',
#    'nu blivjen we het zien',
#    'ik kan niet bij 1,3',
#    'ik heb 6,7',
#    'en 1,1',
#    'je kunt naar het kruis',
#    'sta je erop?',
#    'ja'],
#   59.655),
#  (['1,7', 'enige', 'kun je bij het kruis straks?', 'ben er'],
#   ['oke',
#    'die doe ik zo',
#    'ik moet 3,1',
#    'of 7,3',
#    'eerst',
#    'je kunt naar het kruis',
#    'ja',
#    'sta je erop?'],
#   34.265),
#  (['Hey bro',
#    'I will stand on the switch first if you like?',
#    'Okay, one second',
#    'Okay I understand now',
#    'Okay... can you stand on the grey switch at the bottom?',
#    'Thats the one I need',
#    'Yes, but the bottom one for me is grey. If you stand there, then my gate will open',
#    'okay... what about the most far right square?',
#    'Can you reach that one?',
#    "Okay, looks like I'll have to stand somewhere first",
#    'where should I go?',
#    'the one next to the furthest right?',
#    "cool I'm on it",
#    'are you at your x?',
#    'Hmm'],
#   ['hey man',
#    'okaz',
#    'let me know when you are there',
#    'no',
#    'I have different',
#    'my is on the top',
#    'okay',
#    'but i cannot go there because there is gate',
#    'i cannot go through',
#    'blocked for me',
#    'okay so, can you go to the top<',
#    '?',
#    'right one',
#    'yes',
#    'okay',
#    'so now what',
#    'I mean the gate is still closed'],
#   289.236),
#  (['Can you get to the third from the top?',
#    'I have one grey square for you, it is the third from the top (if you see the line of squares on the far left)',
#    'okay going',
#    "I'm in the top left corner",
#    'Did it work though? The first?',
#    'Hooray',
#    'Now can you go to the third from the top?',
#    'Two below the one you wanted me on',
#    'Im here!',
#    'Great',
#    'Good work',
#    'Yahoo!',
#    "I'm on my x"],
#   ['lets start with the position of ours grey parts',
#    'no i cannot, i am on the right sight',
#    'on top left corner is one',
#    'and the second is on the bottom line from right',
#    'I have open gates',
#    'I am on X',
#    'yes I am there',
#    'lets go to x now<',
#    '?'],
#   135.107),
#  (['Okay, I have two grey squares: one on the far right, one is the second on the left',
#    'Okay im there',
#    'okay',
#    'same!',
#    'going now',
#    'oh wait they closed',
#    'go back',
#    'yes!',
#    'on the x',
#    "I'm on your grey area I think",
#    'Is it open?',
#    'me too',
#    "let's do it :D"],
#   ['okay, I am on the bottom',
#    'my grey parts are> first is on the top, right under the top point',
#    'the second is 3 line from the bottom, on the right side',
#    'I have gates open',
#    'is it open<',
#    'I am locked in that gate now',
#    'I cannot move anywhere',
#    'open my gate and lets try the other grey parts',
#    'yes',
#    'I can go to x'],
#   174.361),
#  (['same',
#    '1 - far left, bottom one; 2 - second row from the bottom, the right one',
#    'Okay',
#    "You will have to go first, I can't get to those",
#    'great',
#    "I'm through",
#    'okay can you open my gates again? Im now stuck',
#    'Im on x',
#    "We're really good at this, no?",
#    'okay this one is a bit harder',
#    'you need to open me again',
#    'before I can open you',
#    'yes',
#    'wait, just finding yours',
#    'no',
#    'yes'],
#   ['2 grey parts',
#    'the second bottom line, right side and the second column from the left, 2nd from the bottom',
#    'okay',
#    'I am on x',
#    'can you reach it?',
#    'I am locked now',
#    'oppen me',
#    'and I will go to the other place',
#    'that will probably open everthing',
#    'is it open?',
#    'open me now',
#    'ok',
#    'can you reach x',
#    '?',
#    'now?'],
#   234.13),
#  (['oaky three gates',
#    'three greys I mean',
#    '1 - top row, left square; 2 - second row from top, third square; 3 - fourth row from top, left square',
#    'okay you will have to open',
#    'thanks',
#    'wait',
#    'yes',
#    'now I am stuck',
#    'awesome',
#    'on x',
#    'damn!',
#    'third from left',
#    'open. same',
#    'ill go',
#    'here'],
#   ['is it always the second way if it doesnt work',
#    '1 grey, three gates',
#    '4th line from the bottom, left side',
#    'I have just one',
#    'okay zyou opened me',
#    'I am stuck now',
#    'open me ... I think I need to manage that',
#    'where is your second? is it third from left or right?',
#    'okay, how is it now for you?',
#    'I can go to x'],
#   197.557),
#  (["do you think we're the best at this?",
#    '2 greys, 1 gate',
#    'dont say that',
#    '1st: fourth row from top, third square. 2nd: bottom row, third square',
#    'I cant reach yours',
#    'yes',
#    'same'],
#   ['1 grey, 2 gates',
#    'no, we are playing 40 more minutes >D we can be the worse',
#    '3rd line from the bottom, the second from right',
#    'there is my grey part',
#    'yyours?',
#    'go through',
#    'can you?',
#    'I am on x'],
#   137.589),
#  (['three, three',
#    '1st: 4th row from top, second square from right; 2nd: bottom row, far left; 3rd: bottom row, far right',
#    'me not',
#    'yes'],
#   ['2 greys, 2 gates',
#    'third line from top, 3 rd from left',
#    'the right bottom corner',
#    'I am on x',
#    'now?'],
#   96.999),
#  (['4 grey, 2',
#    '1st: second row, far right; 2nd: third row, far left; 3rd: far bottom left corner; 4th: second row from bottom, third square from right',
#    'are your gates open?',
#    'now?',
#    'okay I had the wrong one',
#    'on x',
#    'now?',
#    'now?'],
#   ['2,2',
#    'sorry, 2 grey, 3 gates',
#    'right bottom corner and the second from the top on the first column from the left',
#    'I cannot reach any',
#    'my gates are closed',
#    'yes',
#    'how it looks?',
#    'I cannt',
#    'open me gate',
#    'no',
#    'I am there'],
#   231.452),
#  (['so good',
#    "You're awsome at this btw",
#    'two greys, two gates',
#    '1st: second row, second from right; 2nd: fourth row, second from right',
#    'now?',
#    'okay are your gates open?',
#    'go to x',
#    'sorry'],
#   ['we are killing it',
#    '3 greys, 2 gates',
#    '1st / bottom line in the middle, 2nd>2nd line from the bottom on the right side and 3rd> the second row, first from the left',
#    'I cannot reach any',
#    'yes',
#    'you?',
#    'yes',
#    'I can reach x',
#    'its locked now',
#    'i am there'],
#   143.853),
#  (['2 greys, 1 gate',
#    '4th row, third square from right ::: second row from bottom, right square',
#    'go',
#    'yes',
#    'you?',
#    'okay im going'],
#   ['2 greys, 3 gates',
#    '1st / 2nd line, right one',
#    '2nd/ the second bottom line in the middle',
#    'can you go to x?',
#    'yes'],
#   101.011),
#  (["What's up babygirl :)",
#    'bottom left',
#    'last row to the far left',
#    "that's one grey area",
#    'would you mind going there pls?',
#    'okay, where are your grey areas?',
#    'the time running out freaks me out a lil bit',
#    'cant go there I need another one',
#    "I think I'm standing on there",
#    'ah dope',
#    'can you go to the cross now?',
#    'yup!'],
#   ['Heya :)',
#    ':D',
#    "Let's do this!",
#    'Is where your cross is?',
#    "Ah okay, I can't everything that's the first three rows from the left I can't reach",
#    '*anything',
#    'Haha same!',
#    'My grey areas are very bottom right hand corner',
#    'and third row from the left, third row from the top',
#    'Can you go there?',
#    'Niiice!',
#    'Yup, one sec',
#    'Open?'],
#   322.718),
#  (['okay so you need to step on one of my grey areas',
#    'I cant go anywhere basically',
#    'please go to fifth from the top, far left',
#    "I'm on the croos",
#    'cross',
#    'where are yours?',
#    'works?',
#    'dopeee',
#    'I dont have to go back to my cross do I?',
#    'well then I need you to go back to the grey thingy',
#    'aaah I',
#    'okay',
#    'my cross iy the furtuhest down on the maze',
#    'is there a grey area close to the one at thevery bottom?',
#    'quiiiiiiick',
#    'I cant go there I dont think',
#    'uff'],
#   ['Okay, where is it?',
#    'Here?',
#    'One row above, one cell to the right of where yours is',
#    'Yes, on the cross rn',
#    'I think you do',
#    'Can you?',
#    'nan',
#    'haha nooo, now mines closed again',
#    "Yup, The one that's closest to the bottom one row to the right",
#    'Welp'],
#   282.874),
#  (['okay we got this',
#    'where do you need me to go?',
#    'my cross is 4 from the top, three from the left',
#    'anything further up?',
#    'IÄM in the right corner',
#    'on it',
#    'I need you to go from your cross, one up and one left',
#    'yup',
#    "yes, I'm on the cross"],
#   ['My X is second row to the right, the one thats furthest down',
#    'grey areas: Bottom row, middle one',
#    'second from bottom far right',
#    'and second from top all the way left',
#    "Where's your areas?",
#    'Ah, shoit. Can you go back to the grey area?',
#    'nice, yours open?'],
#   192.493),
#  (['cross: 2 from top, 3 from right',
#    'I would need a grey area somewhere in the bottom half of yours',
#    'where is your cross?',
#    'yup one ot the right from the one you send me to, the secon choice',
#    '3 bottom, three from left',
#    'yup perfecto'],
#   ['Perfect, either bottom right or three from bottom second from left',
#    'You got any greys in the bottom three rows`?',
#    'This one?'],
#   120.645),
#  (['cross: bottom, right',
#    'I need a grey one of you in the left thingy',
#    'okay so our crosses are opposite basically',
#    'I can get to the left side and one to the right',
#    'okii',
#    'can you go to the third from the top?',
#    'yup'],
#   ['Cross top left',
#    "Well, all the way up top is the grey, the cross's one beneath :)",
#    "Where's your greys?",
#    'Here?'],
#   95.553),
#  (['cross is 2 from bottom, far left',
#    "I'm in the upper half",
#    'any greys for you there?',
#    'my grey is from your cross three to the left',
#    'but first yours',
#    '4 from bottom',
#    'second from left is my grey',
#    'yup',
#    "I'm on the cross",
#    'where are you?',
#    'whoops my bad omw',
#    'okay now pls go three to the right',
#    'left',
#    'and go back :)',
#    'yup'],
#   ['Cross: four from bottom, far right',
#    'I can do greys in the lower four',
#    'And yes',
#    'second from top, left',
#    "Still on the grey, my gates aren't open yet",
#    'On the cross',
#    'Ah no, my gates closed again',
#    'wait',
#    'can you go',
#    'one right one up from your cross?'],
#   228.607),
#  (['ookay, my cross is top row, left',
#    "I'm somwhere in the bottom",
# ...
#    'f5 is bij mij de grijze',
#    'Zijn we open?',
#    'f4 kan ik ook niet bij',
#    'Nu?',
#    'Wacht doen we linksboven als a1 of rechtsonder?',
#    'linksonder bedoel ik',
#    'c7 kan ik ook niet bij',
#    'Oh wacht nu dan?',
#    'yes'],
#   262.798),
#  (['G2 en E7 zijn mijn grijze vlakken',
#    'Ik sta nu op e4',
#    'Nee',
#    'Bij jou?',
#    'Kan je bij G2 komen?',
#    'oh open',
#    'Ik kan nu bij kruisjke komen'],
#   ['pff het is even uitvogelen haha',
#    'Ik ben b2',
#    'grijs is c1 of e4',
#    'Zijn ze open bij jou¿',
#    'Ja',
#    'Ik ben bij e7',
#    'gelukt?'],
#   116.029),
#  (['D1 en C5 zijn bij mij de grijze vakken',
#    'Kan je bij het kruisje komen? ik wel',
#    'Ah oke',
#    'Nu dan?',
#    'Ik kan er bij'],
#   ['grijze zijn b5, c2 en f7',
#    'Ik nu ook',
#    'Ah net te laat haha',
#    'Ging net dicht',
#    'Kan jij er nu bij of moet ik nog terug?',
#    'Ah nice, ik ben er'],
#   86.692),
#  (['E4 en D6 bij mij', '^^', 'Ik kan nu bij het kruisje'],
#   ['Grijze zijn c6 en e2', 'Daar kan ik niet bij nu', 'Nu wel :)', 'Ik ook'],
#   64.957),
#  (['Ik kan nergens bij',
#    'B4, G6',
#    'Oh nog een keer open?',
#    'Dan kan ik bij D5',
#    'En dan daarna bij het kruisje',
#    'Ik kan nu bij doel'],
#   ['Grijze zijn d2 en d5', 'Ik ben bij het doel'],
#   76.295),
#  (['A3 is mijn enige',
#    'Ja maar alleen als je op een grijs vlak blijft staan',
#    'Ik sta nu op doel'],
#   ['Grijze zijn A1 en F7', 'Kan je er bij?'],
#   58.279),
#  (['A3, A7, E6 en G2', 'Ik kan nu bij doel'],
#   ['Grijze zijn A3 en G6', 'Ik ook'],
#   66.533),
#  (['A5 en E6',
#    'Kan nog niet bij doe van jou',
#    'Ik zit vast op E6',
#    'Ben nu bij het doel'],
#   ['Grijze zijn B4 en E6', 'Ik kan bij het doel'],
#   71.153),
#  (['Okay',
#    'I am on the second row from the bottow on the 5th room',
#    'where is your switch',
#    'haha yes this is weird',
#    'You stood on my swiych',
#    'yes',
#    "Ok I'm on the x in the first colomn",
#    'here?',
#    'tgis one?',
#    'this one',
#    'nice'],
#   ['Okay I am in the bottom row, center',
#    'Right most room in the corner',
#    'second row from below',
#    'I forgot to hit enter',
#    'can you reach the goal?',
#    'now I am blocked of again ahaha',
#    'i have a door right in front of the X',
#    'I have another swithc In the first Column from left and third row',
#    'sorry second row',
#    'no',
#    'first column from left and then second room from top down',
#    'okay!',
#    'yes'],
#   275.196),
#  (["I'm third row from top and first room",
#    'Do you have a switch on the top?',
#    'My siwtch is on the fourth row second room',
#    'am I standing on your switch?',
#    'now',
#    'Okay',
#    'no',
#    'fourth row second room ?',
#    'yess',
#    'go back',
#    'haha',
#    'yesss',
#    'I can reach the x now',
#    'where is your switch'],
#   ['okay I am now in the sixth row and third column',
#    'Yes in the second row the left one',
#    'No',
#    'Am I on your?',
#    's',
#    'yes',
#    'can you reach the X?',
#    'that one?',
#    'sorry',
#    "okay I can't",
#    "there's another switch 5th row and right room",
#    'yesss',
#    'great'],
#   224.52),
#  (['oke',
#    'done',
#    'nee',
#    'kan jij linksonder',
#    'huh',
#    'oke uhm',
#    'kan jij rechtsonder',
#    'ik sta kruis',
#    'maar nu jij',
#    'lol',
#    'wacht',
#    'kan je nu?',
#    'ja nu sta ik cast',
#    'lol',
#    'rechtsonder',
#    'linksonder',
#    'of',
#    'rechtsboven en 1 naar onder',
#    'ja',
#    'en jouw vakjes?'],
#   ['ik heb een plan',
#    'kun je naar linksonder?',
#    'rechtsonder bedoel ik haha sorry',
#    'oke',
#    'zeg jij het maar',
#    'niet helemaal',
#    'ja',
#    'ik sta rechtsonder',
#    'mijn grijze vakjes zijn helemaal rechtonder en ergens anders',
#    'ja!',
#    'oh',
#    'wacht het komt goed',
#    'waar moet ik staan voor je hekjes?',
#    'oke ik kan nu naar linksonder',
#    'is het nu goed?',
#    'ja ook'],
#   192.228),
#  (['congratz',
#    'onder',
#    'rechtsboven',
#    'jij?',
#    'welk midden',
#    'deze?',
#    'deze?',
#    'jeez',
#    'vgm was dat mn beginpunt gwn',
#    'kan jij onder of',
#    'helemaal rechsboven',
#    'ja',
#    'done',
#    'kan jij nog',
#    'o'],
#   ['hahaha',
#    'even denken',
#    'het meest bovenste stukje en dan rechts daarin',
#    'of ergens in het midden',
#    'het was net goed!',
#    'kun je dat nog eens doen? ik was te langzaam',
#    'nee',
#    'ja',
#    'dankje',
#    'nan',
#    'waar moet ik voor jou staan? onder toch?',
#    'ik sta nu onder'],
#   145.76),
#  (['goed idee',
#    'waar is a',
#    'waar zijn letters',
#    'y as?',
#    'x as?',
#    'oke',
#    'b6',
#    'd5',
#    'ik sta toch b3?',
#    'ja',
#    'done'],
#   ['is het niet handiger om A1 B1 enzo te zeggen?',
#    'is goed',
#    'y as',
#    'nummers zijn horizontaal',
#    'ik kan er niet bij',
#    'b3',
#    'g3',
#    'f5',
#    'lukt dat?',
#    'yes klopt',
#    'ik sta op d5',
#    'lukt het?'],
#   166.315),
#  (['uh',
#    'ja',
#    'f4',
#    'd5',
#    'is nu wel makkelijker voor mij',
#    'doe maar wat makkelijkst is',
#    'hangt van je plaatje af',
#    'oh',
#    'zelfde',
#    'nvm',
#    'zeg maar iets',
#    'hahahhaa',
#    'ty',
#    'f3 best'],
#   ['oke vind je dit lastiger werken dan zonder het systeem?',
#    'meid snel',
#    'oke dan doen we het oude',
#    'oh',
#    'oke dan houden we het zo',
#    'maakt mij niet uit',
#    'ik kan er niet bij',
#    'kun jij naar ...',
#    'B5',
#    'oke kun je nu terug naar B5 komen?',
#    'of naar',
#    'F3',
#    'nog eens?',
#    'ik was langzaam',
#    'dankje'],
#   164.828),
#  (['rechtsonder',
#    'links en 1 naar rechts',
#    'ja',
#    'jij?',
#    'ik niet',
#    'miss moest ik e4 gaan',
#    'dat is beter',
#    'dan word ik niet ingesloten',
#    'hoop ik',
#    'nou ik kan sws nergens heen nu',
#    'bevreid me',
#    'ij',
#    'ja en kan jij nu'],
#   ['nu?',
#    'B4 of',
#    'E4',
#    'oke ik sta',
#    'oke moment',
#    'mijn eindpunt is heeft twee hekjes aan weerszijden dus ik kan nergens anders heen',
#    'oke lukt dat of moet ik iets doen?',
#    'hahaha',
#    'oie',
#    'oke kun je naar e4?',
#    'ja top'],
#   146.701),
#  (['e3', 'a4', 'ja?'],
#   ['ik sta op a4',
#    'kun jij naar b3 of',
#    'e2',
#    'zou je dat nog eens kunnen doen?',
#    'dankje',
#    'sta je goed?'],
#   63.078),
#  (['ja', 'ja', 'onderste rechts', 'of d meest rechtse', 'nan', 'ja', 'ik ook'],
#   ['oke ik heb alleen e6', 'lukt het al?', 'ik sta'],
#   44.344),
#  (['hahahah zit klem',
#    'hoop op jou',
#    'oke',
#    'meest links onder',
#    'of',
#    'ja',
#    'jij',
#    'kom wel klem dan',
#    'kom sws klem',
#    'nou we gaan het zien',
#    'ik sta',
#    'uh',
#    'ergens',
#    'helemaal links onder',
#    'of f5',
#    'ja'],
#   ['zeg het maar',
#    'oke',
#    'd2?',
#    'oke wacht',
#    'f5?',
#    'oke doe maar iets',
#    'oke',
#    'moet ik naar de onderste?',
#    'werkt dit?'],
#   139.682),
#  (['bovenste links',
#    'o',
#    'zeg maar',
#    'ja maar',
#    'waar moet ik heen voo rjou',
#    'moet weten',
#    'oke voor mij',
#    'd3',
#    'of',
#    'b3',
#    'of bovenste rij links',
#    'ty'],
#   ['oke ik sta vast op rij A', 'werkt het?', 'd3', 'oke bedankt'],
#   66.228),
#  (['links 3e van boven', 'ja', 'ja', 'ik sta'],
#   ['red ik niet', 'kun je de bovenste?', 'oke', 'ben je nu ook vrij?'],
#   41.596),
#  (['hoi',
#    'mijne zijn 3e van links bovenaan',
#    'nee sorry fout',
#    'bovenaan en dan de 3e van links of 3e rij van onder en dan 3e van links',
#    'Ik kan allemaal niet heen',
#    'ja ben erdoor',
#    'ik ben op een van jou',
#    'kan jij naar kruis',
#    'nu?'],
#   ['Hoi',
#    'Ik heb 3 vakjes',
#    '4e rij van van boven tweede van links',
#    'Onderste rij helemaal rechts',
#    'Of tweede rij van boven tweede van links',
#    'Ik ben nu op een van jou',
#    'Nee',
#    'Je staat op de verkeerde',
#    'Ja',
#    'Sta op kruis'],
#   143.8),
#  (['ik heb maar 1: aller onderste links', 'ben er', 'ben het op het kruis'],
#   ['nan',
#    'Mijne zijn het meest rechter vakje of het rechter vakje van de bovenste rij',
#    'Ik kan niet naar de jouwe',
#    'Ik sta op jou grijze vakje',
#    'En kan nu naar kruis'],
#   52.991),
#  (['hoi',
#    'ja',
#    'kin wol',
#    'ja',
#    'bij mij is er op 1,5 een grijs vak',
#    'ga daar eens op staan',
#    'ik sta nu op 1',
#    'gebeurt er wat',
#    'huh',
#    'gaat er niks open',
#    'ik kan verder niks',
#    'ja',
#    'als je op een grijs vakje staat gaat er bij jou een hekje open toch',
#    'ik sta op de x'],
#   ['hola',
#    'het doolho is 7 bij 7',
#    'how about coordinaten',
#    '(x, y)',
#    'ik heb grijze vakjes bij (6, 1) en (7,1)',
#    'jij moet dan eerst voor mij wat openen',
#    'nog niet',
#    'nope',
#    '(horizontaal, verticaal) right',
#    'jup',
#    'kan jij nu verder>',
#    '?'],
#   290.255),
#  (['6,4',
#    'vanuit waar doe jij de coords',
#    'linksonder is 0,0 doe ik steeds',
#    'ik kan niet bij 6,3 komen',
#    'huh',
#    'ohh wacht',
#    'werkt het',
#    'nee dit klopt ook niet',
#    'dus linksonder is 1,1',
#    'ja dan kan ik echt niet bij 6,3 komen',
#    'haha',
#    'bruh'],
#   ['(6, 3)',
#    'ja same',
#    'jij moet eerst 6,3 voor mij openen',
#    '6, 4 is afgesloten',
#    'hmm',
#    'duurt 3 seconden',
#    'jep',
#    'daar rechts van is 2,1',
#    'ja ik ook niet bij 6,4',
#    'shit hier gaan we weer',
#    'we zijn garbage'],
#   280.914),
#  (['3, 6',
#    'mijn goal is bij 4,1',
#    'ik kan niet bij 3,4 komen',
#    'mijn grijze vakjes zijn: 3.6 & 4,7 & 3,4',
#    'ja ze gingen open bij mij',
#    'ik sta op de x',
#    'ok ik niet',
#    'ik zit vast',
#    'ok jij gaat op die andere staan',
#    'en dan aftellen',
#    'ja',
#    'ik kan er nu opsich heen',
#    'tegelijk oke',
#    'naar de x',
#    '3',
#    '2',
#    '1',
#    'nU'],
#   ['(3, 4)',
#    'en mijn goal is bij (2, 6)',
#    'ik kan in de bovenste rij',
#    'met die 4 rechter vakjes',
#    'zijn we nou retarded?',
#    'wat gebruik jij nou als nulpunt?',
#    'linksonder right>',
#    '?',
#    'zoals bij wiskunde',
#    'je hebt het',
#    'ja ben nu bij shiet ik niet',
#    'kan je terug gaan naar waar je net stond?',
#    'ik ben nu bij x',
#    'gaan ze nu open?',
#    'ik kan er nu gewoon heen',
#    'ook zonder jou'],
#   240.83),
#  (['We zijn denk ik te goed voor dit spel',
#    '1,3 & 5,2',
#    'kan je',
#    'ik niet meer',
#    'zonet wel',
#    'nu kan het',
#    'ok weer tegelijk',
#    '3',
#    '2',
#    '1',
#    'nee ik niet meer',
#    'alles is dicht',
#    'nu wel weer',
#    'ok',
#    'tegelijk naar de x',
#    '3',
#    '2',
#    '1'],
#   ['we did it',
#    '(2, 4)',
#    'is voor mij',
#    'ik ben nu bij 1,3',
#    'ik kan naar x',
#    'jij ook?',
#    'nu?',
#    'ik kan nog steeds naar x',
#    "so it don't matter",
#    'ik ga terug',
#    'zeg maar als je op x staat'],
#   135.278),
#  (['yeahh h ha', '3,3 & 4,7', 'ik ook', 'ben op de x'],
#   ['3,6 2,3 en 6,1', 'yo ik kan naar x', 'aftellen hoeft niet'],
#   69.383),
#  (['ok nice',
#    '2,4 en 7,2',
#    'ok ik kan',
#    'nu niet meer',
#    'ff opnieuw',
#    'ok',
#    '3',
#    '2',
#    '1',
#    'nee weer',
#    'alles dicth',
#    'sta op de x',
#    'ik sta nu op een andere',
#    'je kan naar de x',
#    'ik heb geen hekkies verder'],
#   ['4, 3 en 4,6',
#    'ik sta op 2,4',
#    'ik sta op x',
#    'oke nu wel aftellen',
#    'alright',
#    'gewoon spammen die handel',
#    'nu kan ik er niet meer heen',
#    'x is afgesloten',
#    'open nog eens',
#    'alright',
#    'mooi'],
#   145.933),
#  (['je kan er dus echt naartoe bewegen',
#    '3,1 en 6,4 en 7,1',
#    'ja',
#    'nee',
#    'ik sta erop'],
#   ['7, 1 en 3, 5',
#    'nu open?',
#    'nu weer right?',
#    'ik kan vanaf heir naar x',
#    'ik heb geen hekjes meer tussen mij en x'],
#   83.838),
#  (['1,1', 'ik ook'],
#   ['7, 5 en 3, 7', 'ik heb geen hekjes meer tussen x en mij'],
#   35.678),
#  (['5,1 en 7,6', 'kom maar door'],
#   ['3, 7 en 5, 4', 'ik kan naar x zonder hekjes'],
#   32.971),
#  (['5,4 en 6,6', 'haha', 'jo', 'ga'],
#   ['epic victory royale', '3,1 en 5, 2 en 3, 6', 'ik kan naar x vanaf hier'],
#   59.823),
#  (['okok',
#    'Nee nog niet',
#    'Die van mij is op 4-5',
#    'Kan jij daarbij?',
#    'Ik kan niet bij 6-6 volgens mij',
#    'Ah, ja',
#    'Ik ben er',
#    'Open?',
#    'En nu?',
#    'Nu is mijn gate dicht',
#    'Nee',
#    'Kan je bij  2-4?',
#    'Of 4-5',
#    'Ik ben er al doorheen',
#    'Sta op rood',
#    'Ik ben bij 2-3'],
#   ['Nou laten we er een matrix van maken',
#    'Onderste uitsteeksel is 1-4?',
#    'Mijn grijze vlakje is op 2-3',
#    'Kan jij daarbij?',
#    'Nee',
#    'Mijn andere grijze vlakje is op 6-6',
#    'Kan jij daarbij?',
#    'Ik kan maar op 3 vakjes bewegen dus jij moet mijn gate wss wel eerder openen',
#    'Open?',
#    'Jij moet nu nar',
#    'naar',
#    'Nee',
#    '6-5',
#    'Was het',
#    'Keek net verkeerd',
#    'Kan jij 6-5?',
#    'Mijn gates zijn nu dicht',
#    'Ik sta nu op het kruis',
#    'Kan jij nu naar het rode kruis?',
#    'Ja',
#    'Ik kan bij beide',
#    'Sta nu op 4-5',
#    'Ik dus niet',
#    'Staat bij mij nog 1 gate voor',
#    'Kan jij 2-3 of 6-5?',
#    'Nja is al bijna afgelopen'],
#   282.767),
#  (['Mijn grijze vakje is 1-5',
#    'Ik sta nu op 1-6',
#    'Alleen 1-6',
#    'Staat er nu een poort open bij jou?',
#    'En nu?',
#    'is 7-1 de bovenste links voor jou?',
#    'Dan bedoel ik 5-1',
#    'Dat is mijn grijze',
#    'Ja',
#    'Ik ben op rood'],
#   ['Kan jij bij 1-6?',
#    'Mijn grijze vlakken zijn 1-6 en 7-1',
#    'Waar zijn die van jou?',
#    'Open?',
#    'Nee',
#    'Ja',
#    'Ja',
#    'Open?',
#    'Ga naar kruios'],
#   99.605),
#  (['Grijs is 1-1', 'Open?', 'Ja'],
#   ['Mijn grijze vlakjes zijn 5-7, 7-3',
#    'Ik kan 1-1 als jij gates opent',
#    'Kan jij naar 1 van mijn grijs',
#    'Open?',
#    'Ga kruis'],
#   38.669),
#  (['4-2 en 7-2', 'Ja', 'Ik sta op rood nu', 'Open?'],
#   ['Grijs = 3-4, 6-4',
#    'Open?',
#    'Ik niet',
#    'Mijn gates moeten open',
#    'Ik moet eerst op rood',
#    'Ja sta nu op rood',
#    'Kan jij bij rood?'],
#   62.827),
#  (['3-1 en 2-5',
#    'Open?',
#    'Ik moet nog 1 gate',
#    'Nee',
#    'Hij is niet open bij mij',
#    'Ja',
#    'rood'],
#   ['2-5, 4-2',
#    'Kan jij naar een vak van mij?',
#    'Ik sta nu 3-1',
#    'Ja ben erdoorheen',
#    'Open?',
#    'Ga rood',
#    'Open?',
#    'Ga rood'],
#   74.53),
#  (['1-3, 1-7, 4-6',
#    'Open?',
#    'Open?',
#    'Open?',
#    '1-3, 1-7, 4-6',
#    'Ja',
#    'Kan je bij rood?',
#    'Ga rood'],
#   ['1-7, 3-4',
#    'Nee',
#    'Nee',
#    'Wacht',
#    '1-7, 5-3',
#    'Sorry',
#    'Ja',
#    'Denk dat we andersom moeten doen',
#    'Waar zitten jouw gates?',
#    'Open?',
#    'Gates = niet grijze vlakken btw maar laat maar',
#    'Ja',
#    'Rood nu?'],
#   133.175),
#  (['4-5, 6-6',
#    'Open?',
#    'Ja',
#    'Rood?',
#    'Open?',
#    'Ik heb nog een gate nodig',
#    '4-5  of 6-6',
#    'Rood'],
#   ['1-3, 2-5, 6-3',
#    'Ik kan niet bij jouw gates',
#    'Ja',
#    'Open?',
#    'Nee',
#    'Mijn gates moeten nog 1 x open',
#    'Kan jij nog op 1 van mijn grijs omen nu?',
#    'Rood',
#    'Jij ook?',
#    'Open?',
#    'Dan rood'],
#   80.676),
#  (['1-1, 5-1, 2-5, 6-7',
#    'Open?',
#    'Rood?',
#    'Nee',
#    '1-1, 5-1, 2-5 of 6-7',
#    'Open?',
#    'Ja',
#    'ben rood',
#    'Nee',
#    'Nu wel',
#    'Jij kan rood',
#    'ok',
#    'Nee',
#    'Ik moet 5-1 hebben',
#    'Ja',
#    'Open?'],
#   ['2-7, 5-1',
#    'Ja',
#    'Ja',
#    'Jij ook?',
#    'Jij ook?',
#    'Ik sta nu vast op rood',
#    'Ga op 1 van mijn grijs staan',
#    '2-7, 5-1',
#    'Ik moet eerst dus',
#    'Als ik nu van switch afga',
#    'Kan jij dan rood?',
#    'Ik moet eerst',
#    'Ga terug naar mijn switch',
#    'Kan jij vanaf waar je nu bent rood?',
#    'Ga 2-7',
#    'Nee',
#    'Ga 2-7',
#    'Nu rood?',
#    'Kan jij van 5-1 naar rood zonder gate?',
#    'Ga 5-1',
#    'Ja',
#    'Ga rood'],
#   228.973),
#  (['1-3, 4-6', 'Kan niet bij 3-6', 'Jij mag eerst', 'Ja', 'Open?', 'Rood'],
#   ['3-6', 'Open?', 'Rood'],
#   40.189),
#  (['7-4, 4-3, 6-3',
#    'Ja',
#    'Open?',
#    'Nee',
#    'Nog 1 gate nodig',
#    'Nee',
#    'Nope',
#    '6-3',
#    'Ja'],
#   ['4-3',
#    'Open?',
#    'Kan jij rood?',
#    'Open?',
#    'Nu rood',
#    '6-4 is jouw grijs toch?',
#    'Nu rood',
#    'Ben je?'],
#   99.306),
#  (['x1y4 is mn x',
#    'x3y4, x3y6 of x4y7',
#    'nan',
#    'ja kan er door',
#    'ben bij rood',
#    'of moet ik tussen stop maken bij ander poortje',
#    'Oke jij moet nog op een grijze',
#    'x3y4 x3y6 of x4y7',
#    'ja',
#    'j',
#    'rood'],
#   ['x2y5mijne',
#    'jij moet op x3y4',
#    'nu?',
#    'jij moet x4y4',
#    'ja denk',
#    'x3y4',
#    'Oops',
#    'sta op rood',
#    'wooow'],
#   136.986),
#  (['x3y3 grijs',
#    'rood op x5y6',
#    'x4y7',
#    'x3y3',
#    'ben er door',
#    'ga naar krijs',
#    'kruis',
#    'nice'],
#   ['rood op x5y2',
#    'ik op x5y6',
#    'grijze op x2y3, x6y1, x3y6',
#    'Nu?',
#    'En dan op die van mij',
#    'sta op kruis'],
#   76.058)]

# %%
# Q1: Calculate the average number of turns per interface (efficiency)

# %%
length_WYS = 0
all_lengths_WYS = []
ratios_WYS = []
for conversation in WYS_turn_list:
    length_WYS += len(conversation[0]) + len(conversation[1])
    try:
        log_odds = math.log(len(conversation[0])/len(conversation[1]))
        ratios_WYS.append(log_odds)
    except ZeroDivisionError:
        pass
    all_lengths_WYS.append([len(conversation[0]) + len(conversation[1]), log_odds, 'WYS'])

print('The average length of a WYSIWYG conversation is {0:.0f} turns'.format(length_WYS/len(WYS_turn_list)))

length_TBT = 0
all_lengths_TBT = []
ratios_TBT = []
for conversation in TBT_turn_list:
    length_TBT += len(conversation[0]) + len(conversation[1])
    try:
        log_odds = math.log(len(conversation[0])/len(conversation[1]))
        ratios_TBT.append(log_odds)
    except ZeroDivisionError:
        pass
    all_lengths_TBT.append([len(conversation[0]) + len(conversation[1]), log_odds, 'TBT'])

print('The average length of a TBT conversation is {0:.0f} turns'.format(length_TBT/len(TBT_turn_list)))
# Out:
# The average length of a WYSIWYG conversation is 50 turns
# The average length of a TBT conversation is 24 turns

# %%
interface_df = pd.DataFrame(all_lengths_WYS + all_lengths_TBT, columns=['Length', 'LogOdds', 'Interface'])

# %%
sns.boxplot(x=interface_df['Interface'], y=interface_df['Length'], showfliers=False)
# Out:
# <AxesSubplot:xlabel='Interface', ylabel='Length'>

# %%
# Q2: Calculate ratios of turn by participant1 to participant2 (Turn taking)

# %%
print(sum(ratios_TBT)/len(ratios_TBT))
print(sum(ratios_WYS)/len(ratios_WYS))
# Out:
# 0.042134187051223404
# 0.04182711905735217

# %%
sns.boxplot(x=interface_df['Interface'], y=interface_df['LogOdds'], showfliers=False)
# Out:
# <AxesSubplot:xlabel='Interface', ylabel='LogOdds'>

# %%
# Q3: Calculate similarity of the conversations

# %%
nlp = spacy.load('nl_core_news_lg')

# %%
sentiment = SentimentIntensityAnalyzer()

# %%
TBT_similarity_scores, WYS_similarity_scores, TBT_sentiment_scores, WYS_sentiment_scores, TBT_synchrony_scores, WYS_synchrony_scores = [],[],[],[],[],[]
for i in range(len(TBT_turn_list)):
    convo1 = nlp(' '.join(TBT_turn_list[i][0]))
    convo2 = nlp(' '.join(TBT_turn_list[i][1]))
    sentiment1 = sentiment.polarity_scores(' '.join(TBT_turn_list[i][0]))
    sentiment2 = sentiment.polarity_scores(' '.join(TBT_turn_list[i][1]))
    TBT_similarity_scores.append(convo1.similarity(convo2))
    TBT_sentiment_scores.append((sentiment1['pos']+sentiment2['pos'])/2)
    TBT_synchrony_scores.append(abs(sentiment1['neg']-sentiment2['neg'])+abs(sentiment1['neu']-sentiment2['neu'])+abs(sentiment1['pos']-sentiment2['pos']))
    
for i in range(len(WYS_turn_list)):
    convo1 = nlp(' '.join(WYS_turn_list[i][0]))
    convo2 = nlp(' '.join(WYS_turn_list[i][1]))
    sentiment1 = sentiment.polarity_scores(' '.join(WYS_turn_list[i][0]))
    sentiment2 = sentiment.polarity_scores(' '.join(WYS_turn_list[i][1]))
    WYS_similarity_scores.append(convo1.similarity(convo2))
    WYS_sentiment_scores.append((sentiment1['pos']+sentiment2['pos'])/2)
    WYS_synchrony_scores.append(abs(sentiment1['neg']-sentiment2['neg'])+abs(sentiment1['neu']-sentiment2['neu'])+abs(sentiment1['pos']-sentiment2['pos']))
# Out:
# <ipython-input-47-c542190eddc1>:16: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   WYS_similarity_scores.append(convo1.similarity(convo2))

# %%
interface_df['Similarity'] = (WYS_similarity_scores+TBT_similarity_scores)
interface_df['Happiness'] = (WYS_sentiment_scores+TBT_sentiment_scores)
interface_df['Synchrony'] = (WYS_synchrony_scores+TBT_synchrony_scores)

# %%
interface_df.head(10)
# Out:
#    Length   LogOdds Interface  Similarity  Happiness
# 0      42 -0.191055       WYS    0.846619     0.0260
# 1      21 -0.095310       WYS    0.890361     0.0500
# 2      23 -0.262364       WYS    0.777222     0.0350
# 3       6  0.000000       WYS    0.871421     0.0000
# 4      37  0.054067       WYS    0.775050     0.0630
# 5      50  0.000000       WYS    0.912437     0.0000
# 6      18 -0.451985       WYS    0.786721     0.0255
# 7      25  0.080043       WYS    0.794701     0.0000
# 8      29 -0.068993       WYS    0.644649     0.0455
# 9      24  0.000000       WYS    0.677022     0.0000

# %%
sns.boxplot(x=interface_df['Interface'], y=interface_df['Similarity'], showfliers=False)
# Out:
# <AxesSubplot:xlabel='Interface', ylabel='Similarity'>

# %%
sns.boxplot(x=interface_df['Interface'], y=interface_df['Happiness'], showfliers=False)
# Out:
# <AxesSubplot:xlabel='Interface', ylabel='Happiness'>

# %%
sns.boxplot(x=interface_df['Interface'], y=interface_df['Synchrony'], showfliers=False)
# Out:
# <AxesSubplot:xlabel='Interface', ylabel='Synchrony'>
