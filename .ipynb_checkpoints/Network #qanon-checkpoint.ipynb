# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
from networkx_viewer import Viewer

# %%
df = pd.read_csv('edges_qanon.csv', sep=';')
df.rename(columns=df.iloc[0], inplace=True)
df.drop(df.index[0], inplace=True)

# %%
print(df)
# Out:
#            Vertex 1        Vertex 2 Color Width Style Opacity Visibility  \
# 1         basile061        joebiden   NaN   NaN   NaN     NaN        NaN
# 2         basile061    ericnaulleau   NaN   NaN   NaN     NaN        NaN
# 3          kiermunn     carymarules   NaN   NaN   NaN     NaN        NaN
# 4          kiermunn     spicygarage   NaN   NaN   NaN     NaN        NaN
# 5           lmjcstt           amazi   NaN   NaN   NaN     NaN        NaN
# ..              ...             ...   ...   ...   ...     ...        ...
# 656       f9falcon1               q   NaN   NaN   NaN     NaN        NaN
# 657     davidpuente     davidpuente   NaN   NaN   NaN     NaN        NaN
# 658     davidpuente     davidpuente   NaN   NaN   NaN     NaN        NaN
# 659      keynesblog     davidpuente   NaN   NaN   NaN     NaN        NaN
# 660  johnvalenciacf  johnvalenciacf   NaN   NaN   NaN     NaN        NaN
#
#     Label Label Text Color Label Font Size  ...  \
# 1     NaN              NaN             NaN  ...
# 2     NaN              NaN             NaN  ...
# 3     NaN              NaN             NaN  ...
# 4     NaN              NaN             NaN  ...
# 5     NaN              NaN             NaN  ...
# ..    ...              ...             ...  ...
# 656   NaN              NaN             NaN  ...
# 657   NaN              NaN             NaN  ...
# 658   NaN              NaN             NaN  ...
# 659   NaN              NaN             NaN  ...
# 660   NaN              NaN             NaN  ...
#
#                                                  Tweet  \
# 1    RT @EricNaulleau: Nous sommes le 2 mai 2021 et...
# 2    RT @EricNaulleau: Nous sommes le 2 mai 2021 et...
# 3    RT @spicygarage: For daring to criticize Chris...
# 4    RT @spicygarage: For daring to criticize Chris...
# 5    RT @jarue369: Did anyone hold @PrayingMedic re...
# ..                                                 ...
# 656   @Q @SAYS @HI #QANON @CNN https://t.co/Y9yOlaMnWE
# 657  Dal profilo di uno dei due No vax arrestati co...
# 658  Dal profilo di uno dei due No vax arrestati co...
# 659  RT @DavidPuente: Dal profilo di uno dei due No...
# 660  Looks like this #QAnon documentary could be in...
#
#                                          URLs in Tweet Domains in Tweet  \
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# 3                                                  NaN              NaN
# 4                                                  NaN              NaN
# 5                                                  NaN              NaN
# ..                                                 ...              ...
# 656                                                NaN              NaN
# 657  https://twitter.com/i/web/status/1389148589943...      twitter.com
# 658  https://twitter.com/i/web/status/1389154583981...      twitter.com
# 659                                                NaN              NaN
# 660  https://www.npr.org/2021/04/22/989241933/q-a-d...          npr.org
#
#     Hashtags in Tweet Tweet Date (UTC)  \
# 1                 NaN   2-5-2021 12:31
# 2                 NaN   2-5-2021 12:31
# 3       antivax qanon   2-5-2021 12:33
# 4       antivax qanon   2-5-2021 12:33
# 5                 NaN   2-5-2021 12:33
# ..                ...              ...
# 656             qanon   3-5-2021 12:04
# 657               NaN   3-5-2021 09:23
# 658               NaN   3-5-2021 09:47
# 659               NaN   3-5-2021 12:06
# 660             qanon   3-5-2021 12:06
#
#                                 Twitter Page for Tweet Latitude Longitude  \
# 1    https://twitter.com/#!/basile061/status/138883...      NaN       NaN
# 2    https://twitter.com/#!/basile061/status/138883...      NaN       NaN
# 3    https://twitter.com/#!/kiermunn/status/1388833...      NaN       NaN
# 4    https://twitter.com/#!/kiermunn/status/1388833...      NaN       NaN
# 5    https://twitter.com/#!/lmjcstt/status/13888341...      NaN       NaN
# ..                                                 ...      ...       ...
# 656  https://twitter.com/#!/f9falcon1/status/138918...      NaN       NaN
# 657  https://twitter.com/#!/davidpuente/status/1389...      NaN       NaN
# 658  https://twitter.com/#!/davidpuente/status/1389...      NaN       NaN
# 659  https://twitter.com/#!/keynesblog/status/13891...      NaN       NaN
# 660  https://twitter.com/#!/johnvalenciacf/status/1...      NaN       NaN
#
#              Imported ID In-Reply-To Tweet ID
# 1    1388833534773768195                  NaN
# 2    1388833534773768195                  NaN
# 3    1388833936361598979                  NaN
# 4    1388833936361598979                  NaN
# 5    1388834148362641412                  NaN
# ..                   ...                  ...
# 656  1389189151015243779                  NaN
# 657  1389148589943894017                  NaN
# 658  1389154583981830147                  NaN
# 659  1389189685990371328                  NaN
# 660  1389189708064960512                  NaN
#
# [660 rows x 26 columns]

# %%
df_v = pd.read_csv('vertices_qanon.csv', sep=';')
df_v = df_v.drop(256)
df_v.rename(columns=df_v.iloc[0], inplace=True)
df_v.drop(df_v.index[0], inplace=True)

tweet_size = df_v['Tweets'][:563].to_list()

tweet_size2 = [int(val)/100000 for val in tweet_size]
print(tweet_size)
# Out:
# ['403908', '7327', '9169', '17573', '30346', '44159', '93096', '478', '51927', '109068', '17256', '1308', '19607', '269447', '4170', '50448', '3222', '2013', '170996', '5345', '9441', '809294', '23867', '92844', '272907', '45222', '59660', '59106', '266542', '41449', '414200', '5468', '3678', '96296', '12710', '14364', '22', '3529', '523980', '16976', '31347', '4006', '57260', '258521', '449467', '121776', '263667', '34482', '16222', '7014', '2692', '3136', '7466', '70801', '28170', '1273', '502450', '93', '3844', '15048', '51130', '17988', '4982', '14269', '29107', '17097', '11950', '17344', '6766', '32355', '11834', '187221', '14509', '194439', '326', '3067', '20374', '7788', '27734', '20875', '2310', '85237', '126', '15385', '30189', '68618', '19915', '1439', '10756', '2038', '44481', '4585', '100419', '5486', '18069', '45309', '227', '84413', '31389', '42425', '23745', '27309', '32528', '440754', '8700', '9715', '4169', '79000', '25745', '132712', '65142', '8287', '2822', '91624', '16028', '78959', '5638', '31151', '482', '20195', '44793', '66249', '12174', '93495', '210020', '752', '2975', '35206', '388845', '804', '9980', '61747', '84462', '405067', '213054', '39375', '6346', '6284', '140020', '3246', '161987', '368181', '45491', '38243', '110140', '6922', '79877', '49071', '55522', '57383', '856480', '5998', '2626', '448498', '37896', '60322', '44168', '337103', '46070', '160248', '13258', '39409', '79450', '24702', '6992', '128256', '18111', '7261', '868', '8816', '48035', '135126', '140223', '124902', '34125', '157875', '32911', '872', '74111', '35455', '13206', '26148', '266974', '314474', '32829', '717', '245198', '26679', '62161', '9825', '85249', '25610', '27206', '417645', '5371', '187281', '12551', '347', '262178', '16918', '50069', '24990', '88975', '13216', '232738', '52615', '6613', '11935', '15311', '6496', '89392', '11232', '1354', '73544', '11828', '17127', '22399', '12387', '8', '14201', '33428', '7843', '46', '50563', '81201', '374496', '15018', '4468', '110', '1822', '3152', '53668', '13737', '2232', '9213', '112869', '119548', '30786', '7359', '32190', '21990', '42730', '8420', '67455', '17204', '102152', '34951', '12406', '13503', '287426', '12775', '60124', '96', '8012', '10617', '34439', '187813', '114224', '22251', '23833', '57050', '13668', '54319', '48835', '40067', '50904', '13191', '82598', '91354', '21299', '36287', '0', '7727', '33600', '34630', '2608', '12412', '19737', '11479', '56325', '130217', '50076', '19188', '132237', '558', '9587', '8958', '52780', '19543', '3900', '5497', '1701', '102260', '27069', '35116', '61', '81622', '12658', '53076', '21315', '68200', '244341', '10467', '19714', '64711', '76116', '144165', '142676', '117861', '149907', '29197', '2584', '30023', '15819', '19807', '266086', '325456', '279828', '450713', '533939', '137235', '4766', '7631', '903903', '2167', '146416', '7676', '3586', '4641', '1017', '106580', '86815', '348966', '44755', '9732', '312447', '99797', '2518', '160216', '241871', '39574', '22176', '7317', '635', '821', '852378', '13686', '80520', '339390', '23569', '171817', '3038', '82868', '274913', '88559', '297553', '2032', '34235', '3642', '23454', '520928', '300368', '14227', '14629', '11343', '11987', '123', '824', '37', '53', '97965', '21843', '4029', '32799', '60623', '4602', '260563', '14549', '425410', '304703', '3497', '872188', '33290', '30179', '317461', '72499', '1787', '6203', '97333', '8888', '35834', '9820', '27150', '61305', '4313', '3793', '172779', '116035', '69176', '63', '8173', '10114', '687741', '653752', '12089', '393', '79440', '112416', '136988', '532678', '327078', '11493', '21535', '12723', '5983', '108505', '48020', '29970', '44142', '20211', '3461', '25886', '2345', '90206', '965', '2789', '2945', '5501', '30101', '1109', '77', '118147', '22652', '34363', '2568', '340068', '148623', '118194', '16577', '1232559', '62280', '25328', '202538', '21105', '106399', '78172', '42152', '28151', '132600', '200780', '395233', '109112 ...

# %%
G = nx.Graph()
for i in range(len(df)):
    #if df.iloc[i]['Vertex 1'] != df.iloc[i]['Vertex 2']:
    G.add_edge(df.iloc[i]['Vertex 1'], df.iloc[i]['Vertex 2'])

# %%
closeness = nx.betweenness_centrality(G)
closeness_list = list(closeness.values())
degree = nx.degree_centrality(G)
degree_list = list(degree.values())
color_list = []
# for size in degree_list:
#     if size > 0.02:
#         color_list.append('red')
#     else:
#         color_list.append('blue')

for i in range(len(closeness_list)):
    if degree_list[i] > 0.03:
        color_list.append('red')
    elif closeness_list[i] > 0.02:
        color_list.append('green')
    else:
        color_list.append('blue')
    
        
# size_list = [val*200 for val in size_list]
# size_list = tweet_size
# print(len(size_list))
# print(len(color_list))
# print(len(tweet_size2))
# print(len(G))

# %%
nx.draw(G, node_size=10, node_color=color_list)
plt.show()

# %%
# size_list.sort(reverse=True)

# %%
# print(size_list[:9])

# %%
sorted_size = sorted(degree.items(), key=lambda x: x[1], reverse=True)
names = [item[0] for item in sorted_size[:8]]
print(names)
# Out:
# ['ruthmkb', 'davidpuente', 'bombshelldaily', 'rudybouma', 'mog7546', 'joebiden', 'ericnaulleau', 'stevemandolin']

# %%
# sorted_size = sorted(closeness.items(), key=lambda x: x[1], reverse=True)
# print(sorted_size)

# %%
# df.loc[(df['Vertex 1'] == 'ruthmkb') | (df['Vertex 2'] == 'ruthmkb')]

# %%
highest_degree = df.loc[(df['Vertex 1'].isin(names)) | (df['Vertex 2'].isin(names))]

# %%
highest_degree = df.loc[(df['Vertex 1'].isin(names))]

# %%
highest_degree
# Out:
#            Vertex 1         Vertex 2 Color Width Style Opacity Visibility  \
# 388         mog7546          mog7546   NaN   NaN   NaN     NaN        NaN
# 480   stevemandolin    gopchairwoman   NaN   NaN   NaN     NaN        NaN
# 482   stevemandolin              gop   NaN   NaN   NaN     NaN        NaN
# 484   stevemandolin    michaelwoodtx   NaN   NaN   NaN     NaN        NaN
# 486   stevemandolin     scottpresler   NaN   NaN   NaN     NaN        NaN
# 487   stevemandolin      angiesevers   NaN   NaN   NaN     NaN        NaN
# 489   stevemandolin   bigbluewaveusa   NaN   NaN   NaN     NaN        NaN
# 492   stevemandolin        kennybj52   NaN   NaN   NaN     NaN        NaN
# 493   stevemandolin        kennybj52   NaN   NaN   NaN     NaN        NaN
# 495   stevemandolin             oann   NaN   NaN   NaN     NaN        NaN
# 497   stevemandolin   kaylan_donahou   NaN   NaN   NaN     NaN        NaN
# 498   stevemandolin      aspiringone   NaN   NaN   NaN     NaN        NaN
# 500   stevemandolin           jobrny   NaN   NaN   NaN     NaN        NaN
# 502   stevemandolin     jerasikehorn   NaN   NaN   NaN     NaN        NaN
# 503   stevemandolin  zeropartysystem   NaN   NaN   NaN     NaN        NaN
# 505   stevemandolin        v92835072   NaN   NaN   NaN     NaN        NaN
# 507   stevemandolin      billkristol   NaN   NaN   NaN     NaN        NaN
# 508   stevemandolin     gatewayrover   NaN   NaN   NaN     NaN        NaN
# 510   stevemandolin           jankka   NaN   NaN   NaN     NaN        NaN
# 511   stevemandolin   bombshelldaily   NaN   NaN   NaN     NaN        NaN
# 557         ruthmkb          ruthmkb   NaN   NaN   NaN     NaN        NaN
# 575    ericnaulleau         joebiden   NaN   NaN   NaN     NaN        NaN
# 638  bombshelldaily   bombshelldaily   NaN   NaN   NaN     NaN        NaN
# 639  bombshelldaily   bombshelldaily   NaN   NaN   NaN     NaN        NaN
# 640  bombshelldaily   bombshelldaily   NaN   NaN   NaN     NaN        NaN
# 641  bombshelldaily   bombshelldaily   NaN   NaN   NaN     NaN        NaN
# 642  bombshelldaily   bombshelldaily   NaN   NaN   NaN     NaN        NaN
# 643  bombshelldaily   bombshelldaily   NaN   NaN   NaN     NaN        NaN
# 644  bombshelldaily   bombshelldaily   NaN   NaN   NaN     NaN        NaN
# 645  bombshelldaily   bombshelldaily   NaN   NaN   NaN     NaN        NaN
# 657     davidpuente      davidpuente   NaN   NaN   NaN     NaN        NaN
# 658     davidpuente      davidpuente   NaN   NaN   NaN     NaN        NaN
#
#     Label Label Text Color Label Font Size  ...  \
# 388   NaN              NaN             NaN  ...
# 480   NaN              NaN             NaN  ...
# 482   NaN              NaN             NaN  ...
# 484   NaN              NaN             NaN  ...
# 486   NaN              NaN             NaN  ...
# 487   NaN              NaN             NaN  ...
# 489   NaN              NaN             NaN  ...
# 492   NaN              NaN             NaN  ...
# 493   NaN              NaN             NaN  ...
# 495   NaN              NaN             NaN  ...
# 497   NaN              NaN             NaN  ...
# 498   NaN              NaN             NaN  ...
# 500   NaN              NaN             NaN  ...
# 502   NaN              NaN             NaN  ...
# 503   NaN              NaN             NaN  ...
# 505   NaN              NaN             NaN  ...
# 507   NaN              NaN             NaN  ...
# 508   NaN              NaN             NaN  ...
# 510   NaN              NaN             NaN  ...
# 511   NaN              NaN             NaN  ...
# 557   NaN              NaN             NaN  ...
# 575   NaN              NaN             NaN  ...
# 638   NaN              NaN             NaN  ...
# 639   NaN              NaN             NaN  ...
# 640   NaN              NaN             NaN  ...
# 641   NaN              NaN             NaN  ...
# 642   NaN              NaN             NaN  ...
# 643   NaN              NaN             NaN  ...
# 644   NaN              NaN             NaN  ...
# 645   NaN              NaN             NaN  ...
# 657   NaN              NaN             NaN  ...
# 658   NaN              NaN             NaN  ...
#
#                                                  Tweet  \
# 388  RT @mog7546: This is the fringiest of the frin...
# 480  RT @angiesevers: @ScottPresler @michaelwoodtx ...
# 482  RT @angiesevers: @ScottPresler @michaelwoodtx ...
# 484  RT @angiesevers: @ScottPresler @michaelwoodtx ...
# 486  RT @angiesevers: @ScottPresler @michaelwoodtx ...
# 487  RT @angiesevers: @ScottPresler @michaelwoodtx ...
# 489  RT @BigBlueWaveUSA: If it has to do with Tяump...
# 492  RT @KennyBJ52: Leading #QAnon influencer is De...
# 493  RT @KennyBJ52: Leading #QAnon influencer is De...
# 495  RT @AspiringOne: @kaylan_donahou @OANN It’s to...
# 497  RT @AspiringOne: @kaylan_donahou @OANN It’s to...
# 498  RT @AspiringOne: @kaylan_donahou @OANN It’s to...
# 500  RT @Jobrny: Watching the documentary "Agents o...
# 502  RT @ZeroPartySystem: @JerasIkehorn Hey #qanon ...
# 503  RT @ZeroPartySystem: @JerasIkehorn Hey #qanon ...
# 505  RT @V92835072: Never trust a #conspiracy theor...
# 507  RT @gatewayrover: @BillKristol Is that suppose...
# 508  RT @gatewayrover: @BillKristol Is that suppose...
# 510  RT @jankka: Never stop the madness. #conspirac...
# 511  RT @BombshellDAILY: LIE AFTER LIE AFTER LIE\nS...
# 557  Montréal’s Biggest #COVIDVaccination Site Shut...
# 575  Nous sommes le 3 mai 2021 et @JoeBiden n’a tou...
# 638  RT @BombshellDAILY: EXTREMIST CANDIDATES MAY H...
# 639  RT @BombshellDAILY: DUMB-MONEY CONGRESSMEN RAK...
# 640  WORSHIPPING TRUMP WITHOUT "THE LIE" NOT ENOUGH...
# 641  RT @BombshellDAILY: WORSHIPPING TRUMP WITHOUT ...
# 642  LIE AFTER LIE AFTER LIE\nSpeaking out against ...
# 643  RT @BombshellDAILY: WHY THOSE THAT CONTINUE TO...
# 644  RT @BombshellDAILY: GAETZ VORTEX CONSUMING PAR...
# 645  RT @BombshellDAILY: LIE AFTER LIE AFTER LIE\nS...
# 657  Dal profilo di uno dei due No vax arrestati co...
# 658  Dal profilo di uno dei due No vax arrestati co...
#
#                                          URLs in Tweet Domains in Tweet  \
# 388                                                NaN              NaN
# 480                                                NaN              NaN
# 482                                                NaN              NaN
# 484                                                NaN              NaN
# 486                                                NaN              NaN
# 487                                                NaN              NaN
# 489                                                NaN              NaN
# 492                                                NaN              NaN
# 493                                                NaN              NaN
# 495                                                NaN              NaN
# 497                                                NaN              NaN
# 498                                                NaN              NaN
# 500                                                NaN              NaN
# 502                                                NaN              NaN
# 503                                                NaN              NaN
# 505                                                NaN              NaN
# 507                                                NaN              NaN
# 508                                                NaN              NaN
# 510                                                NaN              NaN
# 511                                                NaN              NaN
# 557  https://twitter.com/i/web/status/1388890609252...      twitter.com
# 575  https://twitter.com/i/web/status/1389101271102...      twitter.com
# 638                                                NaN              NaN
# 639                                                NaN              NaN
# 640  https://twitter.com/i/web/status/1388910690002...      twitter.com
# 641                                                NaN              NaN
# 642  https://twitter.com/i/web/status/1389146270489...      twitter.com
# 643                                                NaN              NaN
# 644                                                NaN              NaN
# 645                                                NaN              NaN
# 657  https://twitter.com/i/web/status/1389148589943...      twitter.com
# 658  https://twitter.com/i/web/status/1389154583981...      twitter.com
#
#                      Hashtags in Tweet Tweet Date (UTC)  \
# 388                              qanon   2-5-2021 23:00
# 480                                NaN   2-5-2021 14:23
# 482                                NaN   2-5-2021 14:23
# 484                                NaN   2-5-2021 14:23
# 486                                NaN   2-5-2021 14:23
# 487                                NaN   2-5-2021 14:23
# 489                       qanon cult45   2-5-2021 21:53
# 492  qanon craiglongley denvercolorado   3-5-2021 00:23
# 493  qanon craiglongley denvercolorado   3-5-2021 01:13
# 495                                NaN   3-5-2021 02:03
# 497                                NaN   3-5-2021 02:03
# 498                                NaN   3-5-2021 02:03
# 500                                NaN   3-5-2021 02:53
# 502                              qanon   3-5-2021 04:33
# 503                              qanon   3-5-2021 04:33
# 505                         conspiracy   3-5-2021 07:03
# 507              conservativeterrorist   3-5-2021 07:53
# 508              conservativeterrorist   3-5-2021 07:53
# 510                   conspiracy qanon   3-5-2021 08:43
# 511                                NaN   3-5-2021 09:33
# 557             covidvaccination qanon   2-5-2021 16:18
# 575                                NaN   3-5-2021 06:15
# 638                                NaN   2-5-2021 16:18
# 639                                NaN   2-5-2021 16:20
# 640                                NaN   2-5-2021 17:38
# 641                                NaN   3-5-2021 08:11
# 642                                NaN   3-5-2021 09:14
# 643                cultism personality   3-5-2021 10:53
# 644                         corruption   3-5-2021 11:42
# 645                                NaN   3-5-2021 11:52
# 657                                NaN   3-5-2021 09:23
# 658                                NaN   3-5-2021 09:47
#
#                                 Twitter Page for Tweet Latitude Longitude  \
# 388  https://twitter.com/#!/mog7546/status/13889918...      NaN       NaN
# 480  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 482  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 484  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 486  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 487  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 489  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 492  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 493  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 495  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 497  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 498  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 500  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 502  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 503  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 505  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 507  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 508  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 510  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 511  https://twitter.com/#!/stevemandolin/status/13...      NaN       NaN
# 557  https://twitter.com/#!/ruthmkb/status/13888906...      NaN       NaN
# 575  https://twitter.com/#!/ericnaulleau/status/138...      NaN       NaN
# 638  https://twitter.com/#!/bombshelldaily/status/1...      NaN       NaN
# 639  https://twitter.com/#!/bombshelldaily/status/1...      NaN       NaN
# 640  https://twitter.com/#!/bombshelldaily/status/1...      NaN       NaN
# 641  https://twitter.com/#!/bombshelldaily/status/1...      NaN       NaN
# 642  https://twitter.com/#!/bombshelldaily/status/1...      NaN       NaN
# 643  https://twitter.com/#!/bombshelldaily/status/1...      NaN       NaN
# 644  https://twitter.com/#!/bombshelldaily/status/1...      NaN       NaN
# 645  https://twitter.com/#!/bombshelldaily/status/1...      NaN       NaN
# 657  https://twitter.com/#!/davidpuente/status/1389...      NaN       NaN
# 658  https://twitter.com/#!/davidpuente/status/1389...      NaN       NaN
#
#              Imported ID In-Reply-To Tweet ID
# 388  1388991846169391107                  NaN
# 480  1388861745683308549                  NaN
# 482  1388861745683308549                  NaN
# 484  1388861745683308549                  NaN
# 486  1388861745683308549                  NaN
# 487  1388861745683308549                  NaN
# 489  1388974983481679874                  NaN
# 492  1389012737368281090                  NaN
# 493  1389025315452641281                  NaN
# 495  1389037899073552386                  NaN
# 497  1389037899073552386                  NaN
# 498  1389037899073552386                  NaN
# 500  1389050481259864064                  NaN
# 502  1389075648879099904                  NaN
# 503  1389075648879099904                  NaN
# 505  1389113398172942341                  NaN
# 507  1389125981324005377                  NaN
# 508  1389125981324005377                  NaN
# 510  1389138564433158146                  NaN
# 511  1389151147865251845                  NaN
# 557  1388890609252016135                  NaN
# 575  1389101271102238722                  NaN
# 638  1388890607679049731                  NaN
# 639  1388891246383489031                  NaN
# 640  1388910690002481160                  NaN
# 641  1389130563148189705                  NaN
# 642  1389146270489583619                  NaN
# 643  1389171331531513856                  NaN
# 644  1389183652546945029                  NaN
# 645  1389186022622248960                  NaN
# 657  1389148589943894017                  NaN
# 658  1389154583981830147                  NaN
#
# [32 rows x 26 columns]

# %%
print(highest_degree['Vertex 1'] + highest_degree['Tweet'])
# Out:
# 388    mog7546RT @mog7546: This is the fringiest of t...
# 480    stevemandolinRT @angiesevers: @ScottPresler @m...
# 482    stevemandolinRT @angiesevers: @ScottPresler @m...
# 484    stevemandolinRT @angiesevers: @ScottPresler @m...
# 486    stevemandolinRT @angiesevers: @ScottPresler @m...
# 487    stevemandolinRT @angiesevers: @ScottPresler @m...
# 489    stevemandolinRT @BigBlueWaveUSA: If it has to ...
# 492    stevemandolinRT @KennyBJ52: Leading #QAnon inf...
# 493    stevemandolinRT @KennyBJ52: Leading #QAnon inf...
# 495    stevemandolinRT @AspiringOne: @kaylan_donahou ...
# 497    stevemandolinRT @AspiringOne: @kaylan_donahou ...
# 498    stevemandolinRT @AspiringOne: @kaylan_donahou ...
# 500    stevemandolinRT @Jobrny: Watching the document...
# 502    stevemandolinRT @ZeroPartySystem: @JerasIkehor...
# 503    stevemandolinRT @ZeroPartySystem: @JerasIkehor...
# 505    stevemandolinRT @V92835072: Never trust a #con...
# 507    stevemandolinRT @gatewayrover: @BillKristol Is...
# 508    stevemandolinRT @gatewayrover: @BillKristol Is...
# 510    stevemandolinRT @jankka: Never stop the madnes...
# 511    stevemandolinRT @BombshellDAILY: LIE AFTER LIE...
# 557    ruthmkbMontréal’s Biggest #COVIDVaccination Si...
# 575    ericnaulleauNous sommes le 3 mai 2021 et @JoeB...
# 638    bombshelldailyRT @BombshellDAILY: EXTREMIST CA...
# 639    bombshelldailyRT @BombshellDAILY: DUMB-MONEY C...
# 640    bombshelldailyWORSHIPPING TRUMP WITHOUT "THE L...
# 641    bombshelldailyRT @BombshellDAILY: WORSHIPPING ...
# 642    bombshelldailyLIE AFTER LIE AFTER LIE\nSpeakin...
# 643    bombshelldailyRT @BombshellDAILY: WHY THOSE TH...
# 644    bombshelldailyRT @BombshellDAILY: GAETZ VORTEX...
# 645    bombshelldailyRT @BombshellDAILY: LIE AFTER LI...
# 657    davidpuenteDal profilo di uno dei due No vax a...
# 658    davidpuenteDal profilo di uno dei due No vax a...
# dtype: object
